# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import cm
from tqdm import tqdm
import os
import torch
torch.cuda.empty_cache()
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from numpy import linalg as la
from numpy import *
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#from solver_sdmd_torch_gpu import KoopmanNNTorch, KoopmanSolverTorch
from solver_sdmd_torch_gpu2 import KoopmanNNTorch, KoopmanSolverTorch
from solver_gedmd_torch_gpu import KoopmanSolverTorch as KoopmanSolverTorch_g
print (torch.__version__, torch.cuda.is_available())
print(torch.version.cuda)
print (torch.cuda.get_device_name())
# device= 'cpu'
device= 'cuda'
# Out:
# 2.5.1 True
# 12.4
# NVIDIA A40

# %%
import torch
torch.cuda.empty_cache()

# %%
#### Test 1 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:18<00:00, 66.52it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 0.416256 val loss: 0.397820
# saving, val loss enhanced: 0.397819509976044 10000
# Epoch: 2 	Training Loss: 0.381067 val loss: 0.365773
# saving, val loss enhanced: 0.3657727338353005 0.397819509976044
# Epoch: 3 	Training Loss: 0.349698 val loss: 0.333781
# saving, val loss enhanced: 0.33378086346317937 0.3657727338353005
# Epoch: 4 	Training Loss: 0.323692 val loss: 0.309410
# saving, val loss enhanced: 0.3094098732743225 0.33378086346317937
# Epoch: 5 	Training Loss: 0.299182 val loss: 0.289855
# saving, val loss enhanced: 0.28985462689457736 0.3094098732743225
# Epoch: 6 	Training Loss: 0.277680 val loss: 0.264986
# saving, val loss enhanced: 0.26498614379408886 0.28985462689457736
# Epoch: 7 	Training Loss: 0.259227 val loss: 0.251065
# saving, val loss enhanced: 0.25106528618535917 0.26498614379408886
# Epoch: 8 	Training Loss: 0.243513 val loss: 0.236210
# saving, val loss enhanced: 0.23620976973437438 0.25106528618535917
# Epoch: 9 	Training Loss: 0.231468 val loss: 0.224803
# saving, val loss enhanced: 0.224803136009159 0.23620976973437438
# Epoch: 10 	Training Loss: 0.220165 val loss: 0.214873
# saving, val loss enhanced: 0.21487274249941787 0.224803136009159
# Epoch: 11 	Training Loss: 0.211032 val loss: 0.206492
# saving, val loss enhanced: 0.2064915520095651 0.21487274249941787
# Epoch: 12 	Training Loss: 0.205003 val loss: 0.201955
# saving, val loss enhanced: 0.20195518832842752 0.2064915520095651
# Epoch: 13 	Training Loss: 0.200166 val loss: 0.195484
# saving, val loss enhanced: 0.19548350871777284 0.20195518832842752
# Epoch: 14 	Training Loss: 0.193552 val loss: 0.190045
# saving, val loss enhanced: 0.19004513986254568 0.19548350871777284
# Epoch: 15 	Training Loss: 0.191753 val loss: 0.187164
# saving, val loss enhanced: 0.1871639442612507 0.19004513986254568
# Epoch: 16 	Training Loss: 0.187785 val loss: 0.184097
# saving, val loss enhanced: 0.18409700309392438 0.1871639442612507
# Epoch: 17 	Training Loss: 0.183757 val loss: 0.181920
# saving, val loss enhanced: 0.18192012161822427 0.18409700309392438
# Epoch: 18 	Training Loss: 0.181977 val loss: 0.179034
# saving, val loss enhanced: 0.1790343316327676 0.18192012161822427
# Epoch: 19 	Training Loss: 0.179084 val loss: 0.176652
# saving, val loss enhanced: 0.17665234890899026 0.1790343316327676
# Epoch: 20 	Training Loss: 0.176270 val loss: 0.173316
# saving, val loss enhanced: 0.17331629963974196 0.17665234890899026
# Epoch: 21 	Training Loss: 0.172523 val loss: 0.169327
# saving, val loss enhanced: 0.16932681729713206 0.17331629963974196
# Epoch: 22 	Training Loss: 0.172008 val loss: 0.169369
# Epoch: 23 	Training Loss: 0.167940 val loss: 0.166781
# saving, val loss enhanced: 0.1667809228956308 0.16932681729713206
# Epoch: 24 	Training Loss: 0.167015 val loss: 0.164340
# saving, val loss enhanced: 0.16433974852554345 0.1667809228956308
# Epoch: 25 	Training Loss: 0.164285 val loss: 0.164107
# saving, val loss enhanced: 0.16410677028353426 0.16433974852554345
# Epoch: 26 	Training Loss: 0.161775 val loss: 0.160088
# saving, val loss enhanced: 0.16008785921746743 0.16410677028353426
# Epoch: 27 	Training Loss: 0.161361 val loss: 0.160467
# Epoch: 28 	Training Loss: 0.160527 val loss: 0.158231
# saving, val loss enhanced: 0.1582305557756828 0.16008785921746743
# Epoch: 29 	Training Loss: 0.157365 val loss: 0.156743
# saving, val loss enhanced: 0.15674339630133555 0.1582305557756828
# Epoch: 30 	Training Loss: 0.157256 val loss: 0.153413
# saving, val loss enhanced: 0.15341304073882253 0.15674339630133555
# Epoch: 31 	Training Loss: 0.156039 val loss: 0.155009
# Epoch: 32 	Training Loss: 0.153285 val loss: 0.153160
# saving, val loss enhanced: 0.1531602310999333 0.15341304073882253
# Epoch: 33 	Training Loss: 0.152939 val loss: 0.148749
# saving, val loss enhanced: 0.14874856644661572 0.1531602310999333
# Epoch: 34 	Training Loss: 0.152175 val loss: 0.150404
# Epoch: 35 	Training Loss: 0.150070 val loss: 0.149986
# Epoch: 36 	Training Loss: 0.149708 val loss: 0.148488
# saving, val loss enhanced: 0.1484882871722355 0.14874856644661572
# Epoch: 37 	Training Loss: 0.148282 val loss: 0.147811
# saving, val loss enhanced: 0.1478105767350445 0.1484882871722355
# Epoch: 38 	Training Loss: 0.148583 val loss: 0.148364
# Epoch: 39 	Training Loss: 0.146001 val loss: 0.145210
# saving, val loss enhanced: 0.14520971554504614 0.1478105767350445
# Epoch: 40 	Training Loss: 0.145334 val loss: 0.143045
# saving, val loss enhanced: 0.14304504335872545 0.14520971554504614
# Epoch: 41 	Training Loss: 0.144833 val loss: 0.140908
# saving, val loss enhanced: 0.14090815109800806 0.14304504335872545
# Epoch: 42 	Training Loss: 0.143389 val loss: 0.143704
# Epoch: 43 	Training Loss: 0.144394 val loss: 0.142547
# Epoch: 44 	Training Loss: 0.143341 val loss: 0.140666
# saving, val loss enhanced: 0.14066625558664728 0.14090815109800806
# Epoch: 45 	Training Loss: 0.144082 val loss: 0.145288
# Epoch: 46 	Training Loss: 0.143193 val loss: 0.141436
# Epoch: 47 	Training Loss: 0.143011 val loss: 0.140402
# saving, val loss enhanced: 0.14040209128916262 0.14066625558664728
# Epoch: 48 	Training Loss: 0.141694 val loss: 0.141076
# Epoch: 49 	Training Loss: 0.141403 val loss: 0.142377
# Epoch: 50 	Training Loss: 0.140960 val loss: 0.139604
# saving, val loss enhanced: 0.13960366430379584 0.14040209128916262
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 125.01batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8815.62iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 117.50batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8334.86iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.059957 val loss: 0.069146
# saving, val loss enhanced: 0.0691459614881348 1000000000000000.0
# Epoch: 2 	Training Loss: 0.059870 val loss: 0.069069
# saving, val loss enhanced: 0.06906911470270939 0.0691459614881348
# Epoch: 3 	Training Loss: 0.059784 val loss: 0.068993
# saving, val loss enhanced: 0.06899271068828307 0.06906911470270939
# /workspace/solver_edmd_torch_gpu_sde.py:300: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_file)
# Epoch: 4 	Training Loss: 0.059699 val loss: 0.068917
# saving, val loss enhanced: 0.06891671045620436 0.06899271068828307
# Epoch 1 time: 49.06 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.83batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9120.86iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.058628 val loss: 0.068238
# saving, val loss enhanced: 0.06823753127523194 0.06891671045620436
# Epoch: 2 	Training Loss: 0.058546 val loss: 0.068164
# saving, val loss enhanced: 0.06816379304983453 0.06823753127523194
# Epoch: 3 	Training Loss: 0.058464 val loss: 0.068090
# saving, val loss enhanced: 0.06809028327309256 0.06816379304983453
# Epoch: 4 	Training Loss: 0.058382 val loss: 0.068017
# saving, val loss enhanced: 0.06801701930473923 0.06809028327309256
# Epoch 2 time: 46.09 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.08batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9174.36iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.057679 val loss: 0.067703
# saving, val loss enhanced: 0.06770348597385893 0.06801701930473923
# Epoch: 2 	Training Loss: 0.057599 val loss: 0.067632
# saving, val loss enhanced: 0.06763155816827296 0.06770348597385893
# Epoch: 3 	Training Loss: 0.057520 val loss: 0.067560
# saving, val loss enhanced: 0.06755985414801312 0.06763155816827296
# Epoch: 4 	Training Loss: 0.057441 val loss: 0.067488
# saving, val loss enhanced: 0.06748838389607846 0.06755985414801312
# Epoch 3 time: 46.31 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.92batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9007.70iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.056940 val loss: 0.067393
# saving, val loss enhanced: 0.06739340130440208 0.06748838389607846
# Epoch: 2 	Training Loss: 0.056862 val loss: 0.067323
# saving, val loss enhanced: 0.06732275514043151 0.06739340130440208
# Epoch: 3 	Training Loss: 0.056785 val loss: 0.067252
# saving, val loss enhanced: 0.06725233663813794 0.06732275514043151
# Epoch: 4 	Training Loss: 0.056708 val loss: 0.067182
# saving, val loss enhanced: 0.06718215178163735 0.06725233663813794
# Epoch 4 time: 46.69 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.55batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9166.09iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.056311 val loss: 0.067217
# Epoch: 2 	Training Loss: 0.056235 val loss: 0.067147
# saving, val loss enhanced: 0.06714749851683717 0.06718215178163735
# Epoch: 3 	Training Loss: 0.056159 val loss: 0.067078
# saving, val loss enhanced: 0.0670780623829044 0.06714749851683717
# Epoch: 4 	Training Loss: 0.056084 val loss: 0.067009
# saving, val loss enhanced: 0.06700886087853213 0.0670780623829044
# Epoch 5 time: 47.55 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.52batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9230.49iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.055731 val loss: 0.067117
# Epoch: 2 	Training Loss: 0.055656 val loss: 0.067048
# Epoch: 3 	Training Loss: 0.055582 val loss: 0.066979
# saving, val loss enhanced: 0.06697912906933404 0.06700886087853213
# Epoch: 4 	Training Loss: 0.055508 val loss: 0.066911
# saving, val loss enhanced: 0.06691071137183079 0.06697912906933404
# Epoch 6 time: 46.71 seconds
# (10,)
# [0.99999944 0.99277369 0.85664585 0.59137529 0.55298277 0.37635031
#  0.28616248 0.17892832 0.05786331 0.00735022]
# /workspace/solver_edmd_torch_gpu_sde.py:684: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(self.checkpoint_file)

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.34batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9816.78iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.80batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9354.79iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.77batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9832.71iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 121.76batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9226.32iteration/s]
# Epoch: 1 	Training Loss: 13.830633 val loss: 10.983085
# saving, val loss enhanced: 10.983084791659769 1000000000000000.0
# Epoch: 2 	Training Loss: 13.794341 val loss: 10.958755
# saving, val loss enhanced: 10.958755433416872 10.983084791659769
# /workspace/solver_gedmd_torch_gpu.py:309: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_file)
# Epoch: 3 	Training Loss: 13.758212 val loss: 10.934532
# saving, val loss enhanced: 10.934531874136203 10.958755433416872
# Epoch: 4 	Training Loss: 13.722199 val loss: 10.910413
# saving, val loss enhanced: 10.910412972910056 10.934531874136203
# Epoch 1 time: 111.73 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.44batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9937.80iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.63batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9715.19iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 123.56batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9621.22iteration/s]
# Epoch: 1 	Training Loss: 13.435705 val loss: 10.718224
# saving, val loss enhanced: 10.718224479788695 10.910412972910056
# Epoch: 2 	Training Loss: 13.401872 val loss: 10.695484
# saving, val loss enhanced: 10.695484454177157 10.718224479788695
# Epoch: 3 	Training Loss: 13.368108 val loss: 10.672761
# saving, val loss enhanced: 10.672761196889805 10.695484454177157
# Epoch: 4 	Training Loss: 13.334386 val loss: 10.650071
# saving, val loss enhanced: 10.650070585154722 10.672761196889805
# Epoch 2 time: 109.23 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.06batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9930.35iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.51batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10080.51iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 122.22batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8668.59iteration/s]
# Epoch: 1 	Training Loss: 13.065560 val loss: 10.469316
# saving, val loss enhanced: 10.469315541464814 10.650070585154722
# Epoch: 2 	Training Loss: 13.033718 val loss: 10.447822
# saving, val loss enhanced: 10.447821801318467 10.469315541464814
# Epoch: 3 	Training Loss: 13.001938 val loss: 10.426334
# saving, val loss enhanced: 10.42633420174758 10.447821801318467
# Epoch: 4 	Training Loss: 12.970180 val loss: 10.404861
# saving, val loss enhanced: 10.404861093042534 10.42633420174758
# Epoch 3 time: 109.83 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.00batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10026.66iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.66batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9821.17iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 122.87batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9273.94iteration/s]
# Epoch: 1 	Training Loss: 12.714634 val loss: 10.232599
# saving, val loss enhanced: 10.23259866889014 10.404861093042534
# Epoch: 2 	Training Loss: 12.684540 val loss: 10.212187
# saving, val loss enhanced: 10.212186923419427 10.23259866889014
# Epoch: 3 	Training Loss: 12.654496 val loss: 10.191774
# saving, val loss enhanced: 10.191773723989268 10.212186923419427
# Epoch: 4 	Training Loss: 12.624458 val loss: 10.171364
# saving, val loss enhanced: 10.171363510253686 10.191773723989268
# Epoch 4 time: 110.16 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.75batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10154.93iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.76batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9677.65iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 120.43batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 9126.75iteration/s]
# Epoch: 1 	Training Loss: 12.380551 val loss: 10.006078
# saving, val loss enhanced: 10.006078095488963 10.171363510253686
# Epoch: 2 	Training Loss: 12.352000 val loss: 9.986618
# saving, val loss enhanced: 9.986618328944312 10.006078095488963
# Epoch: 3 	Training Loss: 12.323484 val loss: 9.967150
# saving, val loss enhanced: 9.96714992339161 9.986618328944312
# Epoch: 4 	Training Loss: 12.294961 val loss: 9.947675
# saving, val loss enhanced: 9.94767521954094 9.96714992339161
# Epoch 5 time: 109.60 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 120.58batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10698.63iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 134.37batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9553.69iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 115.36batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8634.02iteration/s]
# Epoch: 1 	Training Loss: 12.061370 val loss: 9.788193
# saving, val loss enhanced: 9.788192808577662 9.94767521954094
# Epoch: 2 	Training Loss: 12.034191 val loss: 9.769581
# saving, val loss enhanced: 9.769581311738555 9.788192808577662
# /workspace/solver_gedmd_torch_gpu.py:696: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(self.checkpoint_file)
# Epoch: 3 	Training Loss: 12.007035 val loss: 9.750955
# saving, val loss enhanced: 9.750955491102125 9.769581311738555
# Epoch: 4 	Training Loss: 11.979860 val loss: 9.732317
# saving, val loss enhanced: 9.732316772036462 9.750955491102125
# Epoch 6 time: 108.32 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:37<00:00, 115.43batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9115.54iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [3.16662529+0.j         2.4939169 -0.35893849j 2.4939169 +0.35893849j
#  1.6628975 -1.1770692j  1.6628975 +1.1770692j  1.45435709-0.34774155j
#  1.45435709+0.34774155j 1.06632001+0.j         1.00051513+0.j
#  1.        +0.j        ]

# %%
#### Test 2 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:18<00:00, 66.61it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 1.186461 val loss: 1.123608
# saving, val loss enhanced: 1.1236078642899432 10000
# Epoch: 2 	Training Loss: 1.086304 val loss: 1.031773
# saving, val loss enhanced: 1.0317727494506592 1.1236078642899432
# Epoch: 3 	Training Loss: 0.992966 val loss: 0.941689
# saving, val loss enhanced: 0.9416886648353748 1.0317727494506592
# Epoch: 4 	Training Loss: 0.898784 val loss: 0.849887
# saving, val loss enhanced: 0.8498872787211356 0.9416886648353748
# Epoch: 5 	Training Loss: 0.810400 val loss: 0.771879
# saving, val loss enhanced: 0.7718792316240858 0.8498872787211356
# Epoch: 6 	Training Loss: 0.733233 val loss: 0.695533
# saving, val loss enhanced: 0.6955330869789151 0.7718792316240858
# Epoch: 7 	Training Loss: 0.661752 val loss: 0.629697
# saving, val loss enhanced: 0.629696935641642 0.6955330869789151
# Epoch: 8 	Training Loss: 0.598804 val loss: 0.569975
# saving, val loss enhanced: 0.5699747838591023 0.629696935641642
# Epoch: 9 	Training Loss: 0.543088 val loss: 0.517784
# saving, val loss enhanced: 0.5177835491971735 0.5699747838591023
# Epoch: 10 	Training Loss: 0.492693 val loss: 0.473086
# saving, val loss enhanced: 0.4730857585308551 0.5177835491971735
# Epoch: 11 	Training Loss: 0.447740 val loss: 0.428992
# saving, val loss enhanced: 0.42899201655286656 0.4730857585308551
# Epoch: 12 	Training Loss: 0.407347 val loss: 0.391639
# saving, val loss enhanced: 0.391639196148806 0.42899201655286656
# Epoch: 13 	Training Loss: 0.371964 val loss: 0.356981
# saving, val loss enhanced: 0.3569806771993496 0.391639196148806
# Epoch: 14 	Training Loss: 0.341130 val loss: 0.328225
# saving, val loss enhanced: 0.32822484869503893 0.3569806771993496
# Epoch: 15 	Training Loss: 0.311908 val loss: 0.303666
# saving, val loss enhanced: 0.3036657011872412 0.32822484869503893
# Epoch: 16 	Training Loss: 0.287096 val loss: 0.278615
# saving, val loss enhanced: 0.27861501720269943 0.3036657011872412
# Epoch: 17 	Training Loss: 0.265845 val loss: 0.255938
# saving, val loss enhanced: 0.25593784486600407 0.27861501720269943
# Epoch: 18 	Training Loss: 0.247471 val loss: 0.239024
# saving, val loss enhanced: 0.2390238175978194 0.25593784486600407
# Epoch: 19 	Training Loss: 0.230351 val loss: 0.223350
# saving, val loss enhanced: 0.22334975552930822 0.2390238175978194
# Epoch: 20 	Training Loss: 0.217273 val loss: 0.212557
# saving, val loss enhanced: 0.2125565448914493 0.22334975552930822
# Epoch: 21 	Training Loss: 0.203755 val loss: 0.199025
# saving, val loss enhanced: 0.19902532132396217 0.2125565448914493
# Epoch: 22 	Training Loss: 0.195599 val loss: 0.190892
# saving, val loss enhanced: 0.19089241645760188 0.19902532132396217
# Epoch: 23 	Training Loss: 0.186320 val loss: 0.179918
# saving, val loss enhanced: 0.1799181250812753 0.19089241645760188
# Epoch: 24 	Training Loss: 0.179303 val loss: 0.174142
# saving, val loss enhanced: 0.1741418888919363 0.1799181250812753
# Epoch: 25 	Training Loss: 0.171497 val loss: 0.168123
# saving, val loss enhanced: 0.16812314472605847 0.1741418888919363
# Epoch: 26 	Training Loss: 0.166387 val loss: 0.158528
# saving, val loss enhanced: 0.158527741691235 0.16812314472605847
# Epoch: 27 	Training Loss: 0.162807 val loss: 0.155386
# saving, val loss enhanced: 0.15538570199857588 0.158527741691235
# Epoch: 28 	Training Loss: 0.158656 val loss: 0.155474
# Epoch: 29 	Training Loss: 0.156499 val loss: 0.148092
# saving, val loss enhanced: 0.14809198133503265 0.15538570199857588
# Epoch: 30 	Training Loss: 0.151798 val loss: 0.146555
# saving, val loss enhanced: 0.14655526298139834 0.14809198133503265
# Epoch: 31 	Training Loss: 0.149301 val loss: 0.143216
# saving, val loss enhanced: 0.14321597658861174 0.14655526298139834
# Epoch: 32 	Training Loss: 0.147838 val loss: 0.141091
# saving, val loss enhanced: 0.14109121375887132 0.14321597658861174
# Epoch: 33 	Training Loss: 0.146524 val loss: 0.140489
# saving, val loss enhanced: 0.14048942392865565 0.14109121375887132
# Epoch: 34 	Training Loss: 0.144341 val loss: 0.136948
# saving, val loss enhanced: 0.13694764363333065 0.14048942392865565
# Epoch: 35 	Training Loss: 0.142188 val loss: 0.137020
# Epoch: 36 	Training Loss: 0.141794 val loss: 0.131719
# saving, val loss enhanced: 0.13171944475924494 0.13694764363333065
# Epoch: 37 	Training Loss: 0.142408 val loss: 0.130286
# saving, val loss enhanced: 0.1302861651812645 0.13171944475924494
# Epoch: 38 	Training Loss: 0.139459 val loss: 0.133593
# Epoch: 39 	Training Loss: 0.139179 val loss: 0.135208
# Epoch: 40 	Training Loss: 0.140272 val loss: 0.132092
# Epoch: 41 	Training Loss: 0.140601 val loss: 0.131298
# Epoch: 42 	Training Loss: 0.137937 val loss: 0.130922
# Epoch: 43 	Training Loss: 0.138239 val loss: 0.129866
# saving, val loss enhanced: 0.12986564341859144 0.1302861651812645
# Epoch: 44 	Training Loss: 0.139017 val loss: 0.131187
# Epoch: 45 	Training Loss: 0.139325 val loss: 0.129239
# saving, val loss enhanced: 0.12923879290511203 0.12986564341859144
# Epoch: 46 	Training Loss: 0.137991 val loss: 0.131325
# Epoch: 47 	Training Loss: 0.136807 val loss: 0.131024
# Epoch: 48 	Training Loss: 0.136929 val loss: 0.128810
# saving, val loss enhanced: 0.12880970168087802 0.12923879290511203
# Epoch: 49 	Training Loss: 0.136674 val loss: 0.126640
# saving, val loss enhanced: 0.1266402361123108 0.12880970168087802
# Epoch: 50 	Training Loss: 0.136325 val loss: 0.126752
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 117.20batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8477.84iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:37<00:00, 113.99batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8530.09iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.800461 val loss: 0.784643
# saving, val loss enhanced: 0.7846427707364422 1000000000000000.0
# Epoch: 2 	Training Loss: 0.798095 val loss: 0.782850
# saving, val loss enhanced: 0.7828502867355696 0.7846427707364422
# Epoch: 3 	Training Loss: 0.795730 val loss: 0.781059
# saving, val loss enhanced: 0.7810592120657445 0.7828502867355696
# Epoch: 4 	Training Loss: 0.793365 val loss: 0.779272
# saving, val loss enhanced: 0.7792719822299573 0.7810592120657445
# Epoch 1 time: 50.09 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.40batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9360.20iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.926683 val loss: 0.894582
# Epoch: 2 	Training Loss: 0.923681 val loss: 0.892347
# Epoch: 3 	Training Loss: 0.920724 val loss: 0.890156
# Epoch: 4 	Training Loss: 0.917818 val loss: 0.887997
# Epoch 2 time: 47.45 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.38batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8704.09iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.107463 val loss: 1.050435
# Epoch: 2 	Training Loss: 1.103607 val loss: 1.047591
# Epoch: 3 	Training Loss: 1.099825 val loss: 1.044819
# Epoch: 4 	Training Loss: 1.096133 val loss: 1.042106
# Epoch 3 time: 48.61 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.60batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9633.04iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.371456 val loss: 1.275560
# Epoch: 2 	Training Loss: 1.366291 val loss: 1.271782
# Epoch: 3 	Training Loss: 1.361251 val loss: 1.268125
# Epoch: 4 	Training Loss: 1.356366 val loss: 1.264568
# Epoch 4 time: 46.19 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.29batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8210.51iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.759761 val loss: 1.603191
# Epoch: 2 	Training Loss: 1.752584 val loss: 1.597985
# Epoch: 3 	Training Loss: 1.745627 val loss: 1.592982
# Epoch: 4 	Training Loss: 1.738931 val loss: 1.588150
# Epoch 5 time: 50.06 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:37<00:00, 114.76batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8621.18iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 2.320168 val loss: 2.070211
# Epoch: 2 	Training Loss: 2.310038 val loss: 2.062925
# Epoch: 3 	Training Loss: 2.300283 val loss: 2.055973
# Epoch: 4 	Training Loss: 2.290959 val loss: 2.049300
# Epoch 6 time: 49.71 seconds
# (10,)
# [9.99999135e-01 9.93172638e-01 8.92089359e-01 5.66746141e-01
#  5.42917169e-01 3.56299769e-01 2.91276751e-01 5.12600786e-02
#  1.30096948e-02 6.28932945e-04]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 117.64batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10360.91iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.55batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9729.40iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 120.97batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9583.22iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 126.31batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 10161.97iteration/s]
# Epoch: 1 	Training Loss: 35.049022 val loss: 27.308054
# saving, val loss enhanced: 27.30805430763404 1000000000000000.0
# Epoch: 2 	Training Loss: 34.995203 val loss: 27.267477
# saving, val loss enhanced: 27.267476596411782 27.30805430763404
# Epoch: 3 	Training Loss: 34.941570 val loss: 27.227044
# saving, val loss enhanced: 27.227043701354194 27.267476596411782
# Epoch: 4 	Training Loss: 34.888032 val loss: 27.186739
# saving, val loss enhanced: 27.186738911879193 27.227043701354194
# Epoch 1 time: 109.71 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.75batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9441.83iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 126.27batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10547.16iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:13<00:00, 132.25batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 10593.67iteration/s]
# Epoch: 1 	Training Loss: 34.845890 val loss: 27.183407
# saving, val loss enhanced: 27.183406642481067 27.186738911879193
# Epoch: 2 	Training Loss: 34.795295 val loss: 27.145134
# saving, val loss enhanced: 27.14513371162892 27.183406642481067
# Epoch: 3 	Training Loss: 34.744753 val loss: 27.106880
# saving, val loss enhanced: 27.106879884904416 27.14513371162892
# Epoch: 4 	Training Loss: 34.694217 val loss: 27.068662
# saving, val loss enhanced: 27.068661877513676 27.106879884904416
# Epoch 2 time: 109.00 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.49batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8994.60iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:37<00:00, 114.51batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8868.38iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 120.08batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 9010.52iteration/s]
# Epoch: 1 	Training Loss: 34.669616 val loss: 27.050980
# saving, val loss enhanced: 27.050979924364604 27.068661877513676
# Epoch: 2 	Training Loss: 34.621716 val loss: 27.014631
# saving, val loss enhanced: 27.014631392664306 27.050979924364604
# Epoch: 3 	Training Loss: 34.573883 val loss: 26.978296
# saving, val loss enhanced: 26.978295888640275 27.014631392664306
# Epoch: 4 	Training Loss: 34.526049 val loss: 26.941981
# saving, val loss enhanced: 26.941981033675702 26.978295888640275
# Epoch 3 time: 116.11 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 135.79batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9283.51iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.54batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9504.62iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:13<00:00, 139.67batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9323.93iteration/s]
# Epoch: 1 	Training Loss: 34.517500 val loss: 26.921881
# saving, val loss enhanced: 26.92188057182892 26.941981033675702
# Epoch: 2 	Training Loss: 34.472107 val loss: 26.887307
# saving, val loss enhanced: 26.88730664422683 26.92188057182892
# Epoch: 3 	Training Loss: 34.426779 val loss: 26.852741
# saving, val loss enhanced: 26.85274089139452 26.88730664422683
# Epoch: 4 	Training Loss: 34.381445 val loss: 26.818186
# saving, val loss enhanced: 26.81818590920813 26.85274089139452
# Epoch 4 time: 105.73 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.29batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9474.98iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.29batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9512.74iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:16<00:00, 111.75batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8914.53iteration/s]
# Epoch: 1 	Training Loss: 34.379600 val loss: 26.803288
# saving, val loss enhanced: 26.80328842303762 26.81818590920813
# Epoch: 2 	Training Loss: 34.336556 val loss: 26.770367
# saving, val loss enhanced: 26.770366565845016 26.80328842303762
# Epoch: 3 	Training Loss: 34.293571 val loss: 26.737448
# saving, val loss enhanced: 26.737447762514872 26.770366565845016
# Epoch: 4 	Training Loss: 34.250573 val loss: 26.704532
# saving, val loss enhanced: 26.704532177420056 26.737447762514872
# Epoch 5 time: 114.43 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.04batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9421.91iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.92batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10399.81iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:16<00:00, 113.45batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8840.04iteration/s]
# Epoch: 1 	Training Loss: 34.248422 val loss: 26.694507
# saving, val loss enhanced: 26.69450738377686 26.704532177420056
# Epoch: 2 	Training Loss: 34.207587 val loss: 26.663131
# saving, val loss enhanced: 26.663131075194126 26.69450738377686
# Epoch: 3 	Training Loss: 34.166803 val loss: 26.631753
# saving, val loss enhanced: 26.63175285154069 26.663131075194126
# Epoch: 4 	Training Loss: 34.126001 val loss: 26.600372
# saving, val loss enhanced: 26.600371616360498 26.63175285154069
# Epoch 6 time: 112.21 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.16batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9431.72iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [2.66709929+0.j         1.72405752+0.j         1.22505611-1.01870507j
#  1.22505611+1.01870507j 1.18518999+0.j         1.01382263+0.j
#  1.00158378+0.j         1.        +0.j         0.80222604+0.14384447j
#  0.80222604-0.14384447j]

# %%
#### Test 3 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:18<00:00, 64.88it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 1.132557 val loss: 1.078838
# saving, val loss enhanced: 1.078837898517305 10000
# Epoch: 2 	Training Loss: 1.051206 val loss: 1.004321
# saving, val loss enhanced: 1.0043212129869143 1.078837898517305
# Epoch: 3 	Training Loss: 0.975863 val loss: 0.936412
# saving, val loss enhanced: 0.9364116885246674 1.0043212129869143
# Epoch: 4 	Training Loss: 0.909437 val loss: 0.872205
# saving, val loss enhanced: 0.8722053003057765 0.9364116885246674
# Epoch: 5 	Training Loss: 0.850241 val loss: 0.816216
# saving, val loss enhanced: 0.8162159754490989 0.8722053003057765
# Epoch: 6 	Training Loss: 0.794104 val loss: 0.760563
# saving, val loss enhanced: 0.7605628747175901 0.8162159754490989
# Epoch: 7 	Training Loss: 0.742638 val loss: 0.715114
# saving, val loss enhanced: 0.7151136936415508 0.7605628747175901
# Epoch: 8 	Training Loss: 0.699599 val loss: 0.672145
# saving, val loss enhanced: 0.6721453747827645 0.7151136936415508
# Epoch: 9 	Training Loss: 0.658791 val loss: 0.632778
# saving, val loss enhanced: 0.632778488340391 0.6721453747827645
# Epoch: 10 	Training Loss: 0.620023 val loss: 0.598554
# saving, val loss enhanced: 0.5985542187442988 0.632778488340391
# Epoch: 11 	Training Loss: 0.586220 val loss: 0.567781
# saving, val loss enhanced: 0.5677807496911808 0.5985542187442988
# Epoch: 12 	Training Loss: 0.555370 val loss: 0.536598
# saving, val loss enhanced: 0.5365976687100079 0.5677807496911808
# Epoch: 13 	Training Loss: 0.527900 val loss: 0.510124
# saving, val loss enhanced: 0.5101243656132796 0.5365976687100079
# Epoch: 14 	Training Loss: 0.502430 val loss: 0.489078
# saving, val loss enhanced: 0.48907782097884556 0.5101243656132796
# Epoch: 15 	Training Loss: 0.477783 val loss: 0.465957
# saving, val loss enhanced: 0.4659566076184018 0.48907782097884556
# Epoch: 16 	Training Loss: 0.457382 val loss: 0.444736
# saving, val loss enhanced: 0.44473557762822424 0.4659566076184018
# Epoch: 17 	Training Loss: 0.437188 val loss: 0.429281
# saving, val loss enhanced: 0.42928112326503326 0.44473557762822424
# Epoch: 18 	Training Loss: 0.417731 val loss: 0.410796
# saving, val loss enhanced: 0.41079612495030005 0.42928112326503326
# Epoch: 19 	Training Loss: 0.401445 val loss: 0.394148
# saving, val loss enhanced: 0.3941482505918751 0.41079612495030005
# Epoch: 20 	Training Loss: 0.382748 val loss: 0.378547
# saving, val loss enhanced: 0.37854731664555563 0.3941482505918751
# Epoch: 21 	Training Loss: 0.368593 val loss: 0.363885
# saving, val loss enhanced: 0.36388518294572797 0.37854731664555563
# Epoch: 22 	Training Loss: 0.353949 val loss: 0.349440
# saving, val loss enhanced: 0.3494399862937993 0.36388518294572797
# Epoch: 23 	Training Loss: 0.340172 val loss: 0.336926
# saving, val loss enhanced: 0.336926396060877 0.3494399862937993
# Epoch: 24 	Training Loss: 0.327216 val loss: 0.325294
# saving, val loss enhanced: 0.32529434914812266 0.336926396060877
# Epoch: 25 	Training Loss: 0.314279 val loss: 0.313983
# saving, val loss enhanced: 0.3139826410795705 0.32529434914812266
# Epoch: 26 	Training Loss: 0.302818 val loss: 0.301444
# saving, val loss enhanced: 0.3014435455080527 0.3139826410795705
# Epoch: 27 	Training Loss: 0.292348 val loss: 0.291915
# saving, val loss enhanced: 0.2919150792429684 0.3014435455080527
# Epoch: 28 	Training Loss: 0.283025 val loss: 0.284362
# saving, val loss enhanced: 0.28436238027254856 0.2919150792429684
# Epoch: 29 	Training Loss: 0.272805 val loss: 0.275091
# saving, val loss enhanced: 0.27509138194923277 0.28436238027254856
# Epoch: 30 	Training Loss: 0.264487 val loss: 0.267751
# saving, val loss enhanced: 0.26775088691918986 0.27509138194923277
# Epoch: 31 	Training Loss: 0.256969 val loss: 0.261333
# saving, val loss enhanced: 0.26133348104930254 0.26775088691918986
# Epoch: 32 	Training Loss: 0.249610 val loss: 0.254449
# saving, val loss enhanced: 0.2544486443018539 0.26133348104930254
# Epoch: 33 	Training Loss: 0.244580 val loss: 0.249254
# saving, val loss enhanced: 0.2492544821479795 0.2544486443018539
# Epoch: 34 	Training Loss: 0.237209 val loss: 0.243303
# saving, val loss enhanced: 0.24330298953038262 0.2492544821479795
# Epoch: 35 	Training Loss: 0.232697 val loss: 0.239755
# saving, val loss enhanced: 0.23975528991938566 0.24330298953038262
# Epoch: 36 	Training Loss: 0.227548 val loss: 0.234435
# saving, val loss enhanced: 0.23443494796891431 0.23975528991938566
# Epoch: 37 	Training Loss: 0.222691 val loss: 0.230166
# saving, val loss enhanced: 0.230165602972589 0.23443494796891431
# Epoch: 38 	Training Loss: 0.218361 val loss: 0.226799
# saving, val loss enhanced: 0.2267990758472902 0.230165602972589
# Epoch: 39 	Training Loss: 0.214169 val loss: 0.225342
# saving, val loss enhanced: 0.22534193312872508 0.2267990758472902
# Epoch: 40 	Training Loss: 0.212120 val loss: 0.220368
# saving, val loss enhanced: 0.22036794286319147 0.22534193312872508
# Epoch: 41 	Training Loss: 0.209287 val loss: 0.218442
# saving, val loss enhanced: 0.21844220331192288 0.22036794286319147
# Epoch: 42 	Training Loss: 0.205926 val loss: 0.213054
# saving, val loss enhanced: 0.213053513669506 0.21844220331192288
# Epoch: 43 	Training Loss: 0.201771 val loss: 0.211804
# saving, val loss enhanced: 0.21180384815434783 0.213053513669506
# Epoch: 44 	Training Loss: 0.201284 val loss: 0.211003
# saving, val loss enhanced: 0.21100345063998782 0.21180384815434783
# Epoch: 45 	Training Loss: 0.198013 val loss: 0.211643
# Epoch: 46 	Training Loss: 0.194975 val loss: 0.204171
# saving, val loss enhanced: 0.20417092326315944 0.21100345063998782
# Epoch: 47 	Training Loss: 0.190701 val loss: 0.202494
# saving, val loss enhanced: 0.2024935040106461 0.20417092326315944
# Epoch: 48 	Training Loss: 0.188499 val loss: 0.200573
# saving, val loss enhanced: 0.20057303273457402 0.2024935040106461
# Epoch: 49 	Training Loss: 0.186452 val loss: 0.197416
# saving, val loss enhanced: 0.19741555194647367 0.20057303273457402
# Epoch: 50 	Training Loss: 0.183302 val loss: 0.194068
# saving, val loss enhanced: 0.19406818970718198 0.19741555194647367
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 120.79batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8685.14iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 125.96batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8802.35iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.107124 val loss: 0.131506
# saving, val loss enhanced: 0.13150619673983738 1000000000000000.0
# Epoch: 2 	Training Loss: 0.106891 val loss: 0.131336
# saving, val loss enhanced: 0.13133644966965927 0.13150619673983738
# Epoch: 3 	Training Loss: 0.106660 val loss: 0.131168
# saving, val loss enhanced: 0.13116828205888836 0.13133644966965927
# Epoch: 4 	Training Loss: 0.106430 val loss: 0.131001
# saving, val loss enhanced: 0.13100133545658407 0.13116828205888836
# Epoch 1 time: 46.24 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.18batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8727.05iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.101535 val loss: 0.126409
# saving, val loss enhanced: 0.12640902152704758 0.13100133545658407
# Epoch: 2 	Training Loss: 0.101324 val loss: 0.126245
# saving, val loss enhanced: 0.12624454134463398 0.12640902152704758
# Epoch: 3 	Training Loss: 0.101113 val loss: 0.126081
# saving, val loss enhanced: 0.12608052709336343 0.12624454134463398
# Epoch: 4 	Training Loss: 0.100902 val loss: 0.125917
# saving, val loss enhanced: 0.1259170510702815 0.12608052709336343
# Epoch 2 time: 47.01 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.18batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8658.00iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.096190 val loss: 0.122752
# saving, val loss enhanced: 0.12275192211206348 0.1259170510702815
# Epoch: 2 	Training Loss: 0.096005 val loss: 0.122592
# saving, val loss enhanced: 0.12259196512250337 0.12275192211206348
# Epoch: 3 	Training Loss: 0.095819 val loss: 0.122432
# saving, val loss enhanced: 0.12243232088509078 0.12259196512250337
# Epoch: 4 	Training Loss: 0.095634 val loss: 0.122273
# saving, val loss enhanced: 0.12227302511224793 0.12243232088509078
# Epoch 3 time: 47.61 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.65batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8696.09iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.091721 val loss: 0.121221
# saving, val loss enhanced: 0.12122053114926801 0.12227302511224793
# Epoch: 2 	Training Loss: 0.091565 val loss: 0.121065
# saving, val loss enhanced: 0.1210650904306742 0.12122053114926801
# Epoch: 3 	Training Loss: 0.091408 val loss: 0.120910
# saving, val loss enhanced: 0.12091012396109728 0.1210650904306742
# Epoch: 4 	Training Loss: 0.091252 val loss: 0.120756
# saving, val loss enhanced: 0.12075558266126526 0.12091012396109728
# Epoch 4 time: 47.06 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.62batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9941.91iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.089034 val loss: 0.122559
# Epoch: 2 	Training Loss: 0.088901 val loss: 0.122406
# Epoch: 3 	Training Loss: 0.088768 val loss: 0.122254
# Epoch: 4 	Training Loss: 0.088636 val loss: 0.122104
# Epoch 5 time: 46.18 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 125.78batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9021.98iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.089232 val loss: 0.127274
# Epoch: 2 	Training Loss: 0.089101 val loss: 0.127120
# Epoch: 3 	Training Loss: 0.088971 val loss: 0.126968
# Epoch: 4 	Training Loss: 0.088844 val loss: 0.126818
# Epoch 6 time: 45.99 seconds
# (10,)
# [1.00000083 0.99359029 0.86772991 0.53197923 0.50572429 0.33542147
#  0.28007541 0.06891429 0.01415766 0.00221732]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 128.66batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 10866.09iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.49batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9561.36iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.68batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9484.36iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 122.33batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 9145.10iteration/s]
# Epoch: 1 	Training Loss: 9.924473 val loss: 14.202743
# saving, val loss enhanced: 14.202742742085846 1000000000000000.0
# Epoch: 2 	Training Loss: 9.893575 val loss: 14.177190
# saving, val loss enhanced: 14.177189625512964 14.202742742085846
# Epoch: 3 	Training Loss: 9.862962 val loss: 14.151861
# saving, val loss enhanced: 14.151861345654526 14.177189625512964
# Epoch: 4 	Training Loss: 9.832469 val loss: 14.126691
# saving, val loss enhanced: 14.126691343744099 14.151861345654526
# Epoch 1 time: 110.65 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.24batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9442.23iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.64batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10150.03iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 122.75batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 11347.66iteration/s]
# Epoch: 1 	Training Loss: 9.590188 val loss: 13.362061
# saving, val loss enhanced: 13.362061259239887 14.126691343744099
# Epoch: 2 	Training Loss: 9.561613 val loss: 13.339093
# saving, val loss enhanced: 13.339093320779615 13.362061259239887
# Epoch: 3 	Training Loss: 9.533094 val loss: 13.316108
# saving, val loss enhanced: 13.316107761806256 13.339093320779615
# Epoch: 4 	Training Loss: 9.504606 val loss: 13.293120
# saving, val loss enhanced: 13.293119922214522 13.316107761806256
# Epoch 2 time: 108.66 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 125.47batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10622.92iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.74batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10445.58iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 123.01batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 9050.05iteration/s]
# Epoch: 1 	Training Loss: 9.279010 val loss: 12.598584
# saving, val loss enhanced: 12.598584071197568 13.293119922214522
# Epoch: 2 	Training Loss: 9.252187 val loss: 12.577389
# saving, val loss enhanced: 12.577388625292564 12.598584071197568
# Epoch: 3 	Training Loss: 9.225418 val loss: 12.556163
# saving, val loss enhanced: 12.556163451466196 12.577388625292564
# Epoch: 4 	Training Loss: 9.198666 val loss: 12.534916
# saving, val loss enhanced: 12.534915550661974 12.556163451466196
# Epoch 3 time: 108.47 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.76batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9712.31iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 129.44batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9978.17iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:16<00:00, 111.21batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9325.96iteration/s]
# Epoch: 1 	Training Loss: 8.984876 val loss: 11.898342
# saving, val loss enhanced: 11.898341622079622 12.534915550661974
# Epoch: 2 	Training Loss: 8.959631 val loss: 11.878634
# saving, val loss enhanced: 11.87863380323669 11.898341622079622
# Epoch: 3 	Training Loss: 8.934435 val loss: 11.858894
# saving, val loss enhanced: 11.85889406857039 11.87863380323669
# Epoch: 4 	Training Loss: 8.909247 val loss: 11.839125
# saving, val loss enhanced: 11.839125107267513 11.85889406857039
# Epoch 4 time: 109.08 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.47batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9627.59iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.48batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9534.03iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 128.84batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8856.48iteration/s]
# Epoch: 1 	Training Loss: 8.706743 val loss: 11.257188
# saving, val loss enhanced: 11.257187644130646 11.839125107267513
# Epoch: 2 	Training Loss: 8.682932 val loss: 11.238772
# saving, val loss enhanced: 11.238771981148876 11.257187644130646
# Epoch: 3 	Training Loss: 8.659163 val loss: 11.220324
# saving, val loss enhanced: 11.22032380230826 11.238771981148876
# Epoch: 4 	Training Loss: 8.635396 val loss: 11.201844
# saving, val loss enhanced: 11.201843649389117 11.22032380230826
# Epoch 5 time: 110.61 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.09batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9592.37iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.42batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9797.71iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 123.47batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 11345.97iteration/s]
# Epoch: 1 	Training Loss: 8.444034 val loss: 10.672228
# saving, val loss enhanced: 10.672227504368172 11.201843649389117
# Epoch: 2 	Training Loss: 8.421536 val loss: 10.654959
# saving, val loss enhanced: 10.65495936578698 10.672227504368172
# Epoch: 3 	Training Loss: 8.399073 val loss: 10.637659
# saving, val loss enhanced: 10.637658776251081 10.65495936578698
# Epoch: 4 	Training Loss: 8.376607 val loss: 10.620325
# saving, val loss enhanced: 10.620325157204832 10.637658776251081
# Epoch 6 time: 108.74 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.80batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 10905.34iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [1.65101004-1.21569113j 1.65101004+1.21569113j 1.95954368+0.j
#  1.0406348 +0.j         1.03633674-0.06829155j 1.03633674+0.06829155j
#  1.        +0.j         0.69734629+0.j         0.46880817-0.41270431j
#  0.46880817+0.41270431j]

# %%
#### Test 4 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:17<00:00, 70.30it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 0.863103 val loss: 0.854943
# saving, val loss enhanced: 0.8549430182057186 10000
# Epoch: 2 	Training Loss: 0.804071 val loss: 0.800815
# saving, val loss enhanced: 0.8008153878301072 0.8549430182057186
# Epoch: 3 	Training Loss: 0.752494 val loss: 0.749177
# saving, val loss enhanced: 0.7491770145725255 0.8008153878301072
# Epoch: 4 	Training Loss: 0.705751 val loss: 0.704308
# saving, val loss enhanced: 0.7043079737845298 0.7491770145725255
# Epoch: 5 	Training Loss: 0.661470 val loss: 0.659622
# saving, val loss enhanced: 0.6596219986662087 0.7043079737845298
# Epoch: 6 	Training Loss: 0.622154 val loss: 0.620948
# saving, val loss enhanced: 0.6209479099968191 0.6596219986662087
# Epoch: 7 	Training Loss: 0.585882 val loss: 0.584969
# saving, val loss enhanced: 0.5849689707962324 0.6209479099968191
# Epoch: 8 	Training Loss: 0.552856 val loss: 0.552066
# saving, val loss enhanced: 0.5520655357352784 0.5849689707962324
# Epoch: 9 	Training Loss: 0.521150 val loss: 0.522042
# saving, val loss enhanced: 0.5220420524017589 0.5520655357352784
# Epoch: 10 	Training Loss: 0.493026 val loss: 0.496162
# saving, val loss enhanced: 0.496162174013623 0.5220420524017589
# Epoch: 11 	Training Loss: 0.466603 val loss: 0.466246
# saving, val loss enhanced: 0.4662455532060517 0.496162174013623
# Epoch: 12 	Training Loss: 0.441784 val loss: 0.442911
# saving, val loss enhanced: 0.442910520236569 0.4662455532060517
# Epoch: 13 	Training Loss: 0.417854 val loss: 0.420463
# saving, val loss enhanced: 0.4204630758939243 0.442910520236569
# Epoch: 14 	Training Loss: 0.396194 val loss: 0.397397
# saving, val loss enhanced: 0.39739727713217654 0.4204630758939243
# Epoch: 15 	Training Loss: 0.376756 val loss: 0.375267
# saving, val loss enhanced: 0.3752668548098833 0.39739727713217654
# Epoch: 16 	Training Loss: 0.356885 val loss: 0.356986
# saving, val loss enhanced: 0.35698567931115877 0.3752668548098833
# Epoch: 17 	Training Loss: 0.339459 val loss: 0.338153
# saving, val loss enhanced: 0.338152890194421 0.35698567931115877
# Epoch: 18 	Training Loss: 0.321978 val loss: 0.322816
# saving, val loss enhanced: 0.3228155678615585 0.338152890194421
# Epoch: 19 	Training Loss: 0.305330 val loss: 0.306693
# saving, val loss enhanced: 0.30669287102955683 0.3228155678615585
# Epoch: 20 	Training Loss: 0.291646 val loss: 0.289477
# saving, val loss enhanced: 0.28947676338396106 0.30669287102955683
# Epoch: 21 	Training Loss: 0.276559 val loss: 0.277540
# saving, val loss enhanced: 0.2775396554410554 0.28947676338396106
# Epoch: 22 	Training Loss: 0.263838 val loss: 0.260448
# saving, val loss enhanced: 0.2604479490886255 0.2775396554410554
# Epoch: 23 	Training Loss: 0.250552 val loss: 0.249475
# saving, val loss enhanced: 0.24947511599938255 0.2604479490886255
# Epoch: 24 	Training Loss: 0.238108 val loss: 0.236635
# saving, val loss enhanced: 0.23663479394210296 0.24947511599938255
# Epoch: 25 	Training Loss: 0.226860 val loss: 0.224027
# saving, val loss enhanced: 0.22402674166497621 0.23663479394210296
# Epoch: 26 	Training Loss: 0.214767 val loss: 0.211428
# saving, val loss enhanced: 0.21142781662228197 0.22402674166497621
# Epoch: 27 	Training Loss: 0.205317 val loss: 0.200481
# saving, val loss enhanced: 0.20048118381997476 0.21142781662228197
# Epoch: 28 	Training Loss: 0.197087 val loss: 0.189907
# saving, val loss enhanced: 0.18990667612339562 0.20048118381997476
# Epoch: 29 	Training Loss: 0.188999 val loss: 0.187473
# saving, val loss enhanced: 0.18747282434430468 0.18990667612339562
# Epoch: 30 	Training Loss: 0.181467 val loss: 0.174845
# saving, val loss enhanced: 0.17484510007768836 0.18747282434430468
# Epoch: 31 	Training Loss: 0.175337 val loss: 0.169412
# saving, val loss enhanced: 0.16941193194091783 0.17484510007768836
# Epoch: 32 	Training Loss: 0.168917 val loss: 0.162588
# saving, val loss enhanced: 0.1625884558449944 0.16941193194091783
# Epoch: 33 	Training Loss: 0.165366 val loss: 0.158106
# saving, val loss enhanced: 0.15810589541545453 0.1625884558449944
# Epoch: 34 	Training Loss: 0.160920 val loss: 0.152924
# saving, val loss enhanced: 0.15292447969267034 0.15810589541545453
# Epoch: 35 	Training Loss: 0.157232 val loss: 0.149104
# saving, val loss enhanced: 0.14910442082729428 0.15292447969267034
# Epoch: 36 	Training Loss: 0.155378 val loss: 0.145438
# saving, val loss enhanced: 0.14543763703598414 0.14910442082729428
# Epoch: 37 	Training Loss: 0.153528 val loss: 0.145270
# saving, val loss enhanced: 0.14527044151676086 0.14543763703598414
# Epoch: 38 	Training Loss: 0.149976 val loss: 0.148555
# Epoch: 39 	Training Loss: 0.148778 val loss: 0.142047
# saving, val loss enhanced: 0.14204743052707847 0.14527044151676086
# Epoch: 40 	Training Loss: 0.148388 val loss: 0.140415
# saving, val loss enhanced: 0.14041485756137265 0.14204743052707847
# Epoch: 41 	Training Loss: 0.148004 val loss: 0.140869
# Epoch: 42 	Training Loss: 0.147184 val loss: 0.135333
# saving, val loss enhanced: 0.13533276779077116 0.14041485756137265
# Epoch: 43 	Training Loss: 0.144757 val loss: 0.136759
# Epoch: 44 	Training Loss: 0.145343 val loss: 0.140230
# Epoch: 45 	Training Loss: 0.145484 val loss: 0.138033
# Epoch: 46 	Training Loss: 0.143666 val loss: 0.137316
# Epoch: 47 	Training Loss: 0.145751 val loss: 0.134424
# saving, val loss enhanced: 0.13442425563095714 0.13533276779077116
# Epoch: 48 	Training Loss: 0.145128 val loss: 0.135804
# Epoch: 49 	Training Loss: 0.143278 val loss: 0.132701
# saving, val loss enhanced: 0.13270069293869272 0.13442425563095714
# Epoch: 50 	Training Loss: 0.143189 val loss: 0.135731
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.25batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8652.08iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.39batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8649.04iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.164066 val loss: 1.367326
# saving, val loss enhanced: 1.3673256106050282 1000000000000000.0
# Epoch: 2 	Training Loss: 1.162760 val loss: 1.366392
# saving, val loss enhanced: 1.3663920019222187 1.3673256106050282
# Epoch: 3 	Training Loss: 1.161457 val loss: 1.365463
# saving, val loss enhanced: 1.365462981300216 1.3663920019222187
# Epoch: 4 	Training Loss: 1.160154 val loss: 1.364538
# saving, val loss enhanced: 1.364537907733458 1.365462981300216
# Epoch 1 time: 47.12 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.46batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9276.15iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.141456 val loss: 1.339175
# saving, val loss enhanced: 1.3391746297891436 1.364537907733458
# Epoch: 2 	Training Loss: 1.140342 val loss: 1.338386
# saving, val loss enhanced: 1.3383859082416585 1.3391746297891436
# Epoch: 3 	Training Loss: 1.139224 val loss: 1.337592
# saving, val loss enhanced: 1.3375923865763 1.3383859082416585
# Epoch: 4 	Training Loss: 1.138098 val loss: 1.336795
# saving, val loss enhanced: 1.3367954129570612 1.3375923865763
# Epoch 2 time: 45.71 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.39batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8792.96iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.123392 val loss: 1.317187
# saving, val loss enhanced: 1.3171873136955168 1.3367954129570612
# Epoch: 2 	Training Loss: 1.122418 val loss: 1.316501
# saving, val loss enhanced: 1.3165007405722675 1.3171873136955168
# Epoch: 3 	Training Loss: 1.121440 val loss: 1.315810
# saving, val loss enhanced: 1.3158097187490634 1.3165007405722675
# Epoch: 4 	Training Loss: 1.120455 val loss: 1.315115
# saving, val loss enhanced: 1.3151147949809334 1.3158097187490634
# Epoch 3 time: 47.19 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.77batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9765.09iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.106556 val loss: 1.298930
# saving, val loss enhanced: 1.298929876113503 1.3151147949809334
# Epoch: 2 	Training Loss: 1.105699 val loss: 1.298330
# saving, val loss enhanced: 1.2983296840546361 1.298929876113503
# Epoch: 3 	Training Loss: 1.104840 val loss: 1.297726
# saving, val loss enhanced: 1.2977255427626095 1.2983296840546361
# Epoch: 4 	Training Loss: 1.103974 val loss: 1.297118
# saving, val loss enhanced: 1.2971176594932228 1.2977255427626095
# Epoch 4 time: 46.75 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.55batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8717.56iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.090393 val loss: 1.284781
# saving, val loss enhanced: 1.284780589370636 1.2971176594932228
# Epoch: 2 	Training Loss: 1.089635 val loss: 1.284254
# saving, val loss enhanced: 1.2842540605620965 1.284780589370636
# Epoch: 3 	Training Loss: 1.088874 val loss: 1.283724
# saving, val loss enhanced: 1.283724019173724 1.2842540605620965
# Epoch: 4 	Training Loss: 1.088108 val loss: 1.283191
# saving, val loss enhanced: 1.2831905312080718 1.283724019173724
# Epoch 5 time: 46.75 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.44batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8789.31iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.074028 val loss: 1.274168
# saving, val loss enhanced: 1.274167583791771 1.2831905312080718
# Epoch: 2 	Training Loss: 1.073353 val loss: 1.273705
# saving, val loss enhanced: 1.2737050756129555 1.274167583791771
# Epoch: 3 	Training Loss: 1.072676 val loss: 1.273239
# saving, val loss enhanced: 1.2732394242636809 1.2737050756129555
# Epoch: 4 	Training Loss: 1.071993 val loss: 1.272771
# saving, val loss enhanced: 1.2727706252219286 1.2732394242636809
# Epoch 6 time: 46.46 seconds
# (10,)
# [1.00000415e+00 9.94084425e-01 8.13445741e-01 5.44144450e-01
#  4.30589374e-01 2.93637673e-01 2.75900276e-01 5.12270491e-02
#  8.85392379e-03 1.42116843e-04]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.77batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 10862.29iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.88batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9538.32iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.60batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9288.04iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 116.76batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8230.80iteration/s]
# Epoch: 1 	Training Loss: 10.533503 val loss: 25.213519
# saving, val loss enhanced: 25.21351852291321 1000000000000000.0
# Epoch: 2 	Training Loss: 10.500080 val loss: 25.149304
# saving, val loss enhanced: 25.14930360141741 25.21351852291321
# Epoch: 3 	Training Loss: 10.467511 val loss: 25.086296
# saving, val loss enhanced: 25.086296215032732 25.14930360141741
# Epoch: 4 	Training Loss: 10.435226 val loss: 25.023973
# saving, val loss enhanced: 25.023973198875623 25.086296215032732
# Epoch 1 time: 114.93 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:38<00:00, 111.81batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9153.73iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:39<00:00, 107.58batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9044.91iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:18<00:00, 101.46batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9186.95iteration/s]
# Epoch: 1 	Training Loss: 10.317165 val loss: 24.681179
# saving, val loss enhanced: 24.681179005966523 25.023973198875623
# Epoch: 2 	Training Loss: 10.286430 val loss: 24.622076
# saving, val loss enhanced: 24.622076098649757 24.681179005966523
# Epoch: 3 	Training Loss: 10.255784 val loss: 24.563136
# saving, val loss enhanced: 24.56313554320794 24.622076098649757
# Epoch: 4 	Training Loss: 10.225203 val loss: 24.504359
# saving, val loss enhanced: 24.50435943245744 24.56313554320794
# Epoch 2 time: 123.03 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 125.04batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8999.92iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 126.91batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10165.64iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:20<00:00, 90.87batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 7783.43iteration/s]
# Epoch: 1 	Training Loss: 10.117320 val loss: 24.171970
# saving, val loss enhanced: 24.171969603123575 24.50435943245744
# Epoch: 2 	Training Loss: 10.088035 val loss: 24.115893
# saving, val loss enhanced: 24.115893158976988 24.171969603123575
# Epoch: 3 	Training Loss: 10.058814 val loss: 24.059890
# saving, val loss enhanced: 24.059890269378695 24.115893158976988
# Epoch: 4 	Training Loss: 10.029630 val loss: 24.003970
# saving, val loss enhanced: 24.003969957158564 24.059890269378695
# Epoch 3 time: 115.64 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:45<00:00, 93.88batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8568.05iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:41<00:00, 103.16batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10223.67iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 124.20batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9503.95iteration/s]
# Epoch: 1 	Training Loss: 9.928400 val loss: 23.679418
# saving, val loss enhanced: 23.679418023210985 24.003969957158564
# Epoch: 2 	Training Loss: 9.900403 val loss: 23.625982
# saving, val loss enhanced: 23.6259815183717 23.679418023210985
# Epoch: 3 	Training Loss: 9.872459 val loss: 23.572587
# saving, val loss enhanced: 23.57258705644572 23.6259815183717
# Epoch: 4 	Training Loss: 9.844541 val loss: 23.519240
# saving, val loss enhanced: 23.519240235824 23.57258705644572
# Epoch 4 time: 127.44 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:32<00:00, 132.13batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8236.29iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:43<00:00, 98.51batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 7807.98iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:18<00:00, 100.34batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 7491.06iteration/s]
# Epoch: 1 	Training Loss: 9.749046 val loss: 23.200804
# saving, val loss enhanced: 23.200804138864218 23.519240235824
# Epoch: 2 	Training Loss: 9.722230 val loss: 23.149784
# saving, val loss enhanced: 23.149784257917542 23.200804138864218
# Epoch: 3 	Training Loss: 9.695460 val loss: 23.098788
# saving, val loss enhanced: 23.098787921904847 23.149784257917542
# Epoch: 4 	Training Loss: 9.668707 val loss: 23.047818
# saving, val loss enhanced: 23.047817801195997 23.098787921904847
# Epoch 5 time: 126.44 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:39<00:00, 108.87batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9294.42iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.45batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9469.67iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 121.86batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 9126.06iteration/s]
# Epoch: 1 	Training Loss: 9.578354 val loss: 22.734242
# saving, val loss enhanced: 22.734241986087493 23.047817801195997
# Epoch: 2 	Training Loss: 9.552631 val loss: 22.685468
# saving, val loss enhanced: 22.685467541059474 22.734241986087493
# Epoch: 3 	Training Loss: 9.526948 val loss: 22.636703
# saving, val loss enhanced: 22.636703159178733 22.685467541059474
# Epoch: 4 	Training Loss: 9.501277 val loss: 22.587949
# saving, val loss enhanced: 22.587949446798415 22.636703159178733
# Epoch 6 time: 116.68 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 120.72batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9496.81iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [3.45688809+0.j         2.08722408+1.02439317j 2.08722408-1.02439317j
#  1.71819874+0.89324366j 1.71819874-0.89324366j 1.34336025+0.j
#  1.02335925+0.80702405j 1.02335925-0.80702405j 1.03495558+0.j
#  1.        +0.j        ]

# %%
#### Test 5 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:17<00:00, 69.84it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 1.074179 val loss: 1.021647
# saving, val loss enhanced: 1.0216468658882067 10000
# Epoch: 2 	Training Loss: 0.989206 val loss: 0.945440
# saving, val loss enhanced: 0.9454400184582138 1.0216468658882067
# Epoch: 3 	Training Loss: 0.917459 val loss: 0.881058
# saving, val loss enhanced: 0.8810584644807385 0.9454400184582138
# Epoch: 4 	Training Loss: 0.858720 val loss: 0.827523
# saving, val loss enhanced: 0.827522711253609 0.8810584644807385
# Epoch: 5 	Training Loss: 0.809190 val loss: 0.783354
# saving, val loss enhanced: 0.7833537459161461 0.827522711253609
# Epoch: 6 	Training Loss: 0.768005 val loss: 0.745454
# saving, val loss enhanced: 0.7454539846871215 0.7833537459161461
# Epoch: 7 	Training Loss: 0.733546 val loss: 0.713263
# saving, val loss enhanced: 0.7132634649610833 0.7454539846871215
# Epoch: 8 	Training Loss: 0.703530 val loss: 0.685854
# saving, val loss enhanced: 0.6858535066812169 0.7132634649610833
# Epoch: 9 	Training Loss: 0.677139 val loss: 0.661129
# saving, val loss enhanced: 0.6611292707397021 0.6858535066812169
# Epoch: 10 	Training Loss: 0.652599 val loss: 0.637917
# saving, val loss enhanced: 0.6379165354802079 0.6611292707397021
# Epoch: 11 	Training Loss: 0.628872 val loss: 0.613794
# saving, val loss enhanced: 0.6137936200165931 0.6379165354802079
# Epoch: 12 	Training Loss: 0.605380 val loss: 0.590344
# saving, val loss enhanced: 0.590344301806755 0.6137936200165931
# Epoch: 13 	Training Loss: 0.581775 val loss: 0.565575
# saving, val loss enhanced: 0.5655749044277901 0.590344301806755
# Epoch: 14 	Training Loss: 0.556995 val loss: 0.541018
# saving, val loss enhanced: 0.5410183611640761 0.5655749044277901
# Epoch: 15 	Training Loss: 0.532417 val loss: 0.514493
# saving, val loss enhanced: 0.514493237761457 0.5410183611640761
# Epoch: 16 	Training Loss: 0.506522 val loss: 0.488524
# saving, val loss enhanced: 0.48852430113665635 0.514493237761457
# Epoch: 17 	Training Loss: 0.480274 val loss: 0.461551
# saving, val loss enhanced: 0.46155134660384867 0.48852430113665635
# Epoch: 18 	Training Loss: 0.453833 val loss: 0.434994
# saving, val loss enhanced: 0.43499389044884107 0.46155134660384867
# Epoch: 19 	Training Loss: 0.427049 val loss: 0.408760
# saving, val loss enhanced: 0.4087602093003958 0.43499389044884107
# Epoch: 20 	Training Loss: 0.401167 val loss: 0.380744
# saving, val loss enhanced: 0.3807435083635921 0.4087602093003958
# Epoch: 21 	Training Loss: 0.374422 val loss: 0.353676
# saving, val loss enhanced: 0.353676079721482 0.3807435083635921
# Epoch: 22 	Training Loss: 0.348340 val loss: 0.326844
# saving, val loss enhanced: 0.3268440788653525 0.353676079721482
# Epoch: 23 	Training Loss: 0.323407 val loss: 0.302605
# saving, val loss enhanced: 0.3026048831748497 0.3268440788653525
# Epoch: 24 	Training Loss: 0.300028 val loss: 0.278665
# saving, val loss enhanced: 0.2786653222859963 0.3026048831748497
# Epoch: 25 	Training Loss: 0.277171 val loss: 0.255555
# saving, val loss enhanced: 0.2555554706263514 0.2786653222859963
# Epoch: 26 	Training Loss: 0.257110 val loss: 0.236390
# saving, val loss enhanced: 0.23638971331886105 0.2555554706263514
# Epoch: 27 	Training Loss: 0.239424 val loss: 0.220436
# saving, val loss enhanced: 0.2204359472929168 0.23638971331886105
# Epoch: 28 	Training Loss: 0.223931 val loss: 0.204756
# saving, val loss enhanced: 0.2047559404601649 0.2204359472929168
# Epoch: 29 	Training Loss: 0.209916 val loss: 0.191602
# saving, val loss enhanced: 0.19160212324407047 0.2047559404601649
# Epoch: 30 	Training Loss: 0.200238 val loss: 0.182477
# saving, val loss enhanced: 0.18247739338097965 0.19160212324407047
# Epoch: 31 	Training Loss: 0.190934 val loss: 0.174896
# saving, val loss enhanced: 0.17489620542862816 0.18247739338097965
# Epoch: 32 	Training Loss: 0.184759 val loss: 0.169197
# saving, val loss enhanced: 0.16919717938317813 0.17489620542862816
# Epoch: 33 	Training Loss: 0.180208 val loss: 0.164761
# saving, val loss enhanced: 0.1647610902001423 0.16919717938317813
# Epoch: 34 	Training Loss: 0.177740 val loss: 0.160209
# saving, val loss enhanced: 0.16020870978227597 0.1647610902001423
# Epoch: 35 	Training Loss: 0.173353 val loss: 0.158234
# saving, val loss enhanced: 0.15823435684004497 0.16020870978227597
# Epoch: 36 	Training Loss: 0.172493 val loss: 0.158810
# Epoch: 37 	Training Loss: 0.171220 val loss: 0.157169
# saving, val loss enhanced: 0.15716934958444068 0.15823435684004497
# Epoch: 38 	Training Loss: 0.169444 val loss: 0.160319
# Epoch: 39 	Training Loss: 0.169220 val loss: 0.154532
# saving, val loss enhanced: 0.1545315873437759 0.15716934958444068
# Epoch: 40 	Training Loss: 0.168522 val loss: 0.152910
# saving, val loss enhanced: 0.15291037013944572 0.1545315873437759
# Epoch: 41 	Training Loss: 0.167998 val loss: 0.153866
# Epoch: 42 	Training Loss: 0.168330 val loss: 0.152318
# saving, val loss enhanced: 0.15231837000233342 0.15291037013944572
# Epoch: 43 	Training Loss: 0.167298 val loss: 0.152018
# saving, val loss enhanced: 0.1520177983384227 0.15231837000233342
# Epoch: 44 	Training Loss: 0.167574 val loss: 0.150992
# saving, val loss enhanced: 0.15099243676612215 0.1520177983384227
# Epoch: 45 	Training Loss: 0.166050 val loss: 0.152371
# Epoch: 46 	Training Loss: 0.164677 val loss: 0.150742
# saving, val loss enhanced: 0.1507417651069454 0.15099243676612215
# Epoch: 47 	Training Loss: 0.164820 val loss: 0.150357
# saving, val loss enhanced: 0.15035736589688034 0.1507417651069454
# Epoch: 48 	Training Loss: 0.162450 val loss: 0.149864
# saving, val loss enhanced: 0.14986389656745508 0.15035736589688034
# Epoch: 49 	Training Loss: 0.163574 val loss: 0.148818
# saving, val loss enhanced: 0.1488175959867362 0.14986389656745508
# Epoch: 50 	Training Loss: 0.163507 val loss: 0.148329
# saving, val loss enhanced: 0.14832906632645781 0.1488175959867362
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:43<00:00, 98.66batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:11<00:00, 7313.27iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 117.84batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8499.11iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.499627 val loss: 0.360066
# saving, val loss enhanced: 0.3600661460104812 1000000000000000.0
# Epoch: 2 	Training Loss: 0.498584 val loss: 0.359402
# saving, val loss enhanced: 0.3594015451516629 0.3600661460104812
# Epoch: 3 	Training Loss: 0.497540 val loss: 0.358737
# saving, val loss enhanced: 0.35873669729133717 0.3594015451516629
# Epoch: 4 	Training Loss: 0.496497 val loss: 0.358072
# saving, val loss enhanced: 0.3580724918562874 0.35873669729133717
# Epoch 1 time: 49.04 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.47batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8582.04iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.573432 val loss: 0.411809
# Epoch: 2 	Training Loss: 0.572150 val loss: 0.411001
# Epoch: 3 	Training Loss: 0.570883 val loss: 0.410206
# Epoch: 4 	Training Loss: 0.569635 val loss: 0.409420
# Epoch 2 time: 48.10 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.59batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8762.21iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.676972 val loss: 0.484869
# Epoch: 2 	Training Loss: 0.675382 val loss: 0.483874
# Epoch: 3 	Training Loss: 0.673817 val loss: 0.482899
# Epoch: 4 	Training Loss: 0.672282 val loss: 0.481943
# Epoch 3 time: 47.09 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:32<00:00, 133.96batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9230.99iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.826015 val loss: 0.590794
# Epoch: 2 	Training Loss: 0.823972 val loss: 0.589522
# Epoch: 3 	Training Loss: 0.821968 val loss: 0.588284
# Epoch: 4 	Training Loss: 0.820015 val loss: 0.587075
# Epoch 4 time: 43.60 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.99batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8128.13iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.048728 val loss: 0.750380
# Epoch: 2 	Training Loss: 1.045984 val loss: 0.748681
# Epoch: 3 	Training Loss: 1.043309 val loss: 0.747040
# Epoch: 4 	Training Loss: 1.040717 val loss: 0.745447
# Epoch 5 time: 48.91 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:29<00:00, 144.51batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 7977.13iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.394158 val loss: 1.000285
# Epoch: 2 	Training Loss: 1.390298 val loss: 0.997910
# Epoch: 3 	Training Loss: 1.386563 val loss: 0.995634
# Epoch: 4 	Training Loss: 1.382974 val loss: 0.993442
# Epoch 6 time: 42.89 seconds
# (10,)
# [0.99999845 0.99297521 0.87524163 0.54164173 0.51977241 0.3274248
#  0.27317999 0.04798604 0.0310089  0.00100607]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 117.60batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9286.60iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.92batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9059.06iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:30<00:00, 142.10batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9939.87iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:13<00:00, 132.20batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8425.09iteration/s]
# Epoch: 1 	Training Loss: 11.033530 val loss: 14.662472
# saving, val loss enhanced: 14.662471577175625 1000000000000000.0
# Epoch: 2 	Training Loss: 10.979294 val loss: 14.617168
# saving, val loss enhanced: 14.617167896139781 14.662471577175625
# Epoch: 3 	Training Loss: 10.925509 val loss: 14.572397
# saving, val loss enhanced: 14.572396808197158 14.617167896139781
# Epoch: 4 	Training Loss: 10.871992 val loss: 14.528001
# saving, val loss enhanced: 14.528001187849219 14.572396808197158
# Epoch 1 time: 107.58 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:28<00:00, 148.05batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8989.84iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 128.47batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9955.65iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 122.00batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9197.30iteration/s]
# Epoch: 1 	Training Loss: 10.810226 val loss: 14.610964
# Epoch: 2 	Training Loss: 10.758170 val loss: 14.567591
# Epoch: 3 	Training Loss: 10.706353 val loss: 14.524437
# saving, val loss enhanced: 14.524437234324827 14.528001187849219
# Epoch: 4 	Training Loss: 10.654759 val loss: 14.481499
# saving, val loss enhanced: 14.481498616666515 14.524437234324827
# Epoch 2 time: 103.05 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 126.44batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9548.97iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:29<00:00, 147.06batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 10718.72iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 121.50batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9290.94iteration/s]
# Epoch: 1 	Training Loss: 10.590730 val loss: 14.564227
# Epoch: 2 	Training Loss: 10.540547 val loss: 14.522182
# Epoch: 3 	Training Loss: 10.490590 val loss: 14.480319
# saving, val loss enhanced: 14.480318818448957 14.481498616666515
# Epoch: 4 	Training Loss: 10.440835 val loss: 14.438637
# saving, val loss enhanced: 14.438637300615966 14.480318818448957
# Epoch 3 time: 103.38 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.28batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9558.74iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:32<00:00, 131.72batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9758.63iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 122.18batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9437.32iteration/s]
# Epoch: 1 	Training Loss: 10.380463 val loss: 14.526281
# Epoch: 2 	Training Loss: 10.332041 val loss: 14.485421
# Epoch: 3 	Training Loss: 10.283831 val loss: 14.444724
# Epoch: 4 	Training Loss: 10.235806 val loss: 14.404191
# saving, val loss enhanced: 14.404191328927777 14.438637300615966
# Epoch 4 time: 108.04 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:32<00:00, 132.91batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10137.36iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.18batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9298.97iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:12<00:00, 149.85batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9739.75iteration/s]
# Epoch: 1 	Training Loss: 10.180399 val loss: 14.497774
# Epoch: 2 	Training Loss: 10.133632 val loss: 14.458003
# Epoch: 3 	Training Loss: 10.087062 val loss: 14.418383
# Epoch: 4 	Training Loss: 10.040664 val loss: 14.378913
# saving, val loss enhanced: 14.378912940970483 14.404191328927777
# Epoch 5 time: 106.00 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 117.03batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9366.30iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 128.76batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9427.87iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:12<00:00, 150.91batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 11181.00iteration/s]
# Epoch: 1 	Training Loss: 9.990662 val loss: 14.478733
# Epoch: 2 	Training Loss: 9.945451 val loss: 14.439973
# Epoch: 3 	Training Loss: 9.900425 val loss: 14.401352
# Epoch: 4 	Training Loss: 9.855558 val loss: 14.362871
# saving, val loss enhanced: 14.36287089321546 14.378912940970483
# Epoch 6 time: 107.30 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.82batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9584.70iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [2.31607998+1.12125439j 2.31607998-1.12125439j 1.23248999-1.23453876j
#  1.23248999+1.23453876j 1.45485048+0.j         1.22560048+0.j
#  1.        +0.j         0.92405887-0.10020682j 0.92405887+0.10020682j
#  0.87818873+0.j        ]

# %%
#### Test 6 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: S-EDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:17<00:00, 70.07it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 0.404727 val loss: 0.372979
# saving, val loss enhanced: 0.37297914176275876 10000
# Epoch: 2 	Training Loss: 0.366404 val loss: 0.338597
# saving, val loss enhanced: 0.33859672154270337 0.37297914176275876
# Epoch: 3 	Training Loss: 0.337557 val loss: 0.317823
# saving, val loss enhanced: 0.31782296606275967 0.33859672154270337
# Epoch: 4 	Training Loss: 0.318999 val loss: 0.294596
# saving, val loss enhanced: 0.29459621845754297 0.31782296606275967
# Epoch: 5 	Training Loss: 0.300140 val loss: 0.280351
# saving, val loss enhanced: 0.2803505719606184 0.29459621845754297
# Epoch: 6 	Training Loss: 0.288567 val loss: 0.267585
# saving, val loss enhanced: 0.26758544369802617 0.2803505719606184
# Epoch: 7 	Training Loss: 0.277095 val loss: 0.256853
# saving, val loss enhanced: 0.2568533785286672 0.26758544369802617
# Epoch: 8 	Training Loss: 0.267792 val loss: 0.252096
# saving, val loss enhanced: 0.2520961262294739 0.2568533785286672
# Epoch: 9 	Training Loss: 0.260086 val loss: 0.243121
# saving, val loss enhanced: 0.24312084306229242 0.2520961262294739
# Epoch: 10 	Training Loss: 0.255668 val loss: 0.243705
# Epoch: 11 	Training Loss: 0.248264 val loss: 0.229431
# saving, val loss enhanced: 0.22943075159644366 0.24312084306229242
# Epoch: 12 	Training Loss: 0.242273 val loss: 0.224252
# saving, val loss enhanced: 0.2242519341186032 0.22943075159644366
# Epoch: 13 	Training Loss: 0.238795 val loss: 0.228232
# Epoch: 14 	Training Loss: 0.237065 val loss: 0.219667
# saving, val loss enhanced: 0.21966721406499048 0.2242519341186032
# Epoch: 15 	Training Loss: 0.233039 val loss: 0.220792
# Epoch: 16 	Training Loss: 0.228876 val loss: 0.210519
# saving, val loss enhanced: 0.21051889054323855 0.21966721406499048
# Epoch: 17 	Training Loss: 0.226704 val loss: 0.207440
# saving, val loss enhanced: 0.20744038868863704 0.21051889054323855
# Epoch: 18 	Training Loss: 0.225196 val loss: 0.206030
# saving, val loss enhanced: 0.2060295197347465 0.20744038868863704
# Epoch: 19 	Training Loss: 0.224023 val loss: 0.208565
# Epoch: 20 	Training Loss: 0.222489 val loss: 0.212374
# Epoch: 21 	Training Loss: 0.221176 val loss: 0.205650
# saving, val loss enhanced: 0.20565028419403325 0.2060295197347465
# Epoch: 22 	Training Loss: 0.219135 val loss: 0.198387
# saving, val loss enhanced: 0.19838741558369655 0.20565028419403325
# Epoch: 23 	Training Loss: 0.219417 val loss: 0.201760
# Epoch: 24 	Training Loss: 0.215501 val loss: 0.198254
# saving, val loss enhanced: 0.19825422550892943 0.19838741558369655
# Epoch: 25 	Training Loss: 0.211310 val loss: 0.196108
# saving, val loss enhanced: 0.19610837216754518 0.19825422550892943
# Epoch: 26 	Training Loss: 0.211995 val loss: 0.196690
# Epoch: 27 	Training Loss: 0.211223 val loss: 0.196102
# saving, val loss enhanced: 0.1961019678589053 0.19610837216754518
# Epoch: 28 	Training Loss: 0.207126 val loss: 0.191281
# saving, val loss enhanced: 0.19128101829438363 0.1961019678589053
# Epoch: 29 	Training Loss: 0.205291 val loss: 0.199004
# Epoch: 30 	Training Loss: 0.205126 val loss: 0.187252
# saving, val loss enhanced: 0.18725235985097624 0.19128101829438363
# Epoch: 31 	Training Loss: 0.204480 val loss: 0.195737
# Epoch: 32 	Training Loss: 0.204582 val loss: 0.198728
# Epoch: 33 	Training Loss: 0.202370 val loss: 0.189861
# Epoch: 34 	Training Loss: 0.199650 val loss: 0.182926
# saving, val loss enhanced: 0.18292594324857853 0.18725235985097624
# Epoch: 35 	Training Loss: 0.200396 val loss: 0.185184
# Epoch: 36 	Training Loss: 0.200057 val loss: 0.185133
# Epoch: 37 	Training Loss: 0.198047 val loss: 0.191844
# Epoch: 38 	Training Loss: 0.198066 val loss: 0.182722
# saving, val loss enhanced: 0.18272215714027631 0.18292594324857853
# Epoch: 39 	Training Loss: 0.194542 val loss: 0.183269
# Epoch: 40 	Training Loss: 0.195325 val loss: 0.182926
# Epoch: 41 	Training Loss: 0.193605 val loss: 0.180624
# saving, val loss enhanced: 0.18062423269705202 0.18272215714027631
# Epoch: 42 	Training Loss: 0.192188 val loss: 0.183114
# Epoch: 43 	Training Loss: 0.191973 val loss: 0.181009
# Epoch: 44 	Training Loss: 0.190101 val loss: 0.179651
# saving, val loss enhanced: 0.17965140442156372 0.18062423269705202
# Epoch: 45 	Training Loss: 0.187676 val loss: 0.178092
# saving, val loss enhanced: 0.1780915468077499 0.17965140442156372
# Epoch: 46 	Training Loss: 0.189901 val loss: 0.172811
# saving, val loss enhanced: 0.17281121001381855 0.1780915468077499
# Epoch: 47 	Training Loss: 0.189932 val loss: 0.179830
# Epoch: 48 	Training Loss: 0.187445 val loss: 0.170879
# saving, val loss enhanced: 0.170878708698599 0.17281121001381855
# Epoch: 49 	Training Loss: 0.184539 val loss: 0.173882
# Epoch: 50 	Training Loss: 0.187111 val loss: 0.166705
# saving, val loss enhanced: 0.16670464139423494 0.170878708698599
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:29<00:00, 144.36batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9277.20iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.15batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8649.24iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 2.060172 val loss: 1.466259
# saving, val loss enhanced: 1.4662587051037677 1000000000000000.0
# Epoch: 2 	Training Loss: 2.058094 val loss: 1.464895
# saving, val loss enhanced: 1.464895186404248 1.4662587051037677
# Epoch: 3 	Training Loss: 2.056020 val loss: 1.463533
# saving, val loss enhanced: 1.4635333502171508 1.464895186404248
# Epoch: 4 	Training Loss: 2.053949 val loss: 1.462174
# saving, val loss enhanced: 1.46217406522566 1.4635333502171508
# Epoch 1 time: 47.00 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:30<00:00, 138.79batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10143.36iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.992606 val loss: 1.415675
# saving, val loss enhanced: 1.4156750347389189 1.46217406522566
# Epoch: 2 	Training Loss: 1.990783 val loss: 1.414485
# saving, val loss enhanced: 1.4144851357972243 1.4156750347389189
# Epoch: 3 	Training Loss: 1.988957 val loss: 1.413290
# saving, val loss enhanced: 1.4132901890727456 1.4144851357972243
# Epoch: 4 	Training Loss: 1.987124 val loss: 1.412092
# saving, val loss enhanced: 1.4120915747340421 1.4132901890727456
# Epoch 2 time: 41.38 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 126.43batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9473.10iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.917141 val loss: 1.361075
# saving, val loss enhanced: 1.3610753324908824 1.4120915747340421
# Epoch: 2 	Training Loss: 1.915526 val loss: 1.360027
# saving, val loss enhanced: 1.3600272591614018 1.3610753324908824
# Epoch: 3 	Training Loss: 1.913910 val loss: 1.358975
# saving, val loss enhanced: 1.358975009879265 1.3600272591614018
# Epoch: 4 	Training Loss: 1.912287 val loss: 1.357919
# saving, val loss enhanced: 1.3579190306159685 1.358975009879265
# Epoch 3 time: 45.19 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 129.25batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9282.56iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.835584 val loss: 1.303688
# saving, val loss enhanced: 1.3036880625872314 1.3579190306159685
# Epoch: 2 	Training Loss: 1.834146 val loss: 1.302759
# saving, val loss enhanced: 1.302759075262446 1.3036880625872314
# Epoch: 3 	Training Loss: 1.832708 val loss: 1.301826
# saving, val loss enhanced: 1.3018264158673751 1.302759075262446
# Epoch: 4 	Training Loss: 1.831264 val loss: 1.300890
# saving, val loss enhanced: 1.300890236192337 1.3018264158673751
# Epoch 4 time: 44.52 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.44batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9683.87iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.752694 val loss: 1.246636
# saving, val loss enhanced: 1.2466364671354893 1.300890236192337
# Epoch: 2 	Training Loss: 1.751397 val loss: 1.245801
# saving, val loss enhanced: 1.2458011371286735 1.2466364671354893
# Epoch: 3 	Training Loss: 1.750099 val loss: 1.244962
# saving, val loss enhanced: 1.2449620718257186 1.2458011371286735
# Epoch: 4 	Training Loss: 1.748795 val loss: 1.244119
# saving, val loss enhanced: 1.2441193411584344 1.2449620718257186
# Epoch 5 time: 45.89 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:29<00:00, 145.63batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8745.74iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.672382 val loss: 1.192284
# saving, val loss enhanced: 1.1922839695850862 1.2441193411584344
# Epoch: 2 	Training Loss: 1.671196 val loss: 1.191522
# saving, val loss enhanced: 1.1915218924799895 1.1922839695850862
# Epoch: 3 	Training Loss: 1.670007 val loss: 1.190756
# saving, val loss enhanced: 1.190755862585231 1.1915218924799895
# Epoch: 4 	Training Loss: 1.668812 val loss: 1.189986
# saving, val loss enhanced: 1.1899859259928733 1.190755862585231
# Epoch 6 time: 41.40 seconds
# (10,)
# [1.00000207e+00 9.91101923e-01 8.82508015e-01 5.98116340e-01
#  5.53903591e-01 3.72226412e-01 3.05021576e-01 1.80534550e-01
#  8.52976759e-02 1.84743768e-04]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:26<00:00, 163.28batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8269.05iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 135.82batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10473.62iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:26<00:00, 159.50batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9467.63iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:17<00:00, 106.31batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 7841.87iteration/s]
# Epoch: 1 	Training Loss: 14.515103 val loss: 29.499220
# saving, val loss enhanced: 29.499219535819996 1000000000000000.0
# Epoch: 2 	Training Loss: 14.486050 val loss: 29.459389
# saving, val loss enhanced: 29.459389148707785 29.499219535819996
# Epoch: 3 	Training Loss: 14.458124 val loss: 29.420438
# saving, val loss enhanced: 29.420438287595104 29.459389148707785
# Epoch: 4 	Training Loss: 14.430437 val loss: 29.381975
# saving, val loss enhanced: 29.38197482151038 29.420438287595104
# Epoch 1 time: 102.81 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:29<00:00, 145.35batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8525.41iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 135.69batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9354.45iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:05<00:00, 358.05batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 10124.29iteration/s]
# Epoch: 1 	Training Loss: 14.341604 val loss: 29.081555
# saving, val loss enhanced: 29.081555366865434 29.38197482151038
# Epoch: 2 	Training Loss: 14.315257 val loss: 29.045162
# saving, val loss enhanced: 29.04516206561191 29.081555366865434
# Epoch: 3 	Training Loss: 14.288975 val loss: 29.008859
# saving, val loss enhanced: 29.008859424725138 29.04516206561191
# Epoch: 4 	Training Loss: 14.262735 val loss: 28.972642
# saving, val loss enhanced: 28.97264156864421 29.008859424725138
# Epoch 2 time: 93.39 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:20<00:00, 207.68batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9296.67iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.98batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8919.53iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 129.00batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9824.35iteration/s]
# Epoch: 1 	Training Loss: 14.194406 val loss: 28.708846
# saving, val loss enhanced: 28.7088464213666 28.97264156864421
# Epoch: 2 	Training Loss: 14.169209 val loss: 28.674191
# saving, val loss enhanced: 28.674190574560168 28.7088464213666
# Epoch: 3 	Training Loss: 14.144062 val loss: 28.639565
# saving, val loss enhanced: 28.639565118514717 28.674190574560168
# Epoch: 4 	Training Loss: 14.118941 val loss: 28.604972
# saving, val loss enhanced: 28.60497168047987 28.639565118514717
# Epoch 3 time: 97.59 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 136.21batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9722.94iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 128.12batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9775.19iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 125.01batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9268.86iteration/s]
# Epoch: 1 	Training Loss: 14.065769 val loss: 28.365980
# saving, val loss enhanced: 28.365980069724777 28.60497168047987
# Epoch: 2 	Training Loss: 14.041553 val loss: 28.332732
# saving, val loss enhanced: 28.332732031511256 28.365980069724777
# Epoch: 3 	Training Loss: 14.017381 val loss: 28.299498
# saving, val loss enhanced: 28.299497863682376 28.332732031511256
# Epoch: 4 	Training Loss: 13.993232 val loss: 28.266278
# saving, val loss enhanced: 28.266277840290112 28.299497863682376
# Epoch 4 time: 104.82 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:39<00:00, 107.21batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9622.05iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 136.12batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8882.77iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:17<00:00, 106.73batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 7419.35iteration/s]
# Epoch: 1 	Training Loss: 13.954265 val loss: 28.049369
# saving, val loss enhanced: 28.049368895848072 28.266277840290112
# Epoch: 2 	Training Loss: 13.930910 val loss: 28.017336
# saving, val loss enhanced: 28.017336313119642 28.049368895848072
# Epoch: 3 	Training Loss: 13.907596 val loss: 27.985310
# saving, val loss enhanced: 27.985310455771536 28.017336313119642
# Epoch: 4 	Training Loss: 13.884304 val loss: 27.953290
# saving, val loss enhanced: 27.953290303241378 27.985310455771536
# Epoch 5 time: 117.33 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:38<00:00, 112.57batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8598.92iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 117.63batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 10761.81iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 116.80batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 9112.46iteration/s]
# Epoch: 1 	Training Loss: 13.859073 val loss: 27.756938
# saving, val loss enhanced: 27.75693781858441 27.953290303241378
# Epoch: 2 	Training Loss: 13.836478 val loss: 27.725974
# saving, val loss enhanced: 27.72597441000004 27.75693781858441
# Epoch: 3 	Training Loss: 13.813925 val loss: 27.695014
# saving, val loss enhanced: 27.695013915502045 27.72597441000004
# Epoch: 4 	Training Loss: 13.791392 val loss: 27.664054
# saving, val loss enhanced: 27.664054494501727 27.695013915502045
# Epoch 6 time: 116.27 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:37<00:00, 113.85batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8520.49iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [2.86180648-2.43067148j 2.86180648+2.43067148j 2.25014441+0.j
#  0.63266112-0.88322426j 0.63266112+0.88322426j 1.        +0.j
#  0.97781807+0.12153473j 0.97781807-0.12153473j 0.81488099-0.39643076j
#  0.81488099+0.39643076j]

# %%
#### Test 7 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: S-EDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:18<00:00, 66.47it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 0.958677 val loss: 0.873995
# saving, val loss enhanced: 0.873995378982688 10000
# Epoch: 2 	Training Loss: 0.869245 val loss: 0.795032
# saving, val loss enhanced: 0.7950322509820519 0.873995378982688
# Epoch: 3 	Training Loss: 0.790747 val loss: 0.726034
# saving, val loss enhanced: 0.726034073679226 0.7950322509820519
# Epoch: 4 	Training Loss: 0.722382 val loss: 0.664785
# saving, val loss enhanced: 0.6647854987346568 0.726034073679226
# Epoch: 5 	Training Loss: 0.661952 val loss: 0.611752
# saving, val loss enhanced: 0.6117515017954948 0.6647854987346568
# Epoch: 6 	Training Loss: 0.608624 val loss: 0.563372
# saving, val loss enhanced: 0.563371594024941 0.6117515017954948
# Epoch: 7 	Training Loss: 0.561467 val loss: 0.523283
# saving, val loss enhanced: 0.5232829288802583 0.563371594024941
# Epoch: 8 	Training Loss: 0.522167 val loss: 0.488718
# saving, val loss enhanced: 0.4887181844378626 0.5232829288802583
# Epoch: 9 	Training Loss: 0.489762 val loss: 0.458930
# saving, val loss enhanced: 0.45892989024436737 0.4887181844378626
# Epoch: 10 	Training Loss: 0.458737 val loss: 0.431663
# saving, val loss enhanced: 0.4316631201200434 0.45892989024436737
# Epoch: 11 	Training Loss: 0.431382 val loss: 0.407795
# saving, val loss enhanced: 0.40779542973944666 0.4316631201200434
# Epoch: 12 	Training Loss: 0.407013 val loss: 0.383518
# saving, val loss enhanced: 0.38351831382086726 0.40779542973944666
# Epoch: 13 	Training Loss: 0.384278 val loss: 0.364605
# saving, val loss enhanced: 0.36460472815660006 0.38351831382086726
# Epoch: 14 	Training Loss: 0.364356 val loss: 0.345727
# saving, val loss enhanced: 0.34572742782509586 0.36460472815660006
# Epoch: 15 	Training Loss: 0.344525 val loss: 0.328851
# saving, val loss enhanced: 0.3288513283876879 0.34572742782509586
# Epoch: 16 	Training Loss: 0.327048 val loss: 0.313972
# saving, val loss enhanced: 0.3139724842907654 0.3288513283876879
# Epoch: 17 	Training Loss: 0.313469 val loss: 0.300447
# saving, val loss enhanced: 0.3004465215325412 0.3139724842907654
# Epoch: 18 	Training Loss: 0.298782 val loss: 0.289955
# saving, val loss enhanced: 0.28995543834924487 0.3004465215325412
# Epoch: 19 	Training Loss: 0.287065 val loss: 0.280448
# saving, val loss enhanced: 0.2804482239494085 0.28995543834924487
# Epoch: 20 	Training Loss: 0.277222 val loss: 0.270082
# saving, val loss enhanced: 0.27008230122748644 0.2804482239494085
# Epoch: 21 	Training Loss: 0.270121 val loss: 0.263365
# saving, val loss enhanced: 0.2633646638381954 0.27008230122748644
# Epoch: 22 	Training Loss: 0.263874 val loss: 0.256362
# saving, val loss enhanced: 0.25636197158735763 0.2633646638381954
# Epoch: 23 	Training Loss: 0.257324 val loss: 0.251185
# saving, val loss enhanced: 0.25118537934442736 0.25636197158735763
# Epoch: 24 	Training Loss: 0.250917 val loss: 0.247702
# saving, val loss enhanced: 0.24770215481867677 0.25118537934442736
# Epoch: 25 	Training Loss: 0.246591 val loss: 0.242612
# saving, val loss enhanced: 0.24261240801831443 0.24770215481867677
# Epoch: 26 	Training Loss: 0.243562 val loss: 0.238852
# saving, val loss enhanced: 0.2388524295554794 0.24261240801831443
# Epoch: 27 	Training Loss: 0.239037 val loss: 0.236123
# saving, val loss enhanced: 0.23612343142737724 0.2388524295554794
# Epoch: 28 	Training Loss: 0.235380 val loss: 0.233087
# saving, val loss enhanced: 0.23308707012515686 0.23612343142737724
# Epoch: 29 	Training Loss: 0.231652 val loss: 0.229392
# saving, val loss enhanced: 0.22939171032687913 0.23308707012515686
# Epoch: 30 	Training Loss: 0.229013 val loss: 0.226100
# saving, val loss enhanced: 0.22610033922452832 0.22939171032687913
# Epoch: 31 	Training Loss: 0.225701 val loss: 0.223894
# saving, val loss enhanced: 0.22389433847993728 0.22610033922452832
# Epoch: 32 	Training Loss: 0.222479 val loss: 0.218374
# saving, val loss enhanced: 0.21837429519007748 0.22389433847993728
# Epoch: 33 	Training Loss: 0.220566 val loss: 0.218713
# Epoch: 34 	Training Loss: 0.217301 val loss: 0.217980
# saving, val loss enhanced: 0.21798018525151447 0.21837429519007748
# Epoch: 35 	Training Loss: 0.213830 val loss: 0.211727
# saving, val loss enhanced: 0.211727276846708 0.21798018525151447
# Epoch: 36 	Training Loss: 0.211232 val loss: 0.210682
# saving, val loss enhanced: 0.21068219863623702 0.211727276846708
# Epoch: 37 	Training Loss: 0.208329 val loss: 0.207922
# saving, val loss enhanced: 0.20792222833332097 0.21068219863623702
# Epoch: 38 	Training Loss: 0.206339 val loss: 0.206920
# saving, val loss enhanced: 0.20691969535492521 0.20792222833332097
# Epoch: 39 	Training Loss: 0.202856 val loss: 0.200844
# saving, val loss enhanced: 0.2008436206638277 0.20691969535492521
# Epoch: 40 	Training Loss: 0.201522 val loss: 0.199723
# saving, val loss enhanced: 0.1997225964449587 0.2008436206638277
# Epoch: 41 	Training Loss: 0.196848 val loss: 0.199248
# saving, val loss enhanced: 0.19924766644092293 0.1997225964449587
# Epoch: 42 	Training Loss: 0.195036 val loss: 0.196474
# saving, val loss enhanced: 0.19647428900166827 0.19924766644092293
# Epoch: 43 	Training Loss: 0.192384 val loss: 0.194727
# saving, val loss enhanced: 0.19472694907494226 0.19647428900166827
# Epoch: 44 	Training Loss: 0.189367 val loss: 0.190182
# saving, val loss enhanced: 0.19018211670590648 0.19472694907494226
# Epoch: 45 	Training Loss: 0.187013 val loss: 0.191901
# Epoch: 46 	Training Loss: 0.183385 val loss: 0.188001
# saving, val loss enhanced: 0.18800139252411976 0.19018211670590648
# Epoch: 47 	Training Loss: 0.180415 val loss: 0.184849
# saving, val loss enhanced: 0.1848490716345574 0.18800139252411976
# Epoch: 48 	Training Loss: 0.178191 val loss: 0.182618
# saving, val loss enhanced: 0.18261849636504965 0.1848490716345574
# Epoch: 49 	Training Loss: 0.175169 val loss: 0.178603
# saving, val loss enhanced: 0.17860335032240013 0.18261849636504965
# Epoch: 50 	Training Loss: 0.172931 val loss: 0.176453
# saving, val loss enhanced: 0.17645269629155164 0.17860335032240013
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:37<00:00, 115.58batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8108.01iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 136.52batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8665.49iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.033691 val loss: 0.043022
# saving, val loss enhanced: 0.043021903663449455 1000000000000000.0
# Epoch: 2 	Training Loss: 0.033625 val loss: 0.042920
# saving, val loss enhanced: 0.04291988672383943 0.043021903663449455
# Epoch: 3 	Training Loss: 0.033560 val loss: 0.042819
# saving, val loss enhanced: 0.04281926229910109 0.04291988672383943
# Epoch: 4 	Training Loss: 0.033496 val loss: 0.042720
# saving, val loss enhanced: 0.04271971667211802 0.04281926229910109
# Epoch 1 time: 43.90 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:37<00:00, 115.00batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8637.51iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.033542 val loss: 0.042580
# saving, val loss enhanced: 0.042579999186209305 0.04271971667211802
# Epoch: 2 	Training Loss: 0.033479 val loss: 0.042484
# saving, val loss enhanced: 0.04248399732411001 0.042579999186209305
# Epoch: 3 	Training Loss: 0.033417 val loss: 0.042389
# saving, val loss enhanced: 0.042388748002106055 0.04248399732411001
# Epoch: 4 	Training Loss: 0.033355 val loss: 0.042294
# saving, val loss enhanced: 0.042294230295700314 0.042388748002106055
# Epoch 2 time: 49.41 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.22batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9713.06iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.033400 val loss: 0.042166
# saving, val loss enhanced: 0.04216557141569261 0.042294230295700314
# Epoch: 2 	Training Loss: 0.033339 val loss: 0.042074
# saving, val loss enhanced: 0.04207412212068444 0.04216557141569261
# Epoch: 3 	Training Loss: 0.033280 val loss: 0.041983
# saving, val loss enhanced: 0.041983327257517425 0.04207412212068444
# Epoch: 4 	Training Loss: 0.033220 val loss: 0.041893
# saving, val loss enhanced: 0.041893177708542936 0.041983327257517425
# Epoch 3 time: 47.94 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:41<00:00, 102.65batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8710.46iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.033259 val loss: 0.041773
# saving, val loss enhanced: 0.041772745141983404 0.041893177708542936
# Epoch: 2 	Training Loss: 0.033201 val loss: 0.041685
# saving, val loss enhanced: 0.0416854012968014 0.041772745141983404
# Epoch: 3 	Training Loss: 0.033143 val loss: 0.041599
# saving, val loss enhanced: 0.04159865556296678 0.0416854012968014
# Epoch: 4 	Training Loss: 0.033086 val loss: 0.041513
# saving, val loss enhanced: 0.04151250033262396 0.04159865556296678
# Epoch 4 time: 53.76 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.29batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8710.74iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.033119 val loss: 0.041399
# saving, val loss enhanced: 0.0413993479229158 0.04151250033262396
# Epoch: 2 	Training Loss: 0.033063 val loss: 0.041316
# saving, val loss enhanced: 0.04131578487362655 0.0413993479229158
# Epoch: 3 	Training Loss: 0.033007 val loss: 0.041233
# saving, val loss enhanced: 0.041232775599919315 0.04131578487362655
# Epoch: 4 	Training Loss: 0.032951 val loss: 0.041150
# saving, val loss enhanced: 0.04115031292341061 0.041232775599919315
# Epoch 5 time: 49.26 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.32batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9327.17iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 0.032977 val loss: 0.041043
# saving, val loss enhanced: 0.04104349917154777 0.04115031292341061
# Epoch: 2 	Training Loss: 0.032923 val loss: 0.040963
# saving, val loss enhanced: 0.04096344142469175 0.04104349917154777
# Epoch: 3 	Training Loss: 0.032869 val loss: 0.040884
# saving, val loss enhanced: 0.04088389910467261 0.04096344142469175
# Epoch: 4 	Training Loss: 0.032815 val loss: 0.040805
# saving, val loss enhanced: 0.04080486535988754 0.04088389910467261
# Epoch 6 time: 47.64 seconds
# (10,)
# [0.99999808 0.99319536 0.87949578 0.55404642 0.52271136 0.3561771
#  0.2792702  0.11663562 0.05733729 0.01796224]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.95batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9851.08iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.89batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10078.28iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 126.80batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9608.16iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:13<00:00, 132.01batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8221.70iteration/s]
# Epoch: 1 	Training Loss: 23.381007 val loss: 18.577023
# saving, val loss enhanced: 18.577022801675746 1000000000000000.0
# Epoch: 2 	Training Loss: 23.326128 val loss: 18.541455
# saving, val loss enhanced: 18.54145506734177 18.577022801675746
# Epoch: 3 	Training Loss: 23.271246 val loss: 18.505939
# saving, val loss enhanced: 18.50593910027046 18.54145506734177
# Epoch: 4 	Training Loss: 23.216385 val loss: 18.470506
# saving, val loss enhanced: 18.47050563921761 18.50593910027046
# Epoch 1 time: 108.52 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:29<00:00, 145.95batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:11<00:00, 7398.26iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.97batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:11<00:00, 7744.47iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 123.38batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:05<00:00, 7047.67iteration/s]
# Epoch: 1 	Training Loss: 23.200524 val loss: 18.492387
# Epoch: 2 	Training Loss: 23.147037 val loss: 18.457797
# saving, val loss enhanced: 18.457797378445726 18.47050563921761
# Epoch: 3 	Training Loss: 23.093637 val loss: 18.423266
# saving, val loss enhanced: 18.423266349207076 18.457797378445726
# Epoch: 4 	Training Loss: 23.040309 val loss: 18.388802
# saving, val loss enhanced: 18.38880228890754 18.423266349207076
# Epoch 2 time: 115.39 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:37<00:00, 113.40batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8214.41iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:30<00:00, 138.33batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10167.31iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 128.12batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8027.50iteration/s]
# Epoch: 1 	Training Loss: 23.030884 val loss: 18.415099
# Epoch: 2 	Training Loss: 22.978926 val loss: 18.381455
# saving, val loss enhanced: 18.381455159700327 18.38880228890754
# Epoch: 3 	Training Loss: 22.927063 val loss: 18.347865
# saving, val loss enhanced: 18.34786458583749 18.381455159700327
# Epoch: 4 	Training Loss: 22.875265 val loss: 18.314331
# saving, val loss enhanced: 18.31433117978251 18.34786458583749
# Epoch 3 time: 111.21 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.14batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10330.65iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:14<00:00, 295.71batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10135.38iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:06<00:00, 294.81batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 10263.82iteration/s]
# Epoch: 1 	Training Loss: 22.872488 val loss: 18.345302
# Epoch: 2 	Training Loss: 22.822006 val loss: 18.312552
# saving, val loss enhanced: 18.312551817619074 18.31433117978251
# Epoch: 3 	Training Loss: 22.771615 val loss: 18.279849
# saving, val loss enhanced: 18.279848796541323 18.312551817619074
# Epoch: 4 	Training Loss: 22.721280 val loss: 18.247195
# saving, val loss enhanced: 18.24719508304663 18.279848796541323
# Epoch 4 time: 80.59 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:13<00:00, 310.03batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10433.43iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.65batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10113.36iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 116.70batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 10392.13iteration/s]
# Epoch: 1 	Training Loss: 22.725577 val loss: 18.283134
# Epoch: 2 	Training Loss: 22.676502 val loss: 18.251225
# Epoch: 3 	Training Loss: 22.627510 val loss: 18.219357
# saving, val loss enhanced: 18.219357257165665 18.24719508304663
# Epoch: 4 	Training Loss: 22.578565 val loss: 18.187532
# saving, val loss enhanced: 18.18753238112153 18.219357257165665
# Epoch 5 time: 89.14 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:28<00:00, 152.32batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9413.40iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:29<00:00, 144.64batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 10740.24iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:13<00:00, 135.92batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9260.20iteration/s]
# Epoch: 1 	Training Loss: 22.589947 val loss: 18.228437
# Epoch: 2 	Training Loss: 22.542210 val loss: 18.197321
# Epoch: 3 	Training Loss: 22.494549 val loss: 18.166241
# saving, val loss enhanced: 18.166240533258776 18.18753238112153
# Epoch: 4 	Training Loss: 22.446928 val loss: 18.135198
# saving, val loss enhanced: 18.13519762114655 18.166240533258776
# Epoch 6 time: 96.06 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:27<00:00, 154.96batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10579.98iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [2.59090059+0.j         1.66846354-0.3665194j  1.66846354+0.3665194j
#  0.96355628-0.83103622j 0.96355628+0.83103622j 1.09151844+0.j
#  1.        +0.j         0.75233269-0.12004151j 0.75233269+0.12004151j
#  0.26567312+0.j        ]

# %%
#### Test 8 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: S-EDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:17<00:00, 69.61it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 0.774118 val loss: 0.739936
# saving, val loss enhanced: 0.739936148737369 10000
# Epoch: 2 	Training Loss: 0.706302 val loss: 0.677469
# saving, val loss enhanced: 0.6774685946824694 0.739936148737369
# Epoch: 3 	Training Loss: 0.649106 val loss: 0.624258
# saving, val loss enhanced: 0.6242584692545149 0.6774685946824694
# Epoch: 4 	Training Loss: 0.599208 val loss: 0.577965
# saving, val loss enhanced: 0.5779650807382434 0.6242584692545149
# Epoch: 5 	Training Loss: 0.555042 val loss: 0.537410
# saving, val loss enhanced: 0.5374104740711024 0.5779650807382434
# Epoch: 6 	Training Loss: 0.515478 val loss: 0.498870
# saving, val loss enhanced: 0.49886988500826074 0.5374104740711024
# Epoch: 7 	Training Loss: 0.479291 val loss: 0.463968
# saving, val loss enhanced: 0.46396778998100136 0.49886988500826074
# Epoch: 8 	Training Loss: 0.445427 val loss: 0.433675
# saving, val loss enhanced: 0.43367491068034775 0.46396778998100136
# Epoch: 9 	Training Loss: 0.413386 val loss: 0.400522
# saving, val loss enhanced: 0.400521641140667 0.43367491068034775
# Epoch: 10 	Training Loss: 0.381308 val loss: 0.370202
# saving, val loss enhanced: 0.3702020753803511 0.400521641140667
# Epoch: 11 	Training Loss: 0.351830 val loss: 0.341134
# saving, val loss enhanced: 0.3411343216471117 0.3702020753803511
# Epoch: 12 	Training Loss: 0.323748 val loss: 0.316518
# saving, val loss enhanced: 0.31651832437405986 0.3411343216471117
# Epoch: 13 	Training Loss: 0.299739 val loss: 0.294969
# saving, val loss enhanced: 0.2949693626629138 0.31651832437405986
# Epoch: 14 	Training Loss: 0.279075 val loss: 0.272231
# saving, val loss enhanced: 0.27223068749133034 0.2949693626629138
# Epoch: 15 	Training Loss: 0.260805 val loss: 0.257022
# saving, val loss enhanced: 0.2570218770080806 0.27223068749133034
# Epoch: 16 	Training Loss: 0.244998 val loss: 0.244652
# saving, val loss enhanced: 0.24465160618286894 0.2570218770080806
# Epoch: 17 	Training Loss: 0.232986 val loss: 0.232122
# saving, val loss enhanced: 0.23212226378264797 0.24465160618286894
# Epoch: 18 	Training Loss: 0.222557 val loss: 0.224485
# saving, val loss enhanced: 0.2244850120325828 0.23212226378264797
# Epoch: 19 	Training Loss: 0.216114 val loss: 0.217931
# saving, val loss enhanced: 0.2179313305483792 0.2244850120325828
# Epoch: 20 	Training Loss: 0.209163 val loss: 0.213242
# saving, val loss enhanced: 0.21324155050966223 0.2179313305483792
# Epoch: 21 	Training Loss: 0.205316 val loss: 0.208824
# saving, val loss enhanced: 0.20882359987585639 0.21324155050966223
# Epoch: 22 	Training Loss: 0.202574 val loss: 0.206686
# saving, val loss enhanced: 0.20668558767819747 0.20882359987585639
# Epoch: 23 	Training Loss: 0.199058 val loss: 0.203281
# saving, val loss enhanced: 0.2032811537359101 0.20668558767819747
# Epoch: 24 	Training Loss: 0.195868 val loss: 0.200873
# saving, val loss enhanced: 0.20087304545148205 0.2032811537359101
# Epoch: 25 	Training Loss: 0.194546 val loss: 0.200149
# saving, val loss enhanced: 0.2001489314757336 0.20087304545148205
# Epoch: 26 	Training Loss: 0.192276 val loss: 0.198439
# saving, val loss enhanced: 0.1984393186959275 0.2001489314757336
# Epoch: 27 	Training Loss: 0.190965 val loss: 0.197639
# saving, val loss enhanced: 0.19763925524233572 0.1984393186959275
# Epoch: 28 	Training Loss: 0.189746 val loss: 0.195489
# saving, val loss enhanced: 0.19548912452341716 0.19763925524233572
# Epoch: 29 	Training Loss: 0.187456 val loss: 0.193541
# saving, val loss enhanced: 0.19354106786181563 0.19548912452341716
# Epoch: 30 	Training Loss: 0.184701 val loss: 0.190529
# saving, val loss enhanced: 0.1905292906609735 0.19354106786181563
# Epoch: 31 	Training Loss: 0.183176 val loss: 0.189493
# saving, val loss enhanced: 0.18949336374200104 0.1905292906609735
# Epoch: 32 	Training Loss: 0.182202 val loss: 0.188186
# saving, val loss enhanced: 0.18818644634674442 0.18949336374200104
# Epoch: 33 	Training Loss: 0.180366 val loss: 0.188779
# Epoch: 34 	Training Loss: 0.178588 val loss: 0.184872
# saving, val loss enhanced: 0.18487175451163776 0.18818644634674442
# Epoch: 35 	Training Loss: 0.176731 val loss: 0.182571
# saving, val loss enhanced: 0.1825714512940491 0.18487175451163776
# Epoch: 36 	Training Loss: 0.175004 val loss: 0.178532
# saving, val loss enhanced: 0.17853191431231227 0.1825714512940491
# Epoch: 37 	Training Loss: 0.172169 val loss: 0.180131
# Epoch: 38 	Training Loss: 0.170887 val loss: 0.179619
# Epoch: 39 	Training Loss: 0.169407 val loss: 0.173650
# saving, val loss enhanced: 0.1736500525637842 0.17853191431231227
# Epoch: 40 	Training Loss: 0.166999 val loss: 0.172918
# saving, val loss enhanced: 0.17291755246913906 0.1736500525637842
# Epoch: 41 	Training Loss: 0.164525 val loss: 0.167739
# saving, val loss enhanced: 0.1677390164469824 0.17291755246913906
# Epoch: 42 	Training Loss: 0.163491 val loss: 0.170521
# Epoch: 43 	Training Loss: 0.161436 val loss: 0.169130
# Epoch: 44 	Training Loss: 0.158467 val loss: 0.168558
# Epoch: 45 	Training Loss: 0.156887 val loss: 0.165431
# saving, val loss enhanced: 0.16543086265559193 0.1677390164469824
# Epoch: 46 	Training Loss: 0.156940 val loss: 0.160419
# saving, val loss enhanced: 0.16041909177482966 0.16543086265559193
# Epoch: 47 	Training Loss: 0.154612 val loss: 0.162947
# Epoch: 48 	Training Loss: 0.152905 val loss: 0.158645
# saving, val loss enhanced: 0.15864535994136453 0.16041909177482966
# Epoch: 49 	Training Loss: 0.151573 val loss: 0.157357
# saving, val loss enhanced: 0.15735667439547632 0.15864535994136453
# Epoch: 50 	Training Loss: 0.149207 val loss: 0.157866
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 135.58batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:11<00:00, 7498.73iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:39<00:00, 109.93batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8340.49iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.380801 val loss: 1.467295
# saving, val loss enhanced: 1.4672951947418613 1000000000000000.0
# Epoch: 2 	Training Loss: 1.377098 val loss: 1.464733
# saving, val loss enhanced: 1.4647329986824973 1.4672951947418613
# Epoch: 3 	Training Loss: 1.373417 val loss: 1.462189
# saving, val loss enhanced: 1.4621893557702421 1.4647329986824973
# Epoch: 4 	Training Loss: 1.369739 val loss: 1.459661
# saving, val loss enhanced: 1.4596609896937778 1.4621893557702421
# Epoch 1 time: 52.08 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 127.60batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8821.01iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.400390 val loss: 1.486769
# Epoch: 2 	Training Loss: 1.396607 val loss: 1.484194
# Epoch: 3 	Training Loss: 1.392838 val loss: 1.481636
# Epoch: 4 	Training Loss: 1.389087 val loss: 1.479091
# Epoch 2 time: 45.71 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.97batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8335.98iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.418474 val loss: 1.504343
# Epoch: 2 	Training Loss: 1.414631 val loss: 1.501754
# Epoch: 3 	Training Loss: 1.410805 val loss: 1.499180
# Epoch: 4 	Training Loss: 1.406998 val loss: 1.496620
# Epoch 3 time: 48.32 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 135.99batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8998.35iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.435467 val loss: 1.520361
# Epoch: 2 	Training Loss: 1.431575 val loss: 1.517761
# Epoch: 3 	Training Loss: 1.427699 val loss: 1.515175
# Epoch: 4 	Training Loss: 1.423843 val loss: 1.512603
# Epoch 4 time: 43.54 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.16batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8141.07iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.451237 val loss: 1.534674
# Epoch: 2 	Training Loss: 1.447302 val loss: 1.532067
# Epoch: 3 	Training Loss: 1.443384 val loss: 1.529474
# Epoch: 4 	Training Loss: 1.439486 val loss: 1.526894
# Epoch 5 time: 47.98 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:39<00:00, 108.07batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:12<00:00, 6711.19iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 1.465592 val loss: 1.547066
# Epoch: 2 	Training Loss: 1.461622 val loss: 1.544457
# Epoch: 3 	Training Loss: 1.457669 val loss: 1.541861
# Epoch: 4 	Training Loss: 1.453736 val loss: 1.539279
# Epoch 6 time: 56.12 seconds
# (10,)
# [1.00000075+0.j         0.99160192+0.j         0.87998054+0.j
#  0.55240343-0.00835976j 0.55240343+0.00835976j 0.40107222+0.j
#  0.29168336+0.j         0.10752683+0.j         0.00270184+0.j
#  0.00173017+0.j        ]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:32<00:00, 132.69batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9311.38iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:28<00:00, 149.66batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8864.73iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.00batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9822.28iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 124.94batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8438.85iteration/s]
# Epoch: 1 	Training Loss: 13.990088 val loss: 16.619980
# saving, val loss enhanced: 16.61997953930409 1000000000000000.0
# Epoch: 2 	Training Loss: 13.967290 val loss: 16.599099
# saving, val loss enhanced: 16.59909914468755 16.61997953930409
# Epoch: 3 	Training Loss: 13.944673 val loss: 16.578410
# saving, val loss enhanced: 16.57841039421455 16.59909914468755
# Epoch: 4 	Training Loss: 13.922098 val loss: 16.557831
# saving, val loss enhanced: 16.557831150667987 16.57841039421455
# Epoch 1 time: 107.26 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 117.56batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10641.67iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 126.82batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9525.09iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:16<00:00, 110.12batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9841.49iteration/s]
# Epoch: 1 	Training Loss: 14.073567 val loss: 16.682366
# Epoch: 2 	Training Loss: 14.051788 val loss: 16.662495
# Epoch: 3 	Training Loss: 14.030025 val loss: 16.642643
# Epoch: 4 	Training Loss: 14.008265 val loss: 16.622811
# Epoch 2 time: 111.46 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.17batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8942.31iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.84batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9402.41iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:16<00:00, 111.75batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8461.99iteration/s]
# Epoch: 1 	Training Loss: 14.170065 val loss: 16.760732
# Epoch: 2 	Training Loss: 14.149073 val loss: 16.741510
# Epoch: 3 	Training Loss: 14.128094 val loss: 16.722289
# Epoch: 4 	Training Loss: 14.107111 val loss: 16.703072
# Epoch 3 time: 115.48 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:40<00:00, 105.31batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 7846.36iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 125.00batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9497.50iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:11<00:00, 154.88batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9253.10iteration/s]
# Epoch: 1 	Training Loss: 14.276378 val loss: 16.844265
# Epoch: 2 	Training Loss: 14.256141 val loss: 16.825637
# Epoch: 3 	Training Loss: 14.235915 val loss: 16.807004
# Epoch: 4 	Training Loss: 14.215680 val loss: 16.788368
# Epoch 4 time: 114.89 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 137.92batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:11<00:00, 7677.99iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:32<00:00, 131.05batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8228.05iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:17<00:00, 106.93batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 7991.13iteration/s]
# Epoch: 1 	Training Loss: 14.392808 val loss: 16.934016
# Epoch: 2 	Training Loss: 14.373308 val loss: 16.915957
# Epoch: 3 	Training Loss: 14.353818 val loss: 16.897891
# Epoch: 4 	Training Loss: 14.334314 val loss: 16.879818
# Epoch 5 time: 113.36 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:40<00:00, 106.21batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8103.13iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:18<00:00, 231.81batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9838.81iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 118.45batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8680.58iteration/s]
# Epoch: 1 	Training Loss: 14.519611 val loss: 17.030578
# Epoch: 2 	Training Loss: 14.500835 val loss: 17.013074
# Epoch: 3 	Training Loss: 14.482066 val loss: 16.995559
# Epoch: 4 	Training Loss: 14.463282 val loss: 16.978034
# Epoch 6 time: 102.17 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.28batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9534.56iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [4.50997302+0.j         1.85320188-1.19085233j 1.85320188+1.19085233j
#  1.32716031-0.28289892j 1.32716031+0.28289892j 1.02477782-0.64053399j
#  1.02477782+0.64053399j 1.00857925+0.j         1.        +0.j
#  0.82206444+0.j        ]

# %%
#### Test 9 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: S-EDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:18<00:00, 67.16it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 0.571883 val loss: 0.541914
# saving, val loss enhanced: 0.5419135203517483 10000
# Epoch: 2 	Training Loss: 0.539806 val loss: 0.512797
# saving, val loss enhanced: 0.5127974391915712 0.5419135203517483
# Epoch: 3 	Training Loss: 0.511770 val loss: 0.488650
# saving, val loss enhanced: 0.4886501940129098 0.5127974391915712
# Epoch: 4 	Training Loss: 0.486719 val loss: 0.464151
# saving, val loss enhanced: 0.46415085898326025 0.4886501940129098
# Epoch: 5 	Training Loss: 0.465293 val loss: 0.444515
# saving, val loss enhanced: 0.44451544017158745 0.46415085898326025
# Epoch: 6 	Training Loss: 0.444889 val loss: 0.426670
# saving, val loss enhanced: 0.4266702697876596 0.44451544017158745
# Epoch: 7 	Training Loss: 0.427109 val loss: 0.411283
# saving, val loss enhanced: 0.4112827584043461 0.4266702697876596
# Epoch: 8 	Training Loss: 0.412058 val loss: 0.396878
# saving, val loss enhanced: 0.39687813910479725 0.4112827584043461
# Epoch: 9 	Training Loss: 0.397343 val loss: 0.383598
# saving, val loss enhanced: 0.38359812147640954 0.39687813910479725
# Epoch: 10 	Training Loss: 0.384118 val loss: 0.372708
# saving, val loss enhanced: 0.37270849178220106 0.38359812147640954
# Epoch: 11 	Training Loss: 0.371848 val loss: 0.361410
# saving, val loss enhanced: 0.3614104673714459 0.37270849178220106
# Epoch: 12 	Training Loss: 0.360617 val loss: 0.351416
# saving, val loss enhanced: 0.35141581823852003 0.3614104673714459
# Epoch: 13 	Training Loss: 0.350342 val loss: 0.341134
# saving, val loss enhanced: 0.3411335375663007 0.35141581823852003
# Epoch: 14 	Training Loss: 0.340366 val loss: 0.331385
# saving, val loss enhanced: 0.33138531714694003 0.3411335375663007
# Epoch: 15 	Training Loss: 0.331380 val loss: 0.323873
# saving, val loss enhanced: 0.3238734042967455 0.33138531714694003
# Epoch: 16 	Training Loss: 0.322553 val loss: 0.315198
# saving, val loss enhanced: 0.31519795121666944 0.3238734042967455
# Epoch: 17 	Training Loss: 0.314591 val loss: 0.309244
# saving, val loss enhanced: 0.3092438032161809 0.31519795121666944
# Epoch: 18 	Training Loss: 0.305957 val loss: 0.296522
# saving, val loss enhanced: 0.2965219336341964 0.3092438032161809
# Epoch: 19 	Training Loss: 0.295860 val loss: 0.290974
# saving, val loss enhanced: 0.29097362094746615 0.2965219336341964
# Epoch: 20 	Training Loss: 0.286741 val loss: 0.280480
# saving, val loss enhanced: 0.2804797043878171 0.29097362094746615
# Epoch: 21 	Training Loss: 0.278827 val loss: 0.273584
# saving, val loss enhanced: 0.273583509267131 0.2804797043878171
# Epoch: 22 	Training Loss: 0.267650 val loss: 0.261713
# saving, val loss enhanced: 0.2617130954235917 0.273583509267131
# Epoch: 23 	Training Loss: 0.259554 val loss: 0.254900
# saving, val loss enhanced: 0.2549004210899107 0.2617130954235917
# Epoch: 24 	Training Loss: 0.250485 val loss: 0.245256
# saving, val loss enhanced: 0.2452556642022263 0.2549004210899107
# Epoch: 25 	Training Loss: 0.242009 val loss: 0.237247
# saving, val loss enhanced: 0.23724740414705656 0.2452556642022263
# Epoch: 26 	Training Loss: 0.234448 val loss: 0.230653
# saving, val loss enhanced: 0.2306525716638704 0.23724740414705656
# Epoch: 27 	Training Loss: 0.225105 val loss: 0.226353
# saving, val loss enhanced: 0.2263527031019115 0.2306525716638704
# Epoch: 28 	Training Loss: 0.219439 val loss: 0.215448
# saving, val loss enhanced: 0.2154480333252934 0.2263527031019115
# Epoch: 29 	Training Loss: 0.213271 val loss: 0.214101
# saving, val loss enhanced: 0.21410050907143396 0.2154480333252934
# Epoch: 30 	Training Loss: 0.208280 val loss: 0.205785
# saving, val loss enhanced: 0.20578497240572266 0.21410050907143396
# Epoch: 31 	Training Loss: 0.201937 val loss: 0.203285
# saving, val loss enhanced: 0.2032853133837211 0.20578497240572266
# Epoch: 32 	Training Loss: 0.196861 val loss: 0.199542
# saving, val loss enhanced: 0.19954157832825245 0.2032853133837211
# Epoch: 33 	Training Loss: 0.194784 val loss: 0.194875
# saving, val loss enhanced: 0.1948746376533987 0.19954157832825245
# Epoch: 34 	Training Loss: 0.190729 val loss: 0.191129
# saving, val loss enhanced: 0.19112944851518487 0.1948746376533987
# Epoch: 35 	Training Loss: 0.187532 val loss: 0.190492
# saving, val loss enhanced: 0.19049162666154582 0.19112944851518487
# Epoch: 36 	Training Loss: 0.184629 val loss: 0.187106
# saving, val loss enhanced: 0.1871056299401728 0.19049162666154582
# Epoch: 37 	Training Loss: 0.183385 val loss: 0.183125
# saving, val loss enhanced: 0.18312519886087547 0.1871056299401728
# Epoch: 38 	Training Loss: 0.180081 val loss: 0.181604
# saving, val loss enhanced: 0.18160365868172862 0.18312519886087547
# Epoch: 39 	Training Loss: 0.178324 val loss: 0.179758
# saving, val loss enhanced: 0.17975831412856308 0.18160365868172862
# Epoch: 40 	Training Loss: 0.177574 val loss: 0.178434
# saving, val loss enhanced: 0.17843398712735625 0.17975831412856308
# Epoch: 41 	Training Loss: 0.173806 val loss: 0.181948
# Epoch: 42 	Training Loss: 0.173023 val loss: 0.178329
# saving, val loss enhanced: 0.17832871859991206 0.17843398712735625
# Epoch: 43 	Training Loss: 0.170596 val loss: 0.176105
# saving, val loss enhanced: 0.17610487700787933 0.17832871859991206
# Epoch: 44 	Training Loss: 0.170303 val loss: 0.175203
# saving, val loss enhanced: 0.17520319726355796 0.17610487700787933
# Epoch: 45 	Training Loss: 0.167800 val loss: 0.171323
# saving, val loss enhanced: 0.17132299799836762 0.17520319726355796
# Epoch: 46 	Training Loss: 0.166825 val loss: 0.172443
# Epoch: 47 	Training Loss: 0.166473 val loss: 0.168507
# saving, val loss enhanced: 0.16850675866071324 0.17132299799836762
# Epoch: 48 	Training Loss: 0.166423 val loss: 0.169411
# Epoch: 49 	Training Loss: 0.164570 val loss: 0.167801
# saving, val loss enhanced: 0.16780066537987068 0.16850675866071324
# Epoch: 50 	Training Loss: 0.162489 val loss: 0.167343
# saving, val loss enhanced: 0.16734265162135276 0.16780066537987068
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 120.90batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8343.40iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 128.03batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8070.30iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.728864 val loss: 5.431533
# saving, val loss enhanced: 5.4315333539707025 1000000000000000.0
# Epoch: 2 	Training Loss: 3.720222 val loss: 5.425138
# saving, val loss enhanced: 5.425137745082229 5.4315333539707025
# Epoch: 3 	Training Loss: 3.711614 val loss: 5.418766
# saving, val loss enhanced: 5.418765699984003 5.425137745082229
# Epoch: 4 	Training Loss: 3.703019 val loss: 5.412416
# saving, val loss enhanced: 5.412415743985979 5.418765699984003
# Epoch 1 time: 46.99 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.46batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8015.61iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.686245 val loss: 5.201924
# saving, val loss enhanced: 5.201924287673341 5.412415743985979
# Epoch: 2 	Training Loss: 3.677287 val loss: 5.195243
# saving, val loss enhanced: 5.195242749790517 5.201924287673341
# Epoch: 3 	Training Loss: 3.668375 val loss: 5.188608
# saving, val loss enhanced: 5.18860817484461 5.195242749790517
# Epoch: 4 	Training Loss: 3.659516 val loss: 5.182014
# saving, val loss enhanced: 5.182013650093414 5.18860817484461
# Epoch 2 time: 49.40 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:32<00:00, 133.63batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8706.15iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.623421 val loss: 4.927974
# saving, val loss enhanced: 4.927974483226694 5.182013650093414
# Epoch: 2 	Training Loss: 3.614272 val loss: 4.921083
# saving, val loss enhanced: 4.9210826790640505 4.927974483226694
# Epoch: 3 	Training Loss: 3.605173 val loss: 4.914239
# saving, val loss enhanced: 4.914239261240059 4.9210826790640505
# Epoch: 4 	Training Loss: 3.596131 val loss: 4.907439
# saving, val loss enhanced: 4.907439113655199 4.914239261240059
# Epoch 3 time: 44.75 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.42batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8220.55iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.540900 val loss: 4.620487
# saving, val loss enhanced: 4.620487264387689 4.907439113655199
# Epoch: 2 	Training Loss: 3.531579 val loss: 4.613353
# saving, val loss enhanced: 4.613352657285305 4.620487264387689
# Epoch: 3 	Training Loss: 3.522310 val loss: 4.606268
# saving, val loss enhanced: 4.606267928274994 4.613352657285305
# Epoch: 4 	Training Loss: 3.513103 val loss: 4.599229
# saving, val loss enhanced: 4.5992291325552745 4.606267928274994
# Epoch 4 time: 49.15 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.09batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8869.16iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.436520 val loss: 4.315514
# saving, val loss enhanced: 4.315513653204499 4.5992291325552745
# Epoch: 2 	Training Loss: 3.427110 val loss: 4.308135
# saving, val loss enhanced: 4.308134621088307 4.315513653204499
# Epoch: 3 	Training Loss: 3.417755 val loss: 4.300807
# saving, val loss enhanced: 4.300806911389947 4.308134621088307
# Epoch: 4 	Training Loss: 3.408462 val loss: 4.293527
# saving, val loss enhanced: 4.293527211310798 4.300806911389947
# Epoch 5 time: 47.00 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.73batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9036.90iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.316234 val loss: 4.049029
# saving, val loss enhanced: 4.0490291545418176 4.293527211310798
# Epoch: 2 	Training Loss: 3.306855 val loss: 4.041445
# saving, val loss enhanced: 4.041445103872491 4.0490291545418176
# Epoch: 3 	Training Loss: 3.297530 val loss: 4.033912
# saving, val loss enhanced: 4.033911807297097 4.041445103872491
# Epoch: 4 	Training Loss: 3.288264 val loss: 4.026426
# saving, val loss enhanced: 4.026426484804501 4.033911807297097
# Epoch 6 time: 47.14 seconds
# (10,)
# [9.99995518e-01 9.91889125e-01 8.29431427e-01 5.06955372e-01
#  3.65617167e-01 2.94266844e-01 1.42964162e-01 2.88319770e-02
#  1.48078024e-03 5.70140955e-04]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.44batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10666.13iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 127.89batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 10730.43iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:30<00:00, 141.39batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9270.13iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 127.71batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8543.59iteration/s]
# Epoch: 1 	Training Loss: 58.867191 val loss: 58.902368
# saving, val loss enhanced: 58.90236776174571 1000000000000000.0
# Epoch: 2 	Training Loss: 58.744559 val loss: 58.822839
# saving, val loss enhanced: 58.82283882928055 58.90236776174571
# Epoch: 3 	Training Loss: 58.622292 val loss: 58.743703
# saving, val loss enhanced: 58.7437034011374 58.82283882928055
# Epoch: 4 	Training Loss: 58.500055 val loss: 58.664905
# saving, val loss enhanced: 58.664904770255525 58.7437034011374
# Epoch 1 time: 104.29 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.41batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9254.31iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.34batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9476.53iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 123.94batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9398.64iteration/s]
# Epoch: 1 	Training Loss: 58.056973 val loss: 58.271167
# saving, val loss enhanced: 58.27116708126237 58.664904770255525
# Epoch: 2 	Training Loss: 57.940321 val loss: 58.195988
# saving, val loss enhanced: 58.19598808369838 58.27116708126237
# Epoch: 3 	Training Loss: 57.823735 val loss: 58.120857
# saving, val loss enhanced: 58.12085679780557 58.19598808369838
# Epoch: 4 	Training Loss: 57.707160 val loss: 58.045805
# saving, val loss enhanced: 58.04580506829166 58.12085679780557
# Epoch 2 time: 111.82 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 126.05batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9679.28iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:29<00:00, 144.83batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9576.04iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 119.14batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8538.03iteration/s]
# Epoch: 1 	Training Loss: 57.269852 val loss: 57.647672
# saving, val loss enhanced: 57.647672430851635 58.04580506829166
# Epoch: 2 	Training Loss: 57.158701 val loss: 57.576024
# saving, val loss enhanced: 57.57602377131164 57.647672430851635
# Epoch: 3 	Training Loss: 57.047632 val loss: 57.504375
# saving, val loss enhanced: 57.50437509163722 57.57602377131164
# Epoch: 4 	Training Loss: 56.936535 val loss: 57.432746
# saving, val loss enhanced: 57.43274571323832 57.50437509163722
# Epoch 3 time: 105.01 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 120.86batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8951.32iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.32batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9695.53iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 123.19batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8975.17iteration/s]
# Epoch: 1 	Training Loss: 56.505359 val loss: 57.029990
# saving, val loss enhanced: 57.02999010328684 57.43274571323832
# Epoch: 2 	Training Loss: 56.399446 val loss: 56.961612
# saving, val loss enhanced: 56.96161232722224 57.02999010328684
# Epoch: 3 	Training Loss: 56.293599 val loss: 56.893210
# saving, val loss enhanced: 56.89320962030511 56.96161232722224
# Epoch: 4 	Training Loss: 56.187693 val loss: 56.824793
# saving, val loss enhanced: 56.82479281368647 56.89320962030511
# Epoch 4 time: 112.35 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.57batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 10957.01iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 121.85batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9438.58iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 121.48batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8633.04iteration/s]
# Epoch: 1 	Training Loss: 55.761192 val loss: 56.417470
# saving, val loss enhanced: 56.417469588099074 56.82479281368647
# Epoch: 2 	Training Loss: 55.660239 val loss: 56.352171
# saving, val loss enhanced: 56.352170710978044 56.417469588099074
# Epoch: 3 	Training Loss: 55.559331 val loss: 56.286828
# saving, val loss enhanced: 56.28682838399941 56.352170710978044
# Epoch: 4 	Training Loss: 55.458337 val loss: 56.221448
# saving, val loss enhanced: 56.221448164656 56.28682838399941
# Epoch 5 time: 111.40 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 126.61batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10472.93iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.60batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10698.69iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 124.02batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 9087.49iteration/s]
# Epoch: 1 	Training Loss: 55.035280 val loss: 55.810004
# saving, val loss enhanced: 55.810003962508766 56.221448164656
# Epoch: 2 	Training Loss: 54.939025 val loss: 55.747620
# saving, val loss enhanced: 55.74761978188164 55.810003962508766
# Epoch: 3 	Training Loss: 54.842795 val loss: 55.685177
# saving, val loss enhanced: 55.68517693764951 55.74761978188164
# Epoch: 4 	Training Loss: 54.746456 val loss: 55.622678
# saving, val loss enhanced: 55.62267751839668 55.68517693764951
# Epoch 6 time: 108.40 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 119.92batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10537.59iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [2.78308279-1.42278702j 2.78308279+1.42278702j 1.35629517-0.92055749j
#  1.35629517+0.92055749j 1.27709917+0.19878214j 1.27709917-0.19878214j
#  1.00203184+0.j         1.        +0.j         0.63776295-0.33590518j
#  0.63776295+0.33590518j]

# %%
#### Test 10 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 35

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: S-EDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 1225/1225 [00:17<00:00, 69.51it/s]
# Shape of data_X: (1225, 10, 2)
# Shape of data_Y: (1225, 10, 2)
# Shape of X: (12250, 2)
# Shape of Y: (12250, 2)
# (8575, 2)
# Epoch: 1 	Training Loss: 1.310482 val loss: 1.156368
# saving, val loss enhanced: 1.156368087497416 10000
# Epoch: 2 	Training Loss: 1.154393 val loss: 1.016931
# saving, val loss enhanced: 1.0169310351747876 1.156368087497416
# Epoch: 3 	Training Loss: 1.019785 val loss: 0.899859
# saving, val loss enhanced: 0.8998593379813485 1.0169310351747876
# Epoch: 4 	Training Loss: 0.899606 val loss: 0.804689
# saving, val loss enhanced: 0.8046891202713052 0.8998593379813485
# Epoch: 5 	Training Loss: 0.803019 val loss: 0.710854
# saving, val loss enhanced: 0.7108541973100602 0.8046891202713052
# Epoch: 6 	Training Loss: 0.712154 val loss: 0.640784
# saving, val loss enhanced: 0.640783717478342 0.7108541973100602
# Epoch: 7 	Training Loss: 0.636677 val loss: 0.566227
# saving, val loss enhanced: 0.5662269386504293 0.640783717478342
# Epoch: 8 	Training Loss: 0.571885 val loss: 0.510900
# saving, val loss enhanced: 0.5109001787210017 0.5662269386504293
# Epoch: 9 	Training Loss: 0.507275 val loss: 0.454882
# saving, val loss enhanced: 0.4548816428648183 0.5109001787210017
# Epoch: 10 	Training Loss: 0.457907 val loss: 0.405605
# saving, val loss enhanced: 0.4056052407760529 0.4548816428648183
# Epoch: 11 	Training Loss: 0.409250 val loss: 0.371175
# saving, val loss enhanced: 0.37117482635114546 0.4056052407760529
# Epoch: 12 	Training Loss: 0.369206 val loss: 0.333427
# saving, val loss enhanced: 0.33342667594663905 0.37117482635114546
# Epoch: 13 	Training Loss: 0.333443 val loss: 0.306770
# saving, val loss enhanced: 0.30676984887939984 0.33342667594663905
# Epoch: 14 	Training Loss: 0.310187 val loss: 0.279594
# saving, val loss enhanced: 0.27959364830340644 0.30676984887939984
# Epoch: 15 	Training Loss: 0.282542 val loss: 0.260510
# saving, val loss enhanced: 0.26050954262608267 0.27959364830340644
# Epoch: 16 	Training Loss: 0.263741 val loss: 0.247070
# saving, val loss enhanced: 0.24707039714795995 0.26050954262608267
# Epoch: 17 	Training Loss: 0.246449 val loss: 0.229689
# saving, val loss enhanced: 0.22968932589681357 0.24707039714795995
# Epoch: 18 	Training Loss: 0.234296 val loss: 0.218156
# saving, val loss enhanced: 0.21815642414107406 0.22968932589681357
# Epoch: 19 	Training Loss: 0.219734 val loss: 0.204949
# saving, val loss enhanced: 0.20494903623508043 0.21815642414107406
# Epoch: 20 	Training Loss: 0.212312 val loss: 0.193697
# saving, val loss enhanced: 0.1936968993484191 0.20494903623508043
# Epoch: 21 	Training Loss: 0.202969 val loss: 0.192076
# saving, val loss enhanced: 0.19207629665449202 0.1936968993484191
# Epoch: 22 	Training Loss: 0.193469 val loss: 0.181048
# saving, val loss enhanced: 0.18104750111637313 0.19207629665449202
# Epoch: 23 	Training Loss: 0.187953 val loss: 0.180076
# saving, val loss enhanced: 0.1800763089456472 0.18104750111637313
# Epoch: 24 	Training Loss: 0.183102 val loss: 0.173422
# saving, val loss enhanced: 0.17342165220550754 0.1800763089456472
# Epoch: 25 	Training Loss: 0.178288 val loss: 0.166402
# saving, val loss enhanced: 0.16640175189430184 0.17342165220550754
# Epoch: 26 	Training Loss: 0.176319 val loss: 0.165940
# saving, val loss enhanced: 0.1659403677418789 0.16640175189430184
# Epoch: 27 	Training Loss: 0.169936 val loss: 0.162701
# saving, val loss enhanced: 0.16270103945530084 0.1659403677418789
# Epoch: 28 	Training Loss: 0.166384 val loss: 0.158011
# saving, val loss enhanced: 0.1580111864231422 0.16270103945530084
# Epoch: 29 	Training Loss: 0.162530 val loss: 0.157272
# saving, val loss enhanced: 0.1572721207536403 0.1580111864231422
# Epoch: 30 	Training Loss: 0.162920 val loss: 0.156097
# saving, val loss enhanced: 0.15609673620283687 0.1572721207536403
# Epoch: 31 	Training Loss: 0.158387 val loss: 0.150760
# saving, val loss enhanced: 0.15076034122207638 0.15609673620283687
# Epoch: 32 	Training Loss: 0.156565 val loss: 0.151762
# Epoch: 33 	Training Loss: 0.153944 val loss: 0.148495
# saving, val loss enhanced: 0.14849465473142673 0.15076034122207638
# Epoch: 34 	Training Loss: 0.154457 val loss: 0.147183
# saving, val loss enhanced: 0.1471832614250693 0.14849465473142673
# Epoch: 35 	Training Loss: 0.152110 val loss: 0.144198
# saving, val loss enhanced: 0.1441976432905677 0.1471832614250693
# Epoch: 36 	Training Loss: 0.150138 val loss: 0.144573
# Epoch: 37 	Training Loss: 0.146787 val loss: 0.144176
# saving, val loss enhanced: 0.14417611891084028 0.1441976432905677
# Epoch: 38 	Training Loss: 0.147385 val loss: 0.144481
# Epoch: 39 	Training Loss: 0.146330 val loss: 0.138937
# saving, val loss enhanced: 0.1389374538727696 0.14417611891084028
# Epoch: 40 	Training Loss: 0.147336 val loss: 0.140964
# Epoch: 41 	Training Loss: 0.145562 val loss: 0.137829
# saving, val loss enhanced: 0.13782890882289214 0.1389374538727696
# Epoch: 42 	Training Loss: 0.144396 val loss: 0.139405
# Epoch: 43 	Training Loss: 0.144106 val loss: 0.141771
# Epoch: 44 	Training Loss: 0.143196 val loss: 0.137277
# saving, val loss enhanced: 0.1372773374143588 0.13782890882289214
# Epoch: 45 	Training Loss: 0.143391 val loss: 0.139862
# Epoch: 46 	Training Loss: 0.142520 val loss: 0.139716
# Epoch: 47 	Training Loss: 0.142657 val loss: 0.138115
# Epoch: 48 	Training Loss: 0.141852 val loss: 0.136255
# saving, val loss enhanced: 0.13625456096299002 0.1372773374143588
# Epoch: 49 	Training Loss: 0.140673 val loss: 0.133483
# saving, val loss enhanced: 0.13348253251772668 0.13625456096299002
# Epoch: 50 	Training Loss: 0.142346 val loss: 0.136820
# a_Xt: torch.Size([8574, 2])
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 122.46batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8474.97iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# saving FNN a and b to:  a_b_example_3ple_well.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.91batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8427.13iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 9.712782 val loss: 10.346921
# saving, val loss enhanced: 10.346921360503856 1000000000000000.0
# Epoch: 2 	Training Loss: 9.686387 val loss: 10.321609
# saving, val loss enhanced: 10.321608550401724 10.346921360503856
# Epoch: 3 	Training Loss: 9.660288 val loss: 10.296590
# saving, val loss enhanced: 10.296589736776328 10.321608550401724
# Epoch: 4 	Training Loss: 9.634298 val loss: 10.271768
# saving, val loss enhanced: 10.271767553243459 10.296589736776328
# Epoch 1 time: 47.52 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 129.43batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9414.03iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 9.140517 val loss: 9.830874
# saving, val loss enhanced: 9.8308742765706 10.271767553243459
# Epoch: 2 	Training Loss: 9.117169 val loss: 9.808495
# saving, val loss enhanced: 9.808495333999875 9.8308742765706
# Epoch: 3 	Training Loss: 9.093804 val loss: 9.786090
# saving, val loss enhanced: 9.78609003471492 9.808495333999875
# Epoch: 4 	Training Loss: 9.070379 val loss: 9.763680
# saving, val loss enhanced: 9.763680273903217 9.78609003471492
# Epoch 2 time: 44.59 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 118.27batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9515.32iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 8.631370 val loss: 9.372596
# saving, val loss enhanced: 9.37259596229637 9.763680273903217
# Epoch: 2 	Training Loss: 8.610112 val loss: 9.352188
# saving, val loss enhanced: 9.352187855480894 9.37259596229637
# Epoch: 3 	Training Loss: 8.588830 val loss: 9.331733
# saving, val loss enhanced: 9.33173265004057 9.352187855480894
# Epoch: 4 	Training Loss: 8.567474 val loss: 9.311243
# saving, val loss enhanced: 9.311243033034467 9.33173265004057
# Epoch 3 time: 47.76 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.23batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:10<00:00, 8357.59iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 8.184915 val loss: 8.973395
# saving, val loss enhanced: 8.973395137893023 9.311243033034467
# Epoch: 2 	Training Loss: 8.165382 val loss: 8.954588
# saving, val loss enhanced: 8.954587921759883 8.973395137893023
# Epoch: 3 	Training Loss: 8.145824 val loss: 8.935731
# saving, val loss enhanced: 8.935730814909618 8.954587921759883
# Epoch: 4 	Training Loss: 8.126189 val loss: 8.916831
# saving, val loss enhanced: 8.916830820052208 8.935730814909618
# Epoch 4 time: 47.35 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.27batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9063.79iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 7.798496 val loss: 8.630673
# saving, val loss enhanced: 8.630673216211699 8.916830820052208
# Epoch: 2 	Training Loss: 7.780391 val loss: 8.613186
# saving, val loss enhanced: 8.613185551102816 8.630673216211699
# Epoch: 3 	Training Loss: 7.762257 val loss: 8.595649
# saving, val loss enhanced: 8.595649036634114 8.613185551102816
# Epoch: 4 	Training Loss: 7.744050 val loss: 8.578068
# saving, val loss enhanced: 8.578067605572693 8.595649036634114
# Epoch 5 time: 46.68 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 4288/4288 [00:31<00:00, 136.38batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9291.25iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 7.455806 val loss: 8.328097
# saving, val loss enhanced: 8.328097456985269 8.578067605572693
# Epoch: 2 	Training Loss: 7.438925 val loss: 8.311742
# saving, val loss enhanced: 8.311742136936049 8.328097456985269
# Epoch: 3 	Training Loss: 7.422014 val loss: 8.295339
# saving, val loss enhanced: 8.295339300188875 8.311742136936049
# Epoch: 4 	Training Loss: 7.405032 val loss: 8.278891
# saving, val loss enhanced: 8.278891030250186 8.295339300188875
# Epoch 6 time: 42.95 seconds
# (10,)
# [1.00000225e+00 9.90949897e-01 8.58804994e-01 5.91850642e-01
#  4.93292806e-01 3.56192348e-01 2.82146624e-01 5.89223498e-02
#  1.21244012e-02 8.55454570e-05]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[10], n_psi_train=7).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 122.54batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9382.98iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# Outer Epoch 1/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.86batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:07<00:00, 11131.62iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 123.13batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9615.79iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 121.45batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 9039.54iteration/s]
# Epoch: 1 	Training Loss: 43.235027 val loss: 40.652531
# saving, val loss enhanced: 40.652531008283304 1000000000000000.0
# Epoch: 2 	Training Loss: 43.132883 val loss: 40.590659
# saving, val loss enhanced: 40.59065869341655 40.652531008283304
# Epoch: 3 	Training Loss: 43.031348 val loss: 40.529082
# saving, val loss enhanced: 40.529081638316626 40.59065869341655
# Epoch: 4 	Training Loss: 42.930119 val loss: 40.467781
# saving, val loss enhanced: 40.46778056467794 40.529081638316626
# Epoch 1 time: 108.90 seconds
# Outer Epoch 2/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 126.24batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9912.45iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 125.02batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 9643.09iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:14<00:00, 123.35batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9555.60iteration/s]
# Epoch: 1 	Training Loss: 42.839950 val loss: 40.665953
# Epoch: 2 	Training Loss: 42.744033 val loss: 40.607712
# Epoch: 3 	Training Loss: 42.648276 val loss: 40.549522
# Epoch: 4 	Training Loss: 42.552602 val loss: 40.491412
# Epoch 2 time: 107.86 seconds
# Outer Epoch 3/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:33<00:00, 127.27batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:08<00:00, 10470.58iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:39<00:00, 108.03batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9150.85iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 119.37batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8617.72iteration/s]
# Epoch: 1 	Training Loss: 42.515649 val loss: 40.692473
# Epoch: 2 	Training Loss: 42.424702 val loss: 40.637084
# Epoch: 3 	Training Loss: 42.333889 val loss: 40.581696
# Epoch: 4 	Training Loss: 42.243100 val loss: 40.526326
# Epoch 3 time: 115.29 seconds
# Outer Epoch 4/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:36<00:00, 116.76batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9134.48iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:35<00:00, 120.61batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8954.66iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:15<00:00, 120.40batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:03<00:00, 9595.98iteration/s]
# Epoch: 1 	Training Loss: 42.185182 val loss: 40.688349
# Epoch: 2 	Training Loss: 42.098968 val loss: 40.635600
# Epoch: 3 	Training Loss: 42.012853 val loss: 40.582814
# Epoch: 4 	Training Loss: 41.926709 val loss: 40.530001
# Epoch 4 time: 114.12 seconds
# Outer Epoch 5/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 125.07batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8724.61iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:27<00:00, 153.89batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9310.49iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:09<00:00, 191.32batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8537.62iteration/s]
# Epoch: 1 	Training Loss: 41.816602 val loss: 40.627259
# Epoch: 2 	Training Loss: 41.735000 val loss: 40.577048
# Epoch: 3 	Training Loss: 41.653460 val loss: 40.526770
# Epoch: 4 	Training Loss: 41.571846 val loss: 40.476432
# Epoch 5 time: 99.32 seconds
# Outer Epoch 6/6
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:22<00:00, 191.36batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8699.95iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:24<00:00, 173.32batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 8949.99iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 1837/1837 [00:13<00:00, 139.09batch/s]
# Computing dPsi_X: 100%|██████████| 36730/36730 [00:04<00:00, 8569.10iteration/s]
# Epoch: 1 	Training Loss: 41.411827 val loss: 40.512813
# Epoch: 2 	Training Loss: 41.334704 val loss: 40.465059
# saving, val loss enhanced: 40.46505872383541 40.46778056467794
# Epoch: 3 	Training Loss: 41.257614 val loss: 40.417218
# saving, val loss enhanced: 40.417218414956835 40.46505872383541
# Epoch: 4 	Training Loss: 41.180414 val loss: 40.369296
# saving, val loss enhanced: 40.36929594323832 40.417218414956835
# Epoch 6 time: 88.38 seconds
# cuda:0
# Processing batches: 100%|██████████| 4288/4288 [00:34<00:00, 124.08batch/s]
# Computing dPsi_X: 100%|██████████| 85740/85740 [00:09<00:00, 9158.86iteration/s]
# dPsi_X shape:  torch.Size([8574, 10])
# psi_x shape:  torch.Size([8574, 10])
# psi_x_inv shape:  torch.Size([10, 8574])
# cuda:0
# cuda:0
# (10,)
# [2.82281271-1.27110385j 2.82281271+1.27110385j 3.02633733+0.j
#  1.19378471-0.87328646j 1.19378471+0.87328646j 1.43593144+0.j
#  1.02121937+0.j         1.01705486+0.j         1.        +0.j
#  0.38335668+0.j        ]
