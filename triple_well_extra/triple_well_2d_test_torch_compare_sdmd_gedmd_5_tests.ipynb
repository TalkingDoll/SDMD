# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import cm
from tqdm import tqdm
import os
import torch
torch.cuda.empty_cache()
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from numpy import linalg as la
from numpy import *
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#from solver_sdmd_torch_gpu import KoopmanNNTorch, KoopmanSolverTorch
from solver_sdmd_torch_gpu import KoopmanNNTorch, KoopmanSolverTorch
from solver_gedmd_torch_gpu import KoopmanNNTorch as KoopmanNNTorch_g
from solver_gedmd_torch_gpu import  KoopmanSolverTorch as KoopmanSolverTorch_g
print (torch.__version__, torch.cuda.is_available())
print(torch.version.cuda)
print (torch.cuda.get_device_name())
# device= 'cpu'
device= 'cuda'
# Out:
# 2.5.1 True
# 12.4
# NVIDIA A40

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# ## Test 1 ##

# %%
#### Test 1 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 25

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 625/625 [00:08<00:00, 72.59it/s]
# Shape of data_X: (625, 10, 2)
# Shape of data_Y: (625, 10, 2)
# Shape of X: (6250, 2)
# Shape of Y: (6250, 2)
# (4375, 2)
# Epoch: 1 	Training Loss: 0.877457 val loss: 0.855144
# saving, val loss enhanced: 0.8551444456630074 10000
# Epoch: 2 	Training Loss: 0.847173 val loss: 0.825772
# saving, val loss enhanced: 0.8257716812341043 0.8551444456630074
# Epoch: 3 	Training Loss: 0.820295 val loss: 0.798390
# saving, val loss enhanced: 0.7983897902592288 0.8257716812341043
# Epoch: 4 	Training Loss: 0.791551 val loss: 0.772971
# saving, val loss enhanced: 0.7729712700613915 0.7983897902592288
# Epoch: 5 	Training Loss: 0.765733 val loss: 0.746611
# saving, val loss enhanced: 0.7466113633097425 0.7729712700613915
# Epoch: 6 	Training Loss: 0.741556 val loss: 0.720003
# saving, val loss enhanced: 0.7200028398614223 0.7466113633097425
# Epoch: 7 	Training Loss: 0.716925 val loss: 0.695860
# saving, val loss enhanced: 0.695859637174816 0.7200028398614223
# Epoch: 8 	Training Loss: 0.693817 val loss: 0.673964
# saving, val loss enhanced: 0.6739643056281326 0.695859637174816
# Epoch: 9 	Training Loss: 0.672309 val loss: 0.652951
# saving, val loss enhanced: 0.6529512832511266 0.6739643056281326
# Epoch: 10 	Training Loss: 0.651083 val loss: 0.630622
# saving, val loss enhanced: 0.6306223740185339 0.6529512832511266
# Epoch: 11 	Training Loss: 0.632111 val loss: 0.613155
# saving, val loss enhanced: 0.6131547282617215 0.6306223740185339
# Epoch: 12 	Training Loss: 0.612822 val loss: 0.594225
# saving, val loss enhanced: 0.5942245559165085 0.6131547282617215
# Epoch: 13 	Training Loss: 0.595002 val loss: 0.575637
# saving, val loss enhanced: 0.5756369994796339 0.5942245559165085
# Epoch: 14 	Training Loss: 0.577010 val loss: 0.559311
# saving, val loss enhanced: 0.559311191430924 0.5756369994796339
# Epoch: 15 	Training Loss: 0.561400 val loss: 0.543809
# saving, val loss enhanced: 0.5438094890294961 0.559311191430924
# Epoch: 16 	Training Loss: 0.546769 val loss: 0.530192
teration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 65.582474 val loss: 128.606359
# saving, val loss enhanced: 128.6063592677867 129.45001424700664
# Epoch: 2 	Training Loss: 65.401770 val loss: 128.250271
# saving, val loss enhanced: 128.2502707936853 128.6063592677867
# Epoch: 3 	Training Loss: 65.221798 val loss: 127.895432
# saving, val loss enhanced: 127.89543225365526 128.2502707936853
# Epoch: 4 	Training Loss: 65.042421 val loss: 127.541557
# saving, val loss enhanced: 127.54155684588471 127.89543225365526
# Epoch 10 time: 28.70 seconds
# (15,)
# [1.00000251e+00 9.93192303e-01 8.73805473e-01 5.61858204e-01
#  5.47918819e-01 3.33275670e-01 2.48580213e-01 1.33416515e-01
#  6.15473671e-02 1.43489085e-02 1.00916319e-02 2.19369081e-03
#  8.63797833e-05 5.93672332e-06 3.98587495e-07]
# /workspace/solver_edmd_torch_gpu_sde.py:684: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(self.checkpoint_file)

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:20<00:00, 107.24batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:05<00:00, 11655.70iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Outer Epoch 1/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 92.44batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:05<00:00, 11027.42iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.33batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9874.20iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 99.49batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9721.85iteration/s]
# Epoch: 1 	Training Loss: 3.973382 val loss: 16.710437
# saving, val loss enhanced: 16.71043742309146 1000000000000000.0
# Epoch: 2 	Training Loss: 3.964690 val loss: 16.679569
# saving, val loss enhanced: 16.679568525682377 16.71043742309146
# /workspace/solver_gedmd_torch_gpu.py:309: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_file)
# Epoch: 3 	Training Loss: 3.956996 val loss: 16.649508
# saving, val loss enhanced: 16.649508035460446 16.679568525682377
# Epoch: 4 	Training Loss: 3.949471 val loss: 16.620012
# saving, val loss enhanced: 16.620011722425716 16.649508035460446
# Epoch 1 time: 73.58 seconds
# Outer Epoch 2/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 96.01batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9495.65iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.01batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9872.85iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 99.93batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9489.49iteration/s]
# Epoch: 1 	Training Loss: 3.913384 val loss: 16.452346
# saving, val loss enhanced: 16.452346006268844 16.620011722425716
# Epoch: 2 	Training Loss: 3.906190 val loss: 16.424340
# saving, val loss enhanced: 16.424339693685518 16.452346006268844
# Epoch: 3 	Training Loss: 3.899046 val loss: 16.396499
# saving, val loss enhanced: 16.396498930749253 16.424339693685518
# Epoch: 4 	Training Loss: 3.891931 val loss: 16.368767
# saving, val loss enhanced: 16.368766958790545 16.396498930749253
# Epoch 2 time: 73.32 seconds
# Outer Epoch 3/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.32batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9842.05iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.13batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9515.53iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:08<00:00, 115.01batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 11730.08iteration/s]
# Epoch: 1 	Training Loss: 3.859224 val loss: 16.218994
# saving, val loss enhanced: 16.21899433056986 16.368766958790545
# Epoch: 2 	Training Loss: 3.852307 val loss: 16.192215
# saving, val loss enhanced: 16.192215074224627 16.21899433056986
# Epoch: 3 	Training Loss: 3.845417 val loss: 16.165508
# saving, val loss enhanced: 16.16550803411896 16.192215074224627
# Epoch: 4 	Training Loss: 3.838542 val loss: 16.138843
# saving, val loss enhanced: 16.138843308490802 16.16550803411896
# Epoch 3 time: 71.23 seconds
# Outer Epoch 4/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.31batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9530.40iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.76batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 10704.15iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 99.11batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 
ch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9432.86iteration/s]
# Epoch: 1 	Training Loss: 3.569997 val loss: 14.972136
# saving, val loss enhanced: 14.972135972105303 15.09743224262703
# Epoch: 2 	Training Loss: 3.564099 val loss: 14.949860
# saving, val loss enhanced: 14.949860331552909 14.972135972105303
# Epoch: 3 	Training Loss: 3.558215 val loss: 14.927604
# saving, val loss enhanced: 14.927604090343221 14.949860331552909
# Epoch: 4 	Training Loss: 3.552335 val loss: 14.905345
# saving, val loss enhanced: 14.905345308070865 14.927604090343221
# Epoch 9 time: 74.88 seconds
# Outer Epoch 10/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 94.20batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9072.13iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 96.28batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:05<00:00, 11613.53iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 95.77batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9745.12iteration/s]
# Epoch: 1 	Training Loss: 3.526229 val loss: 14.782367
# saving, val loss enhanced: 14.7823670950697 14.905345308070865
# Epoch: 2 	Training Loss: 3.520469 val loss: 14.760698
# saving, val loss enhanced: 14.760697528071733 14.7823670950697
# /workspace/solver_gedmd_torch_gpu.py:696: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(self.checkpoint_file)
# Epoch: 3 	Training Loss: 3.514722 val loss: 14.739045
# saving, val loss enhanced: 14.73904525499064 14.760697528071733
# Epoch: 4 	Training Loss: 3.508979 val loss: 14.717389
# saving, val loss enhanced: 14.717388804936176 14.73904525499064
# Epoch 10 time: 73.69 seconds
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 93.58batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8732.86iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# (15,)
# [2.2289812 +0.00000000e+00j 1.36983935+0.00000000e+00j
#  1.24185559+5.48028958e-01j 1.24185559-5.48028958e-01j
#  1.08264021-3.24395864e-01j 1.08264021+3.24395864e-01j
#  1.05683381+0.00000000e+00j 0.36325028+9.67988605e-01j
#  0.36325028-9.67988605e-01j 1.02322022+0.00000000e+00j
#  1.        +0.00000000e+00j 0.99999834+4.94043193e-04j
#  0.99999834-4.94043193e-04j 0.99648331+0.00000000e+00j
#  0.76702144+0.00000000e+00j]

# %% [markdown]
# ## Test 2 ##

# %%
#### Test 2 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 25

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 625/625 [00:08<00:00, 72.58it/s]
# Shape of data_X: (625, 10, 2)
# Shape of data_Y: (625, 10, 2)
# Shape of X: (6250, 2)
# Shape of Y: (6250, 2)
# (4375, 2)
# Epoch: 1 	Training Loss: 0.994715 val loss: 0.971084
# saving, val loss enhanced: 0.9710840978876475 10000
# Epoch: 2 	Training Loss: 0.943543 val loss: 0.915005
# saving, val loss enhanced: 0.9150050366277913 0.9710840978876475
# Epoch: 3 	Training Loss: 0.892505 val loss: 0.870663
# saving, val loss enhanced: 0.8706625018283937 0.9150050366277913
# Epoch: 4 	Training Loss: 0.847860 val loss: 0.823825
# saving, val loss enhanced: 0.8238249428784628 0.8706625018283937
# Epoch: 5 	Training Loss: 0.801777 val loss: 0.777418
# saving, val loss enhanced: 0.7774178399866014 0.8238249428784628
# Epoch: 6 	Training Loss: 0.762142 val loss: 0.742121
# saving, val loss enhanced: 0.742121027827677 0.7774178399866014
# Epoch: 7 	Training Loss: 0.727729 val loss: 0.707505
# saving, val loss enhanced: 0.7075054126594517 0.742121027827677
# Epoch: 8 	Training Loss: 0.686097 val loss: 0.668301
# saving, val loss enhanced: 0.6683008396298683 0.7075054126594517
ch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8400.72iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 254.916666 val loss: 246.669410
# saving, val loss enhanced: 246.66940970719997 268.5118949518534
# Epoch: 2 	Training Loss: 254.321717 val loss: 246.263684
# saving, val loss enhanced: 246.26368418071036 246.66940970719997
# Epoch: 3 	Training Loss: 253.728161 val loss: 245.856025
# saving, val loss enhanced: 245.85602506894548 246.26368418071036
# Epoch: 4 	Training Loss: 253.130541 val loss: 245.444908
# saving, val loss enhanced: 245.44490819124064 245.85602506894548
# Epoch 9 time: 33.84 seconds
# Outer Epoch 10/10
# Processing batches: 100%|██████████| 2188/2188 [00:21<00:00, 100.76batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8757.78iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 239.030712 val loss: 226.894719
# saving, val loss enhanced: 226.89471924500305 245.44490819124064
# Epoch: 2 	Training Loss: 238.486640 val loss: 226.527270
# saving, val loss enhanced: 226.52727046973195 226.89471924500305
# Epoch: 3 	Training Loss: 237.943666 val loss: 226.158120
# saving, val loss enhanced: 226.15811999142264 226.52727046973195
# Epoch: 4 	Training Loss: 237.397141 val loss: 225.785986
# saving, val loss enhanced: 225.78598585723196 226.15811999142264
# Epoch 10 time: 30.83 seconds
# (15,)
# [9.99999462e-01 9.95754068e-01 8.43015314e-01 5.47299585e-01
#  5.31218821e-01 3.63793992e-01 2.77872461e-01 9.82377025e-02
#  4.23070394e-02 9.85109683e-03 2.61746336e-03 4.00780528e-04
#  5.99840946e-05 6.64034668e-06 4.73096321e-07]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 93.99batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9579.69iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Outer Epoch 1/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:20<00:00, 104.22batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9560.12iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:20<00:00, 104.30batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9867.97iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 102.86batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 8255.69iteration/s]
# Epoch: 1 	Training Loss: 10.355725 val loss: 39.561061
# saving, val loss enhanced: 39.56106071866397 1000000000000000.0
# Epoch: 2 	Training Loss: 10.327990 val loss: 39.465651
# saving, val loss enhanced: 39.465651121217256 39.56106071866397
# Epoch: 3 	Training Loss: 10.302272 val loss: 39.372093
# saving, val loss enhanced: 39.372093160975076 39.465651121217256
# Epoch: 4 	Training Loss: 10.277044 val loss: 39.279989
# saving, val loss enhanced: 39.2799891625181 39.372093160975076
# Epoch 1 time: 70.82 seconds
# Outer Epoch 2/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:21<00:00, 99.64batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9057.16iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 96.23batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9331.16iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 97.33batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9759.85iteration/s]
# Epoch: 1 	Training Loss: 10.182812 val loss: 38.920473
# saving, val loss enhanced: 38.920473361080006 39.2799891625181
# Epoch: 2 	Training Loss: 10.158611 val loss: 38.831966
# saving, val loss enhanced: 38.83196631841515 38.920473361080006
# Epoch: 3 	Training Loss: 10.134592 val loss: 38.743948
# saving, val loss enhanced: 38.74394757508807 38.83196631841515
# Epoch: 4 	Training Loss: 10.110696 val loss: 38.656288
# saving, val loss enhanced: 38.65628832984349 38.74394757508807
# Epoch 2 time: 73.91 seconds
# Outer Epoch 3/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 94.65batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9420.03iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 95.33batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9154.16iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:08<00:00, 105.44batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00,
ch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9718.05iteration/s]
# Epoch: 1 	Training Loss: 9.314474 val loss: 35.578908
# saving, val loss enhanced: 35.5789080606544 35.87070711277756
# Epoch: 2 	Training Loss: 9.294680 val loss: 35.504770
# saving, val loss enhanced: 35.504770166179924 35.5789080606544
# Epoch: 3 	Training Loss: 9.274957 val loss: 35.430736
# saving, val loss enhanced: 35.43073605704215 35.504770166179924
# Epoch: 4 	Training Loss: 9.255273 val loss: 35.356753
# saving, val loss enhanced: 35.35675319796838 35.43073605704215
# Epoch 8 time: 75.13 seconds
# Outer Epoch 9/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 95.65batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9562.89iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 96.76batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9319.94iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 98.09batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 9293.96iteration/s]
# Epoch: 1 	Training Loss: 9.185711 val loss: 35.071935
# saving, val loss enhanced: 35.071935122980385 35.35675319796838
# Epoch: 2 	Training Loss: 9.166479 val loss: 34.999677
# saving, val loss enhanced: 34.999676976024304 35.071935122980385
# Epoch: 3 	Training Loss: 9.147313 val loss: 34.927513
# saving, val loss enhanced: 34.92751339506608 34.999676976024304
# Epoch: 4 	Training Loss: 9.128182 val loss: 34.855393
# saving, val loss enhanced: 34.855392509118424 34.92751339506608
# Epoch 9 time: 74.47 seconds
# Outer Epoch 10/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 95.82batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9272.29iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.15batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9780.39iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 97.96batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9672.00iteration/s]
# Epoch: 1 	Training Loss: 9.060839 val loss: 34.577300
# saving, val loss enhanced: 34.577299887783276 34.855392509118424
# Epoch: 2 	Training Loss: 9.042139 val loss: 34.506850
# saving, val loss enhanced: 34.50685022092214 34.577299887783276
# Epoch: 3 	Training Loss: 9.023502 val loss: 34.436487
# saving, val loss enhanced: 34.43648708499656 34.50685022092214
# Epoch: 4 	Training Loss: 9.004896 val loss: 34.366159
# saving, val loss enhanced: 34.36615932720677 34.43648708499656
# Epoch 10 time: 73.84 seconds
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 95.84batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:05<00:00, 10984.35iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# (15,)
# [2.76733968+1.99460335j 2.76733968-1.99460335j 2.39432559+0.j
#  1.69356487+0.3552351j  1.69356487-0.3552351j  1.61115126+0.j
#  1.03888666+0.j         1.00348108+0.j         1.00010036+0.j
#  1.        +0.j         0.98622347+0.j         0.96412157-0.05202873j
#  0.96412157+0.05202873j 0.78598925-0.04632571j 0.78598925+0.04632571j]

# %% [markdown]
# ## Test 3 ##

# %%
#### Test 3 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 25

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 625/625 [00:08<00:00, 72.59it/s]
# Shape of data_X: (625, 10, 2)
# Shape of data_Y: (625, 10, 2)
# Shape of X: (6250, 2)
# Shape of Y: (6250, 2)
# (4375, 2)
# Epoch: 1 	Training Loss: 0.932670 val loss: 0.846778
# saving, val loss enhanced: 0.8467779416131097 10000
# Epoch: 2 	Training Loss: 0.888172 val loss: 0.802939
# saving, val loss enhanced: 0.802938958182612 0.8467779416131097
# Epoch: 3 	Training Loss: 0.846368 val loss: 0.767041
# saving, val loss enhanced: 0.7670406765316291 0.802938958182612
# Epoch: 4 	Training Loss: 0.807844 val loss: 0.733408
teration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3830.859229 val loss: 3189.651681
# Epoch: 2 	Training Loss: 3820.583671 val loss: 3182.897370
# Epoch: 3 	Training Loss: 3810.355429 val loss: 3176.153995
# Epoch: 4 	Training Loss: 3800.140404 val loss: 3169.415435
# Epoch 10 time: 32.52 seconds
# (15,)
# [9.99998718e-01+0.j         9.93409857e-01+0.j
#  8.78179023e-01+0.j         5.35046115e-01-0.01547794j
#  5.35046115e-01+0.01547794j 3.52533477e-01+0.j
#  3.10977456e-01+0.j         9.63464589e-02+0.j
#  4.87835113e-02+0.j         3.84459523e-02+0.j
#  1.33716730e-02+0.j         2.25271293e-03+0.j
#  1.53428699e-04+0.j         1.36144935e-05+0.j
#  3.81999314e-08+0.j        ]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 96.35batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9295.54iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Outer Epoch 1/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:21<00:00, 100.96batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9089.71iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 98.30batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9973.06iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 98.18batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 9358.18iteration/s]
# Epoch: 1 	Training Loss: 16.893187 val loss: 15.556066
# saving, val loss enhanced: 15.556065569804307 1000000000000000.0
# Epoch: 2 	Training Loss: 16.849621 val loss: 15.529088
# saving, val loss enhanced: 15.529087659456323 15.556065569804307
# Epoch: 3 	Training Loss: 16.806454 val loss: 15.502174
# saving, val loss enhanced: 15.502174306284733 15.529087659456323
# Epoch: 4 	Training Loss: 16.763355 val loss: 15.475347
# saving, val loss enhanced: 15.475347327811598 15.502174306284733
# Epoch 1 time: 72.98 seconds
# Outer Epoch 2/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.05batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9242.26iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 95.70batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9204.67iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 97.77batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 10897.95iteration/s]
# Epoch: 1 	Training Loss: 16.649258 val loss: 15.401565
# saving, val loss enhanced: 15.401564754339534 15.475347327811598
# Epoch: 2 	Training Loss: 16.607484 val loss: 15.375552
# saving, val loss enhanced: 15.375552440750141 15.401564754339534
# Epoch: 3 	Training Loss: 16.565854 val loss: 15.349607
# saving, val loss enhanced: 15.349607434701563 15.375552440750141
# Epoch: 4 	Training Loss: 16.524301 val loss: 15.323726
# saving, val loss enhanced: 15.32372596833631 15.349607434701563
# Epoch 2 time: 73.94 seconds
# Outer Epoch 3/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 95.08batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9310.10iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 94.84batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9046.07iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 97.50batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 9239.67iteration/s]
# Epoch: 1 	Training Loss: 16.411100 val loss: 15.250679
# saving, val loss enhanced: 15.25067948309831 15.32372596833631
# Epoch: 2 	Training Loss: 16.370858 val loss: 15.225582
# saving, val loss enhanced: 15.225582452275544 15.25067948309831
# Epoch: 3 	Training Loss: 16.330769 val loss: 15.200546
# saving, val loss enhanced: 15.200545992887722 15.225582452275544
# Epoch: 4 	Training Loss: 16.290755 val loss: 15.175563
# saving, val loss enhanced: 15.17556281519509 15.200545992887722
# Epoch 3 time: 75.87 seconds
# Outer Epoch 4/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 94.92batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9505.64iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.36batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9340.40iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 96.70batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9531.64iteration/s]
# Epoch: 1 	Training Loss: 16.180492 val loss: 15.104425
# saving, val loss enhanced: 15.104425091999033 15.17556281519509
# Epoch: 2 	Training Loss: 16.141727 val loss: 15.080187
# saving, val loss enhanced: 15.080186756440337 15.104425091999033
# Epoch: 3 	Training Loss: 16.103111 val loss: 15.056003
# saving, val loss enhanced: 15.056003465412553 15.080186756440337
# Epoch: 4 	Training Loss: 16.064565 val loss: 15.031867
# saving, val loss enhanced: 15.031866503715237 15.056003465412553
# Epoch 4 time: 74.46 seconds
# Outer Epoch 5/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 94
ch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 8401.32iteration/s]
# Epoch: 1 	Training Loss: 15.128245 val loss: 14.434365
# saving, val loss enhanced: 14.434364944551751 14.497298830896609
# Epoch: 2 	Training Loss: 15.095821 val loss: 14.413787
# saving, val loss enhanced: 14.413787305725211 14.434364944551751
# Epoch: 3 	Training Loss: 15.063509 val loss: 14.393246
# saving, val loss enhanced: 14.39324579784652 14.413787305725211
# Epoch: 4 	Training Loss: 15.031239 val loss: 14.372730
# saving, val loss enhanced: 14.372730431154615 14.39324579784652
# Epoch 9 time: 81.29 seconds
# Outer Epoch 10/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:24<00:00, 89.37batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:08<00:00, 7710.94iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:26<00:00, 83.18batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8722.96iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:10<00:00, 88.48batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 9227.79iteration/s]
# Epoch: 1 	Training Loss: 14.935460 val loss: 14.311230
# saving, val loss enhanced: 14.311229611518733 14.372730431154615
# Epoch: 2 	Training Loss: 14.904130 val loss: 14.291289
# saving, val loss enhanced: 14.291289490065534 14.311229611518733
# Epoch: 3 	Training Loss: 14.872906 val loss: 14.271383
# saving, val loss enhanced: 14.271382699702649 14.291289490065534
# Epoch: 4 	Training Loss: 14.841718 val loss: 14.251499
# saving, val loss enhanced: 14.251499296184724 14.271382699702649
# Epoch 10 time: 83.56 seconds
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:25<00:00, 85.13batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8657.30iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# (15,)
# [3.18721611+0.71537434j 3.18721611-0.71537434j 2.27393941+0.j
#  1.28970774+0.09336797j 1.28970774-0.09336797j 1.10492595-0.50788521j
#  1.10492595+0.50788521j 1.01213905+0.j         1.00233799+0.j
#  1.00000314+0.j         1.        +0.j         0.99987511+0.j
#  0.98426599-0.1352622j  0.98426599+0.1352622j  0.43375737+0.j        ]

# %% [markdown]
# ## Test 4 ##

# %%
#### Test 4 ####
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 25

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Lag time:  0.1
# 100%|██████████| 625/625 [00:10<00:00, 61.40it/s]
# Shape of data_X: (625, 10, 2)
# Shape of data_Y: (625, 10, 2)
# Shape of X: (6250, 2)
# Shape of Y: (6250, 2)
# (4375, 2)
# Epoch: 1 	Training Loss: 0.546276 val loss: 0.537084
# saving, val loss enhanced: 0.537083832075154 10000
# Epoch: 2 	Training Loss: 0.531133 val loss: 0.524969
# saving, val loss enhanced: 0.5249690108305123 0.537083832075154
# Epoch: 3 	Training Loss: 0.516665 val loss: 0.510252
# saving, val loss enhanced: 0.5102524603243433 0.5249690108305123
# Epoch: 4 	Training Loss: 0.504045 val loss: 0.498699
# saving, val loss enhanced: 0.49869911549247126 0.5102524603243433
# Epoch: 5 	Training Loss: 0.492480 val loss: 0.487378
# saving, val loss enhanced: 0.4873778438317067 0.49869911549247126
# Epoch: 6 	Training Loss: 0.480263 val loss: 0.477052
# saving, val loss enhanced: 0.47705204068748164 0.4873778438317067
# Epoch: 7 	Training Loss: 0.470310 val loss: 0.466767
# saving, val loss enhanced: 0.4667666394440077 0.47705204068748164
# Epoch: 8 	Training Loss: 0.460242 val loss: 0.459136
# saving, val loss enhanced: 0.459136002553767 0.4667666394440077
# Epoch: 9 	Training Loss: 0.450067 val loss: 0.447918
# saving, val loss enhanced: 0.44791830095490454 0.459136002553767
10
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.54batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:08<00:00, 8110.15iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.865875 val loss: 2.839896
# saving, val loss enhanced: 2.8398963832561606 2.853258868307482
# Epoch: 2 	Training Loss: 3.853246 val loss: 2.831723
# saving, val loss enhanced: 2.83172259936665 2.8398963832561606
# Epoch: 3 	Training Loss: 3.840672 val loss: 2.823566
# saving, val loss enhanced: 2.823566293909172 2.83172259936665
# Epoch: 4 	Training Loss: 3.828119 val loss: 2.815420
# saving, val loss enhanced: 2.815420450791198 2.823566293909172
# Epoch 8 time: 32.23 seconds
# Outer Epoch 9/10
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 93.56batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:08<00:00, 8168.16iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.803781 val loss: 2.799646
# saving, val loss enhanced: 2.799646281286699 2.815420450791198
# Epoch: 2 	Training Loss: 3.791717 val loss: 2.791843
# saving, val loss enhanced: 2.7918428956725605 2.799646281286699
# Epoch: 3 	Training Loss: 3.779707 val loss: 2.784056
# saving, val loss enhanced: 2.7840557444048426 2.7918428956725605
# Epoch: 4 	Training Loss: 3.767716 val loss: 2.776278
# saving, val loss enhanced: 2.7762779301402416 2.7840557444048426
# Epoch 9 time: 33.24 seconds
# Outer Epoch 10/10
# Processing batches: 100%|██████████| 2188/2188 [00:24<00:00, 90.89batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:08<00:00, 8164.23iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 3.739981 val loss: 2.758892
# saving, val loss enhanced: 2.758891695260149 2.7762779301402416
# Epoch: 2 	Training Loss: 3.728457 val loss: 2.751440
# saving, val loss enhanced: 2.7514399634839726 2.758891695260149
# Epoch: 3 	Training Loss: 3.716983 val loss: 2.744003
# saving, val loss enhanced: 2.744003427398581 2.7514399634839726
# Epoch: 4 	Training Loss: 3.705527 val loss: 2.736575
# saving, val loss enhanced: 2.736575470474126 2.744003427398581
# Epoch 10 time: 33.96 seconds
# (15,)
# [1.00000433e+00 9.93472115e-01 8.98852803e-01 5.77762282e-01
#  5.72142192e-01 3.81486168e-01 2.70723436e-01 2.60837965e-01
#  1.73732290e-01 2.88484357e-02 1.88741015e-02 3.01014328e-03
#  5.27757377e-04 8.85109814e-05 1.28394502e-06]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:24<00:00, 90.62batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9214.48iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Outer Epoch 1/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 93.15batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8720.26iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 91.42batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8258.43iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:10<00:00, 87.14batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 8056.32iteration/s]
# Epoch: 1 	Training Loss: 15.511787 val loss: 15.096240
# saving, val loss enhanced: 15.096239754960697 1000000000000000.0
# Epoch: 2 	Training Loss: 15.468595 val loss: 15.057066
# saving, val loss enhanced: 15.057065855109501 15.096239754960697
# Epoch: 3 	Training Loss: 15.425932 val loss: 15.018190
# saving, val loss enhanced: 15.01818988909607 15.057065855109501
# Epoch: 4 	Training Loss: 15.383440 val loss: 14.979572
# saving, val loss enhanced: 14.979572240241836 15.01818988909607
# Epoch 1 time: 80.46 seconds
# Outer Epoch 2/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:24<00:00, 89.31batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 
## Define the potential function V(x, y) and plot the potential landscape
def potential(x, y):
    return (
        3 * np.exp(-x**2 - (y - 1/3)**2)
        - 3 * np.exp(-x**2 - (y - 5/3)**2)
        - 5 * np.exp(-(x - 1)**2 - y**2)
        - 5 * np.exp(-(x + 1)**2 - y**2)
        + 0.2 * x**4
        + 0.2 * (y - 1/3)**4
    )

# Define the gradient of the potential function
def gradient(x, y):
    dVdx = (
        -6 * x * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * x * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * (x - 1) * np.exp(-(x - 1)**2 - y**2)
        + 10 * (x + 1) * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * x**3
    )
    dVdy = (
        -6 * (y - 1/3) * np.exp(-x**2 - (y - 1/3)**2)
        + 6 * (y - 5/3) * np.exp(-x**2 - (y - 5/3)**2)
        + 10 * y * np.exp(-(x - 1)**2 - y**2)
        + 10 * y * np.exp(-(x + 1)**2 - y**2)
        + 0.8 * (y - 1/3)**3
    )
    return dVdx, dVdy

## Generate m^2 trajectories in the landscape
# Set the parameters for the SDE
#h = 1e-3  # Integration step size
h = 1e-3  # Integration step size
#h = 1e-5  # Integration step size
n_steps = 100  # Number of integration steps between each evaluation
n_eval = 10  # Number of evaluations
lag_time = h * n_steps  # Lag time

# Set the number of points to select in each dimension
m = 25

# Set the diffusion coefficient
sigma = 1.09
print ('Lag time: ', lag_time)



# Generate linspace for x and y coordinates
x_values = np.linspace(-2, 2, m)
y_values = np.linspace(-1, 2, m)

# Create a meshgrid from these linspace arrays
xx, yy = np.meshgrid(x_values, y_values)

# Flatten the meshgrid matrices to get the coordinate pairs
x0_values = xx.flatten()
y0_values = yy.flatten()

# Initialize the data_matrix
data_matrix = np.zeros((m**2, n_eval+1, 2))

# Generate trajectories for each selected point
for i in tqdm (range(m**2)):
    x = x0_values[i]
    y = y0_values[i]
    
    for j in range(n_eval+1):
        data_matrix[i, j, 0] = x
        data_matrix[i, j, 1] = y
        
        for k in range(n_steps):
            dVdx, dVdy = gradient(x, y)
            x += -dVdx * h + sigma * np.sqrt(h) * np.random.normal()
            y += -dVdy * h + sigma * np.sqrt(h) * np.random.normal()

# Create a grid of points
x_plot = np.linspace(-2, 2, 100)
y_plot = np.linspace(-1, 2, 100)
X, Y = np.meshgrid(x_plot, y_plot)



# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)



#### SDMD Test ####
checkpoint_file= 'well2d_example_ckpt004.torch'

basis_function = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32, delta_t= lag_time)

solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver.get_Psi_X()
Psi_Y = solver.get_Psi_Y()
Koopman_matrix_K = solver.K

outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data

# Assuming evalues is a numpy array of complex numbers
print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: SDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' SDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
#
ch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9135.78iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 6.573064 val loss: 16.159178
# Epoch: 2 	Training Loss: 6.562468 val loss: 16.139338
# Epoch: 3 	Training Loss: 6.551880 val loss: 16.119566
# Epoch: 4 	Training Loss: 6.541351 val loss: 16.099873
# Epoch 8 time: 27.24 seconds
# Outer Epoch 9/10
# Processing batches: 100%|██████████| 2188/2188 [00:17<00:00, 125.93batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8738.14iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 6.808467 val loss: 16.499391
# Epoch: 2 	Training Loss: 6.797392 val loss: 16.479304
# Epoch: 3 	Training Loss: 6.786326 val loss: 16.459287
# Epoch: 4 	Training Loss: 6.775322 val loss: 16.439352
# Epoch 9 time: 26.36 seconds
# Outer Epoch 10/10
# Processing batches: 100%|██████████| 2188/2188 [00:17<00:00, 124.70batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8483.38iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Epoch: 1 	Training Loss: 7.059810 val loss: 16.861667
# Epoch: 2 	Training Loss: 7.048227 val loss: 16.841305
# Epoch: 3 	Training Loss: 7.036655 val loss: 16.821018
# Epoch: 4 	Training Loss: 7.025150 val loss: 16.800816
# Epoch 10 time: 26.72 seconds
# (15,)
# [9.99998011e-01 9.92095603e-01 8.83236161e-01 5.86405611e-01
#  5.66624438e-01 3.18306479e-01 2.54241217e-01 1.84680976e-01
#  1.13539489e-01 3.28173954e-02 5.87501684e-03 1.68119762e-03
#  1.47997744e-04 2.15764183e-05 5.20894073e-06]

# %%
#### gEDMD Test ####
checkpoint_file_g= 'well2d_example_ckpt004_g.torch'

basis_function_g = KoopmanNNTorch(input_size= 2, layer_sizes=[15], n_psi_train=12).to(device)  # basis number would be 20


solver_g = KoopmanSolverTorch_g(dic=basis_function_g, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                                                   reg=0.1,  checkpoint_file= checkpoint_file_g, fnn_checkpoint_file= 'example_fnn001.torch', 
                            a_b_file= 'a_b_example_3ple_well.jbl', 
                        generator_batch_size= 2, fnn_batch_size= 32)

solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=10,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )

# Results from solver_gedmd
evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
#kpm_modes = solver.compute_mode().T
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()


outputs = {
    'efuns': efuns,
    'evalues': evalues,
    # 'kpm_modes': kpm_modes,
    'N_dict': N_dict,
    # 'K': Koopman_matrix_K,
    # 'Psi_X': Psi_X,
    # 'Psi_Y': Psi_Y,
    }



#computing eigenvalues of K from generator eigenvalues using exponetnt
#eigenfunctions are the same for the operator and the generator
evalues= np.exp(evalues)

# Assuming 'efuns' is a 2D numpy array with shape (n_samples, n_eigenfunctions)
# and 'X' is a 2D numpy array with shape (n_samples, 2) representing your input data
# Assuming evalues is a numpy array of complex numbers

print(evalues.shape)
print(evalues)

# Plot eigenvalues on unit circle
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# Plot eigenfunctions
fig, axs = plt.subplots(1, 4, figsize=(16, 3))

# Plot for the 1st eigenfunction
# scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm')
scatter1 = axs[0].scatter(*X.T, c=np.real(efuns)[:, 0], cmap='coolwarm', vmin=1.091, vmax=1.093)
axs[0].set_title('1st eigenfunction')
axs[0].set_xlim(-2, 2)
axs[0].set_ylim(-1, 2)
cbar1 = fig.colorbar(scatter1, ax=axs[0], shrink=0.7, aspect=20)

# Plot for the 2nd eigenfunction
scatter2 = axs[1].scatter(*X.T, c=np.real(efuns)[:, 1], cmap='coolwarm')
axs[1].set_title('2nd eigenfunction')
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-1, 2)
cbar2 = fig.colorbar(scatter2, ax=axs[1])

# Plot for the 3rd eigenfunction
scatter3 = axs[2].scatter(*X.T, c=np.real(efuns)[:, 2], cmap='coolwarm')
axs[2].set_title('3rd eigenfunction')
axs[2].set_xlim(-2, 2)
axs[2].set_ylim(-1, 2)
cbar3 = fig.colorbar(scatter3, ax=axs[2])

# Plot for the 4th eigenfunction
scatter4 = axs[3].scatter(*X.T, c=np.real(efuns)[:, 3], cmap='coolwarm')
axs[3].set_title('4th eigenfunction')
axs[3].set_xlim(-2, 2)
axs[3].set_ylim(-1, 2)
cbar4 = fig.colorbar(scatter4, ax=axs[3])
fig.suptitle(' gEDMD ', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Precomputed SDE coefficients loaded from: a_b_example_3ple_well.jbl
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:17<00:00, 124.42batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 10628.29iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# Outer Epoch 1/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:17<00:00, 124.49batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9632.24iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:20<00:00, 108.10batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9282.28iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:08<00:00, 110.95batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 8756.50iteration/s]
# Epoch: 1 	Training Loss: 4.020854 val loss: 8.853738
# saving, val loss enhanced: 8.853737522318943 1000000000000000.0
# Epoch: 2 	Training Loss: 4.013826 val loss: 8.837573
# saving, val loss enhanced: 8.837572757167614 8.853737522318943
# Epoch: 3 	Training Loss: 4.007287 val loss: 8.821646
# saving, val loss enhanced: 8.821646475801321 8.837572757167614
# Epoch: 4 	Training Loss: 4.000841 val loss: 8.805939
# saving, val loss enhanced: 8.805939146513513 8.821646475801321
# Epoch 1 time: 65.87 seconds
# Outer Epoch 2/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 94.58batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8508.17iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:23<00:00, 93.30batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8371.68iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 103.00batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9794.98iteration/s]
# Epoch: 1 	Training Loss: 3.988020 val loss: 8.776110
# saving, val loss enhanced: 8.776110114853052 8.805939146513513
# Epoch: 2 	Training Loss: 3.981762 val loss: 8.760847
# saving, val loss enhanced: 8.760846836528113 8.776110114853052
# Epoch: 3 	Training Loss: 3.975536 val loss: 8.745665
# saving, val loss enhanced: 8.745665315289834 8.760846836528113
# Epoch: 4 	Training Loss: 3.969331 val loss: 8.730548
# saving, val loss enhanced: 8.730548032200124 8.745665315289834
# Epoch 2 time: 76.41 seconds
# Outer Epoch 3/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 99.44batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 
10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:21<00:00, 101.84batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9202.30iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:20<00:00, 104.36batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:05<00:00, 11179.29iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:08<00:00, 106.45batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:02<00:00, 9558.85iteration/s]
# Epoch: 1 	Training Loss: 3.816393 val loss: 8.366981
# saving, val loss enhanced: 8.366981425338519 8.390804785257243
# Epoch: 2 	Training Loss: 3.811001 val loss: 8.353537
# saving, val loss enhanced: 8.353536513888459 8.366981425338519
# Epoch: 3 	Training Loss: 3.805623 val loss: 8.340116
# saving, val loss enhanced: 8.340115537443534 8.353536513888459
# Epoch: 4 	Training Loss: 3.800253 val loss: 8.326713
# saving, val loss enhanced: 8.326713486803966 8.340115537443534
# Epoch 8 time: 69.56 seconds
# Outer Epoch 9/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 98.20batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 9921.67iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 97.84batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 9140.36iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:08<00:00, 105.77batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 8713.77iteration/s]
# Epoch: 1 	Training Loss: 3.790101 val loss: 8.303319
# saving, val loss enhanced: 8.303319341491232 8.326713486803966
# Epoch: 2 	Training Loss: 3.784827 val loss: 8.290114
# saving, val loss enhanced: 8.29011448156329 8.303319341491232
# Epoch: 3 	Training Loss: 3.779567 val loss: 8.276932
# saving, val loss enhanced: 8.276932179320204 8.29011448156329
# Epoch: 4 	Training Loss: 3.774314 val loss: 8.263767
# saving, val loss enhanced: 8.263767452182535 8.276932179320204
# Epoch 9 time: 73.28 seconds
# Outer Epoch 10/10
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:20<00:00, 104.41batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:06<00:00, 10491.88iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:21<00:00, 100.14batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8872.56iteration/s]
# cuda:0
# Processing batches: 100%|██████████| 937/937 [00:09<00:00, 100.97batch/s]
# Computing dPsi_X: 100%|██████████| 28095/28095 [00:03<00:00, 8894.17iteration/s]
# Epoch: 1 	Training Loss: 3.764387 val loss: 8.240789
# saving, val loss enhanced: 8.240788814438105 8.263767452182535
# Epoch: 2 	Training Loss: 3.759227 val loss: 8.227816
# saving, val loss enhanced: 8.227816418156115 8.240788814438105
# Epoch: 3 	Training Loss: 3.754080 val loss: 8.214865
# saving, val loss enhanced: 8.214865366220497 8.227816418156115
# Epoch: 4 	Training Loss: 3.748940 val loss: 8.201931
# saving, val loss enhanced: 8.201930704911891 8.214865366220497
# Epoch 10 time: 71.30 seconds
# cuda:0
# Processing batches: 100%|██████████| 2188/2188 [00:22<00:00, 99.28batch/s]
# Computing dPsi_X: 100%|██████████| 65610/65610 [00:07<00:00, 8865.78iteration/s]
# dPsi_X shape:  torch.Size([4374, 15])
# psi_x shape:  torch.Size([4374, 15])
# psi_x_inv shape:  torch.Size([15, 4374])
# cuda:0
# cuda:0
# (15,)
# [3.73500537+0.j         1.70178587-0.68479285j 1.70178587+0.68479285j
#  1.24271491+0.66096105j 1.24271491-0.66096105j 1.03381585+0.j
#  1.01295723+0.j         1.00049542+0.j         1.        +0.j
#  0.99991465+0.j         0.98096095-0.03320296j 0.98096095+0.03320296j
#  0.62789228-0.33604907j 0.62789228+0.33604907j 0.42492934+0.j        ]
