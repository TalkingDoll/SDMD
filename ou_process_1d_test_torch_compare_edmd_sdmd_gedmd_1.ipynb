# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import cm
from tqdm import tqdm
import os
import torch
torch.cuda.empty_cache()
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from numpy import linalg as la
from numpy import *
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#from solver_sdmd_torch_gpu import KoopmanNNTorch, KoopmanSolverTorch


print (torch.__version__, torch.cuda.is_available())
print(torch.version.cuda)
print (torch.cuda.get_device_name())
# device= 'cpu'
device= 'cuda'
# Out:
# 2.3.1 True
# 11.8
# NVIDIA GeForce RTX 3070 Ti

# %%
import torch
torch.cuda.empty_cache()

# %%
def ou_process_1d(theta=1, mu=0, sigma=1, X0=0, n_steps=10000, n_eval=200, h=1e-5):
    """
    Simulates the Ornstein-Uhlenbeck process.
    
    Parameters:
    - theta: rate of mean reversion
    - mu: long-term mean of the process
    - sigma: volatility
    - X0: initial value
    - n_steps: number of steps in each evaluation
    - n_eval: number of evaluations
    - h: Integration step size
    
    Returns:
    - A numpy array containing the simulated values at each evaluation
    """
    X_eval = np.zeros(n_eval)
    X = X0
    
    for i in range(n_eval):
        for _ in range(n_steps):
            dW = np.sqrt(h) * np.random.randn()
            X = X + theta * (mu - X) * h + sigma * dW
        X_eval[i] = X
    
    return X_eval

## Setup the parameters
theta = 1
mu = 0
sigma = 0.1

# %%
# Generate m initial points from the domain space [-2, 2]
m = 10
n_eval = 200
n_steps = 1000
h = 1e-4
lag_time = n_steps * h
print("lag time: ", lag_time)
X0_values = np.linspace(-2, 2, m)

# Initialize the data_matrix
data_matrix = np.zeros((m, n_eval+1, 1))

# Simulate trajectories for each initial point and store them in the data_matrix
for i, X0 in tqdm(enumerate(X0_values), total=m, desc="Simulating trajectories"):
    X_eval = np.concatenate(([X0], ou_process_1d(X0=X0, n_steps=n_steps, n_eval=n_eval, h=h)))
    data_matrix[i, :, 0] = X_eval

# Print the shape of data_matrix
print("Shape of data_matrix:", data_matrix.shape)

# Extract data_X and data_Y from the data matrix
data_X = data_matrix[:, :-1, :]
data_Y = data_matrix[:, 1:, :]
print(f"Shape of data_X: {data_X.shape}")
print(f"Shape of data_Y: {data_Y.shape}")

# Reshape data_X and data_Y into a single column
X = data_X.reshape(-1, data_X.shape[2])  # 2D features
Y = data_Y.reshape(-1, data_X.shape[2])  # 2D targets
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

# Separate data into two parts: train and validation
len_all = X.shape[0]
data_x_train = X[:int(0.7*len_all)]
data_x_valid = X[int(0.7*len_all)+1:]

data_y_train = Y[:int(0.7*len_all)]
data_y_valid = Y[int(0.7*len_all)+1:]

data_train = [data_x_train, data_y_train]
data_valid = [data_x_valid, data_y_valid]

print(data_x_train.shape)
# Out:
# lag time:  0.1
# Simulating trajectories: 100%|██████████| 10/10 [00:02<00:00,  3.62it/s]
# Shape of data_matrix: (10, 201, 1)
# Shape of data_X: (10, 200, 1)
# Shape of data_Y: (10, 200, 1)
# Shape of X: (2000, 1)
# Shape of Y: (2000, 1)
# (1400, 1)

# %%
from solver_edmd_torch_gpu import KoopmanNNTorch, EDMDSolverTorch
#### EDMD Test ####
checkpoint_file= 'ou1d_example_ckpt003.torch'

basis_function = KoopmanNNTorch(input_size=1, layer_sizes=[20, 20], n_psi_train=18).to(device)

solver = EDMDSolverTorch(
    dic=basis_function,
    target_dim=np.shape(data_x_train)[-1],
    reg=0.1,
    checkpoint_file=checkpoint_file,
    batch_size=32
)

data_x_train_tensor = torch.DoubleTensor(data_x_train).to (device)#, requieres_grad= True)#, dtype=tf.float64)
data_y_train_tensor = torch.DoubleTensor(data_y_train).to (device)#, requires_grad= True)#, dtype=tf.float64)

# %%
solver.build_with_edmd(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=0.8
)
# Out:
# Outer Epoch 1/6
# Epoch: 1 	Training Loss: 0.006749 val loss: 0.006313
# saving, val loss enhanced: 0.006312501151995022 1000000000000000.0
# Epoch: 2 	Training Loss: 0.006737 val loss: 0.006302
# saving, val loss enhanced: 0.006301501678275098 0.006312501151995022
# Epoch: 3 	Training Loss: 0.006726 val loss: 0.006291
# saving, val loss enhanced: 0.006290587205148428 0.006301501678275098
# Outer Epoch 2/6
# Epoch: 1 	Training Loss: 0.006713 val loss: 0.006281
# saving, val loss enhanced: 0.00628068756870586 0.006290587205148428
# Epoch: 2 	Training Loss: 0.006702 val loss: 0.006270
# saving, val loss enhanced: 0.006269563224483732 0.00628068756870586
# Epoch: 3 	Training Loss: 0.006690 val loss: 0.006259
# saving, val loss enhanced: 0.006258818190227247 0.006269563224483732
# Outer Epoch 3/6
# Epoch: 1 	Training Loss: 0.006679 val loss: 0.006249
# saving, val loss enhanced: 0.006249117956484614 0.006258818190227247
# Epoch: 2 	Training Loss: 0.006667 val loss: 0.006239
# saving, val loss enhanced: 0.006238531386007916 0.006249117956484614
# Epoch: 3 	Training Loss: 0.006656 val loss: 0.006228
# saving, val loss enhanced: 0.006227879485218047 0.006238531386007916
# Outer Epoch 4/6
# Epoch: 1 	Training Loss: 0.006645 val loss: 0.006218
# saving, val loss enhanced: 0.006218296754050934 0.006227879485218047
# Epoch: 2 	Training Loss: 0.006634 val loss: 0.006208
# saving, val loss enhanced: 0.006207870617143103 0.006218296754050934
# Epoch: 3 	Training Loss: 0.006623 val loss: 0.006197
# saving, val loss enhanced: 0.0061972401130564805 0.006207870617143103
# Outer Epoch 5/6
# Epoch: 1 	Training Loss: 0.006611 val loss: 0.006188
# saving, val loss enhanced: 0.006188149410748377 0.0061972401130564805
# Epoch: 2 	Training Loss: 0.006600 val loss: 0.006178
# saving, val loss enhanced: 0.0061777543629406954 0.006188149410748377
# Epoch: 3 	Training Loss: 0.006589 val loss: 0.006167
# saving, val loss enhanced: 0.00616749552855713 0.0061777543629406954
# Outer Epoch 6/6
# Epoch: 1 	Training Loss: 0.006578 val loss: 0.006158
# saving, val loss enhanced: 0.0061583092664965035 0.00616749552855713
# Epoch: 2 	Training Loss: 0.006567 val loss: 0.006148
# saving, val loss enhanced: 0.00614819540860899 0.0061583092664965035
# Epoch: 3 	Training Loss: 0.006557 val loss: 0.006138
# saving, val loss enhanced: 0.006138157038656563 0.00614819540860899

# %%
# Results from solver_edmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
N_dict = np.shape(evalues)[0]
Koopman_matrix_K = solver.K
outputs = {
    'efuns': efuns,
    'evalues': evalues,
    'N_dict': N_dict,
    'K': Koopman_matrix_K
    }

# %%
# Take ln values of the eigenvalues and divide by 0.1
# ln_evalues = np.log(evalues[:4]) / lag_time
ln_evalues = (evalues[:4]-1) / lag_time

print(ln_evalues)

## Plot eigenvalues on unit circle
# Assuming evalues is a numpy array of complex numbers
real_parts = ln_evalues.real
imag_parts = ln_evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2*np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

## Plot eigenfunctions
# Get the real part of eigenfunctions and normalize them
phi = np.real(efuns)

# Use the entire efuns instead of slicing
for i in range(len(evalues)):
    phi[:, i] = phi[:, i] / np.max(np.abs(phi[:, i]))

# Create a plot with 2x2 layout
fig, axs = plt.subplots(2, 2, figsize=(8, 8))
titles = ['1st eigenfunction', '2nd eigenfunction', '3rd eigenfunction', '4th eigenfunction']

# Determine global min and max values for the eigenfunctions for a uniform scale
vmin = np.min(phi)
vmax = np.max(phi)
cbar_ticks = np.linspace(vmin, vmax, 5)

# Flatten the 2D array of axes for easy iteration
axs_flat = axs.flatten()

for i, (ax, title) in enumerate(zip(axs_flat, titles)):
    scatter = ax.scatter(X, phi[:, i], c=phi[:, i], cmap='Spectral', marker='.', vmin=vmin, vmax=vmax)
    ax.set_title(title, pad=20)
    ax.set_xlabel('Data')
    ax.set_ylabel('Eigenfunction Value')
    ax.set_xlim(-2, 2)
    ax.set_ylim(-2, 2)
    cbar = fig.colorbar(scatter, ax=ax, orientation='vertical', fraction=0.046, pad=0.04, ticks=cbar_ticks)
    cbar.set_ticklabels([f"{tick:.1f}" for tick in cbar_ticks])
    ax.grid()
# fig.suptitle('SDMD', fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# [-3.62898150e-04+0.j -9.49685766e-01+0.j -3.51691657e+00+0.j
#  -7.28140948e+00+0.j]

# %%
from solver_sdmd_torch_gpu2 import KoopmanNNTorch, KoopmanSolverTorch
#### SDMD Test ####
checkpoint_file= 'ou1d_example_ckpt002.torch'

basis_function = KoopmanNNTorch(input_size=1, layer_sizes=[20, 20], n_psi_train=18).to(device)

solver = KoopmanSolverTorch(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                       reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn_ou_001.torch', a_b_file= 'a_b_example_ou.jbl',
                generator_batch_size= 4, fnn_batch_size= 32, delta_t= lag_time)

data_x_train_tensor = torch.DoubleTensor(data_x_train).to (device)#, requieres_grad= True)#, dtype=tf.float64)
data_y_train_tensor = torch.DoubleTensor(data_y_train).to (device)#, requires_grad= True)#, dtype=tf.float64)

# %%
solver.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=256,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8
    )
# Out:
# Epoch: 1 	Training Loss: 0.390616 	Validation Loss: 0.239996
# Saving model, validation loss improved: 0.239996 < 10000.000000
# Epoch: 2 	Training Loss: 0.220808 	Validation Loss: 0.142848
# Saving model, validation loss improved: 0.142848 < 0.239996
# Epoch: 3 	Training Loss: 0.138656 	Validation Loss: 0.107447
# Saving model, validation loss improved: 0.107447 < 0.142848
# Epoch: 4 	Training Loss: 0.111295 	Validation Loss: 0.100660
# Saving model, validation loss improved: 0.100660 < 0.107447
# Epoch: 5 	Training Loss: 0.106701 	Validation Loss: 0.099774
# Saving model, validation loss improved: 0.099774 < 0.100660
# Epoch: 6 	Training Loss: 0.106638 	Validation Loss: 0.099444
# Saving model, validation loss improved: 0.099444 < 0.099774
# Epoch: 7 	Training Loss: 0.105630 	Validation Loss: 0.098726
# Saving model, validation loss improved: 0.098726 < 0.099444
# Epoch: 8 	Training Loss: 0.104514 	Validation Loss: 0.098551
# Saving model, validation loss improved: 0.098551 < 0.098726
# Epoch: 9 	Training Loss: 0.103732 	Validation Loss: 0.098131
# Saving model, validation loss improved: 0.098131 < 0.098551
# Epoch: 10 	Training Loss: 0.103016 	Validation Loss: 0.097144
# Saving model, validation loss improved: 0.097144 < 0.098131
# Epoch: 11 	Training Loss: 0.102837 	Validation Loss: 0.097060
# Saving model, validation loss improved: 0.097060 < 0.097144
# Epoch: 12 	Training Loss: 0.101585 	Validation Loss: 0.096676
# Saving model, validation loss improved: 0.096676 < 0.097060
# Epoch: 13 	Training Loss: 0.100791 	Validation Loss: 0.096503
# Saving model, validation loss improved: 0.096503 < 0.096676
# Epoch: 14 	Training Loss: 0.100378 	Validation Loss: 0.095838
# Saving model, validation loss improved: 0.095838 < 0.096503
# Epoch: 15 	Training Loss: 0.100090 	Validation Loss: 0.095765
# Saving model, validation loss improved: 0.095765 < 0.095838
# Epoch: 16 	Training Loss: 0.099551 	Validation Loss: 0.095090
# Saving model, validation loss improved: 0.095090 < 0.095765
# Epoch: 17 	Training Loss: 0.099111 	Validation Loss: 0.094500
# Saving model, validation loss improved: 0.094500 < 0.095090
# Epoch: 18 	Training Loss: 0.099005 	Validation Loss: 0.094660
# Epoch: 19 	Training Loss: 0.098633 	Validation Loss: 0.094079
# Saving model, validation loss improved: 0.094079 < 0.094500
# Epoch: 20 	Training Loss: 0.098713 	Validation Loss: 0.094210
# Epoch: 21 	Training Loss: 0.097960 	Validation Loss: 0.093641
# Saving model, validation loss improved: 0.093641 < 0.094079
# Epoch: 22 	Training Loss: 0.098027 	Validation Loss: 0.093886
# Epoch: 23 	Training Loss: 0.098087 	Validation Loss: 0.093957
# Epoch: 24 	Training Loss: 0.097695 	Validation Loss: 0.093836
# Epoch: 25 	Training Loss: 0.097658 	Validation Loss: 0.093498
# Saving model, validation loss improved: 0.093498 < 0.093641
# Epoch: 26 	Training Loss: 0.097604 	Validation Loss: 0.093832
# Epoch: 27 	Training Loss: 0.097694 	Validation Loss: 0.093755
# Epoch: 28 	Training Loss: 0.097105 	Validation Loss: 0.094431
# Epoch: 29 	Training Loss: 0.097554 	Validation Loss: 0.094506
# Epoch: 30 	Training Loss: 0.097570 	Validation Loss: 0.093998
# Epoch: 31 	Training Loss: 0.097252 	Validation Loss: 0.093530
# Epoch: 32 	Training Loss: 0.097426 	Validation Loss: 0.094022
# Epoch: 33 	Training Loss: 0.097492 	Validation Loss: 0.093979
# Epoch: 34 	Training Loss: 0.097334 	Validation Loss: 0.093835
# Epoch: 35 	Training Loss: 0.097257 	Validation Loss: 0.094402
# Epoch: 36 	Training Loss: 0.097086 	Validation Loss: 0.093912
# Epoch: 37 	Training Loss: 0.096706 	Validation Loss: 0.094055
# Epoch: 38 	Training Loss: 0.096956 	Validation Loss: 0.093761
# Epoch: 39 	Training Loss: 0.097135 	Validation Loss: 0.094178
# Epoch: 40 	Training Loss: 0.097411 	Validation Loss: 0.094429
# Epoch: 41 	Training Loss: 0.097100 	Validation Loss: 0.094220
# Epoch: 42 	Training Loss: 0.097392 	Validation Loss: 0.094361
# Epoch: 43 	Training Loss: 0.096222 	Validation Loss: 0.094565
# Epoch: 44 	Training Loss: 0.097173 	Validation Loss: 0.094692
# Epoch: 45 	Training Loss: 0.097115 	Validation Loss: 0.094188
# Epoch: 46 	Training Loss: 0.097243 	Validation Loss: 0.094379
# Epoch: 47 	Training Loss: 0.097198 	Validation Loss: 0.095230
# Epoch: 48 	Training Loss: 0.097908 	Validation Loss: 0.094044
# Epoch: 49 	Training Loss: 0.097187 	Validation Loss: 0.094662
# Epoch: 50 	Training Loss: 0.097045 	Validation Loss: 0.094343
# Using original a_Xt shape: torch.Size([1399, 1, 1])
# Processing batches:   0%|          | 0/22 [00:00<?, ?batch/s]c:\Users\xyc93\AppData\Local\anaconda3\envs\myvenvtorch\lib\site-packages\torch\_functorch\deprecated.py:61: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.vmap is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.vmap instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('vmap', 'torch.vmap')
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 162.68batch/s]
# saving FNN a and b to:  a_b_example_ou.jbl
# Outer Epoch 1/6
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 183.90batch/s]
# c:\Users\xyc93\AppData\Local\anaconda3\envs\myvenvtorch\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch: 1 	Training Loss: 0.009080 val loss: 0.008941
# Saving model, val loss improved from 1000000000000000.000000 to 0.008941
# Epoch: 2 	Training Loss: 0.009057 val loss: 0.008919
# Saving model, val loss improved from 0.008941 to 0.008919
# EarlyStopping counter: 1 out of 7
# Epoch 1 time: 0.21 seconds
# Outer Epoch 2/6
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 193.03batch/s]
# Epoch: 1 	Training Loss: 0.009038 val loss: 0.008902
# Saving model, val loss improved from 0.008919 to 0.008902
# Epoch: 2 	Training Loss: 0.009016 val loss: 0.008881
# Saving model, val loss improved from 0.008902 to 0.008881
# EarlyStopping counter: 1 out of 7
# Epoch 2 time: 0.20 seconds
# Outer Epoch 3/6
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 183.51batch/s]
# Epoch: 1 	Training Loss: 0.008997 val loss: 0.008864
# Saving model, val loss improved from 0.008881 to 0.008864
# Epoch: 2 	Training Loss: 0.008974 val loss: 0.008843
# Saving model, val loss improved from 0.008864 to 0.008843
# EarlyStopping counter: 1 out of 7
# Epoch 3 time: 0.20 seconds
# Outer Epoch 4/6
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 194.89batch/s]
# Epoch: 1 	Training Loss: 0.008955 val loss: 0.008827
# Saving model, val loss improved from 0.008843 to 0.008827
# Epoch: 2 	Training Loss: 0.008933 val loss: 0.008806
# Saving model, val loss improved from 0.008827 to 0.008806
# EarlyStopping counter: 1 out of 7
# Epoch 4 time: 0.20 seconds
# Outer Epoch 5/6
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 169.26batch/s]
# Epoch: 1 	Training Loss: 0.008915 val loss: 0.008790
# Saving model, val loss improved from 0.008806 to 0.008790
# Epoch: 2 	Training Loss: 0.008893 val loss: 0.008769
# Saving model, val loss improved from 0.008790 to 0.008769
# EarlyStopping counter: 1 out of 7
# Epoch 5 time: 0.22 seconds
# Outer Epoch 6/6
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 187.96batch/s]
# Epoch: 1 	Training Loss: 0.008876 val loss: 0.008754
# Saving model, val loss improved from 0.008769 to 0.008754
# Epoch: 2 	Training Loss: 0.008854 val loss: 0.008734
# Saving model, val loss improved from 0.008754 to 0.008734
# EarlyStopping counter: 1 out of 7
# Epoch 6 time: 0.20 seconds

# %%
# Results from solver_edmd/solver_resdmd
evalues = solver.eigenvalues.T
efuns = solver.eigenfunctions(X)
N_dict = np.shape(evalues)[0]
Koopman_matrix_K = solver.K
outputs = {
    'efuns': efuns,
    'evalues': evalues,
    'N_dict': N_dict,
    'K': Koopman_matrix_K
    }

# %%
# Take ln values of the eigenvalues and divide by 0.1
# ln_evalues = np.log(evalues[:4]) / lag_time
ln_evalues = (evalues[:4]-1) / lag_time

print(ln_evalues)

## Plot eigenvalues on unit circle
# Assuming evalues is a numpy array of complex numbers
real_parts = ln_evalues.real
imag_parts = ln_evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2*np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

## Plot eigenfunctions
# Get the real part of eigenfunctions and normalize them
phi = np.real(efuns)

# Use the entire efuns instead of slicing
for i in range(len(evalues)):
    phi[:, i] = phi[:, i] / np.max(np.abs(phi[:, i]))

# Create a plot with 2x2 layout
fig, axs = plt.subplots(2, 2, figsize=(8, 8))
titles = ['1st eigenfunction', '2nd eigenfunction', '3rd eigenfunction', '4th eigenfunction']

# Determine global min and max values for the eigenfunctions for a uniform scale
vmin = np.min(phi)
vmax = np.max(phi)
cbar_ticks = np.linspace(vmin, vmax, 5)

# Flatten the 2D array of axes for easy iteration
axs_flat = axs.flatten()

for i, (ax, title) in enumerate(zip(axs_flat, titles)):
    scatter = ax.scatter(X, phi[:, i], c=phi[:, i], cmap='Spectral', marker='.', vmin=vmin, vmax=vmax)
    ax.set_title(title, pad=20)
    ax.set_xlabel('Data')
    ax.set_ylabel('Eigenfunction Value')
    ax.set_xlim(-2, 2)
    ax.set_ylim(-2, 2)
    cbar = fig.colorbar(scatter, ax=ax, orientation='vertical', fraction=0.046, pad=0.04, ticks=cbar_ticks)
    cbar.set_ticklabels([f"{tick:.1f}" for tick in cbar_ticks])
    ax.grid()
# fig.suptitle('SDMD', fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# [-5.75892737e-05+0.j -1.03753149e+00+0.j -2.23424145e+00+0.j
#  -3.88774292e+00+0.j]

# %%
from solver_gedmd_torch_gpu import KoopmanNNTorch as KoopmanNNTorch_g
from solver_gedmd_torch_gpu import  KoopmanSolverTorch as KoopmanSolverTorch_g
#### gEDMD Test ####
basis_function_g = KoopmanNNTorch_g(input_size=1, layer_sizes=[20, 20], n_psi_train=18).to(device)

solver_g = KoopmanSolverTorch_g(dic=basis_function, # Replace 'koopman_nn' by 'dic' if you use the original solver_edmdvar
                       target_dim=np.shape(data_x_train)[-1],
                       reg=0.1,  checkpoint_file= checkpoint_file, fnn_checkpoint_file= 'example_fnn_ou_001.torch',  a_b_file= 'a_b_example_ou.jbl',
                generator_batch_size= 4, fnn_batch_size= 32)

# %%
solver_g.build_with_generator(
    data_train=data_train,
    data_valid=data_valid,
    epochs=6,
    batch_size=32,
    lr=1e-5,
    log_interval=10,
    lr_decay_factor=.8,   
    )
# Out:
# Epoch: 1 	Training Loss: 0.352342 	Validation Loss: 0.262791
# Saving model, validation loss improved: 0.262791 < 10000.000000
# Epoch: 2 	Training Loss: 0.194043 	Validation Loss: 0.162041
# Saving model, validation loss improved: 0.162041 < 0.262791
# Epoch: 3 	Training Loss: 0.127553 	Validation Loss: 0.125966
# Saving model, validation loss improved: 0.125966 < 0.162041
# Epoch: 4 	Training Loss: 0.106790 	Validation Loss: 0.117170
# Saving model, validation loss improved: 0.117170 < 0.125966
# Epoch: 5 	Training Loss: 0.102129 	Validation Loss: 0.115620
# Saving model, validation loss improved: 0.115620 < 0.117170
# Epoch: 6 	Training Loss: 0.101340 	Validation Loss: 0.114812
# Saving model, validation loss improved: 0.114812 < 0.115620
# Epoch: 7 	Training Loss: 0.100138 	Validation Loss: 0.114000
# Saving model, validation loss improved: 0.114000 < 0.114812
# Epoch: 8 	Training Loss: 0.099802 	Validation Loss: 0.113338
# Saving model, validation loss improved: 0.113338 < 0.114000
# Epoch: 9 	Training Loss: 0.099823 	Validation Loss: 0.113204
# Saving model, validation loss improved: 0.113204 < 0.113338
# Epoch: 10 	Training Loss: 0.099005 	Validation Loss: 0.112094
# Saving model, validation loss improved: 0.112094 < 0.113204
# Epoch: 11 	Training Loss: 0.098570 	Validation Loss: 0.111843
# Saving model, validation loss improved: 0.111843 < 0.112094
# Epoch: 12 	Training Loss: 0.097618 	Validation Loss: 0.111019
# Saving model, validation loss improved: 0.111019 < 0.111843
# Epoch: 13 	Training Loss: 0.097122 	Validation Loss: 0.110528
# Saving model, validation loss improved: 0.110528 < 0.111019
# Epoch: 14 	Training Loss: 0.096425 	Validation Loss: 0.110058
# Saving model, validation loss improved: 0.110058 < 0.110528
# Epoch: 15 	Training Loss: 0.096326 	Validation Loss: 0.109697
# Saving model, validation loss improved: 0.109697 < 0.110058
# Epoch: 16 	Training Loss: 0.096141 	Validation Loss: 0.109511
# Saving model, validation loss improved: 0.109511 < 0.109697
# Epoch: 17 	Training Loss: 0.095477 	Validation Loss: 0.109195
# Saving model, validation loss improved: 0.109195 < 0.109511
# Epoch: 18 	Training Loss: 0.094887 	Validation Loss: 0.108789
# Saving model, validation loss improved: 0.108789 < 0.109195
# Epoch: 19 	Training Loss: 0.095323 	Validation Loss: 0.108614
# Saving model, validation loss improved: 0.108614 < 0.108789
# Epoch: 20 	Training Loss: 0.094877 	Validation Loss: 0.108261
# Saving model, validation loss improved: 0.108261 < 0.108614
# Epoch: 21 	Training Loss: 0.094487 	Validation Loss: 0.108733
# Epoch: 22 	Training Loss: 0.094504 	Validation Loss: 0.108517
# Epoch: 23 	Training Loss: 0.093952 	Validation Loss: 0.108334
# Epoch: 24 	Training Loss: 0.094144 	Validation Loss: 0.108057
# Saving model, validation loss improved: 0.108057 < 0.108261
# Epoch: 25 	Training Loss: 0.093927 	Validation Loss: 0.108310
# Epoch: 26 	Training Loss: 0.093658 	Validation Loss: 0.107956
# Saving model, validation loss improved: 0.107956 < 0.108057
# Epoch: 27 	Training Loss: 0.093642 	Validation Loss: 0.108140
# Epoch: 28 	Training Loss: 0.093871 	Validation Loss: 0.108113
# Epoch: 29 	Training Loss: 0.093566 	Validation Loss: 0.108087
# Epoch: 30 	Training Loss: 0.093714 	Validation Loss: 0.108218
# Epoch: 31 	Training Loss: 0.093822 	Validation Loss: 0.108342
# Epoch: 32 	Training Loss: 0.093785 	Validation Loss: 0.108198
# Epoch: 33 	Training Loss: 0.093679 	Validation Loss: 0.108025
# Epoch: 34 	Training Loss: 0.094080 	Validation Loss: 0.108408
# Epoch: 35 	Training Loss: 0.093825 	Validation Loss: 0.107890
# Saving model, validation loss improved: 0.107890 < 0.107956
# Epoch: 36 	Training Loss: 0.093927 	Validation Loss: 0.107944
# Epoch: 37 	Training Loss: 0.093450 	Validation Loss: 0.108322
# Epoch: 38 	Training Loss: 0.093978 	Validation Loss: 0.108228
# Epoch: 39 	Training Loss: 0.093686 	Validation Loss: 0.107954
# Epoch: 40 	Training Loss: 0.093353 	Validation Loss: 0.108370
# Epoch: 41 	Training Loss: 0.093230 	Validation Loss: 0.108166
# Epoch: 42 	Training Loss: 0.093917 	Validation Loss: 0.108947
# Epoch: 43 	Training Loss: 0.093461 	Validation Loss: 0.108052
# Epoch: 44 	Training Loss: 0.094053 	Validation Loss: 0.108290
# Epoch: 45 	Training Loss: 0.093768 	Validation Loss: 0.107954
# Epoch: 46 	Training Loss: 0.093996 	Validation Loss: 0.108297
# Epoch: 47 	Training Loss: 0.093484 	Validation Loss: 0.108243
# Epoch: 48 	Training Loss: 0.093781 	Validation Loss: 0.107779
# Saving model, validation loss improved: 0.107779 < 0.107890
# Epoch: 49 	Training Loss: 0.093750 	Validation Loss: 0.108166
# Epoch: 50 	Training Loss: 0.093831 	Validation Loss: 0.108030
# Using original a_Xt shape: torch.Size([1399, 1, 1])
# c:\Users\xyc93\AppData\Local\anaconda3\envs\myvenvtorch\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Processing batches:   0%|          | 0/22 [00:00<?, ?batch/s]c:\Users\xyc93\AppData\Local\anaconda3\envs\myvenvtorch\lib\site-packages\torch\_functorch\deprecated.py:61: UserWarning: We've integrated functorch into PyTorch. As the final step of the integration, functorch.vmap is deprecated as of PyTorch 2.0 and will be deleted in a future version of PyTorch >= 2.3. Please use torch.vmap instead; see the PyTorch 2.0 release notes and/or the torch.func migration guide for more details https://pytorch.org/docs/master/func.migrating.html
#   warn_deprecated('vmap', 'torch.vmap')
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 140.10batch/s]
# Epoch 1/6, gEDMD loss: 4.378909e-03
# Saving best model at epoch 1
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 143.42batch/s]
# EarlyStopping counter: 1 out of 7
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 149.86batch/s]
# EarlyStopping counter: 2 out of 7
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 165.26batch/s]
# EarlyStopping counter: 3 out of 7
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 164.64batch/s]
# EarlyStopping counter: 4 out of 7
# Processing batches: 100%|██████████| 22/22 [00:00<00:00, 164.24batch/s]
# EarlyStopping counter: 5 out of 7
# ([0.004378908964085631,
#   0.004380273241739325,
#   0.004381639560803736,
#   0.004383007815651641,
#   0.004384377900521913,
#   0.004385749709754397],
#  0.004378908964085631)

# %%
solver_g.eig_decomp()  # Do spectral decomposition to generate eigenvalues and eigenvectors

evalues = solver_g.eigenvalues.T
efuns = solver_g.eigenfunctions(X)
N_dict = np.shape(evalues)[0]
Psi_X = solver_g.get_Psi_X()
Psi_Y = solver_g.get_Psi_Y()
outputs = {
    'efuns': efuns,
    'evalues': evalues,
    'N_dict': N_dict
}

# %%
## Plot eigenvalues on unit circle
# Assuming evalues is a numpy array of complex numbers
real_parts = evalues.real
imag_parts = evalues.imag

# Create the plot
plt.figure(figsize=(6, 4))
plt.scatter(real_parts, imag_parts, color='blue', label='Eigenvalues')

# Draw a unit circle for reference
theta = np.linspace(0, 2*np.pi, 100)
plt.plot(np.cos(theta), np.sin(theta), linestyle='--', color='grey', label='Unit Circle')

plt.title('Eigenvalues in Unit Circle: gEDMD')
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.axis('equal')  # Ensure the aspect ratio is equal to make the unit circle round
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

## Plot eigenfunctions
# Get the real part of eigenfunctions and normalize them
phi = np.real(efuns)

# Use the entire efuns instead of slicing
for i in range(len(evalues)):
    phi[:, i] = phi[:, i] / np.max(np.abs(phi[:, i]))

# Create a plot with 2x2 layout
fig, axs = plt.subplots(2, 2, figsize=(8, 8))
titles = ['1st eigenfunction', '2nd eigenfunction', '3rd eigenfunction', '4th eigenfunction']

# Determine global min and max values for the eigenfunctions for a uniform scale
vmin = np.min(phi)
vmax = np.max(phi)
cbar_ticks = np.linspace(vmin, vmax, 5)

# Flatten the 2D array of axes for easy iteration
axs_flat = axs.flatten()

for i, (ax, title) in enumerate(zip(axs_flat, titles)):
    scatter = ax.scatter(X, phi[:, i], c=phi[:, i], cmap='Spectral', marker='.', vmin=vmin, vmax=vmax)
    ax.set_title(title, pad=20)
    ax.set_xlabel('Data')
    ax.set_ylabel('Eigenfunction Value')
    ax.set_xlim(-2, 2)
    ax.set_ylim(-2, 2)
    cbar = fig.colorbar(scatter, ax=ax, orientation='vertical', fraction=0.046, pad=0.04, ticks=cbar_ticks)
    cbar.set_ticklabels([f"{tick:.1f}" for tick in cbar_ticks])
    ax.grid()
# fig.suptitle('gEDMD', fontsize=20)
plt.tight_layout()
plt.show()
